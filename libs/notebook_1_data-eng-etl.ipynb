# %% [markdown]
# #LocaleBnB - AirBnB contextual recommender
#
# ###G Scott Stukey, Zipfian Academy, April 2015 - July 2015
#
# Welcome to my capstone project, LocaleBnB - AirBnB Contextual Recommender.
#
# ###Background:
# This project was born out of my frustrations with AirBnB's search functionality. While my fiancee & I were booking in Montreal, we knew that we wanted to stay in a fun, young neighborhood & experience "local Montreal" and stay away from touristy areas. We wanted to find our 'Mission, SF' or 'Park Slope, Brooklyn' of Montreal. We found that while we could filter by neighborhood, we didn't know what the neighborhoods were like. We had no way of mapping the neighborhood to our criteria!
#
# Interestingly, the AirBnB content team has this amazing [neighborhood guide](https://www.airbnb.com/locations) section of their site, that gives great information about various cities (ex: [San Francisco](https://www.airbnb.com/locations/san-francisco)) & [traits of neighborhoods](https://www.airbnb.com/locations/san-francisco/neighborhoods) found in these cities (ex: [Alamo Square](https://www.airbnb.com/locations/san-francisco/alamo-square) is: Loved by San Franciscans, Stunning Views, & Touristy).
#
# Using the neighborhood guides put together for NYC & SF neighborhoods & scraping 4,000+ listings on AirBnB, I'm building an app that uses the listing description to predict whether the listing's neighborhood has a specified trait. I'm then applying that model to score the existing search results & resort their order based on a user's like of each.
#
# ###Project Details:
# I'm going to do the project in 4 phases:
# * Data Aquisition & ETL (scraping, storing, feature engineering)
# * Exploratory Data Analysis
# * Predictive Modeling
# * App Creation
#
# ###Notebook Details:
# This notebook was created retroactively after much of the project, for the purposes of explaining my methodology for the project. Prior to this notebook's creation, there were several notebooks used to test & iterate into good solutions.  For the actual project, I created classes for Neighborhoods, Search Results, & Room Listings which helped me with my app & code.
#
# Also note, I will be creating import cells for each section, so that if you wanted to recreate a particular section you can do it without worrying about the above code.

# %% [markdown]
# #Data Aquisition & ETL (scraping, storing, feature engineering)

# %% [markdown]
# ###Extracting neighborhoods from AirBnB's city guide

# %%
# import some things for this section
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# I've already made a file with the 2 cities I want to scrape:
# NOTE: city_id is unique to this project; it is not based on AirBnB's city ids 
df = pd.read_csv('../data/city_list.csv')
print df.head()
# Out:
#    city_id           city state        country
# 0        1  San-Francisco    CA  United-States
# 1        2       New-York    NY  United-States

# %%
# lets scrape an example city ('https://www.airbnb.com/locations/new-york') to see what we're working with
r = requests.get('https://www.airbnb.com/locations/new-york')

# %%
soup = BeautifulSoup(r.content)
soup.prettify
# Out:
# <bound method BeautifulSoup.prettify of <!DOCTYPE html>
# <html lang="en" xmlns:fb="http://ogp.me/ns/fb#">
# <head>
# <meta charset="utf-8"/>
# <script>
#   sherlock_firstbyte = Number(new Date());
# </script>
# <title>New York Travel Guide - Airbnb Neighborhoods</title>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"fc09a36731","applicationID":"1024027","transactionName":"dlwMQktaWAgBEB1RWkFaB0UWRlwLEw==","queueTime":10,"applicationTime":203,"ttGuid":"","agentToken":null,"agent":"js-agent.newrelic.com/nr-632.min.js"}</script>
# <script type="text/javascript">window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o?o:n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({QJf3ax:[function(e,n){function t(e){function n(n,t,a){e&&e(n,t,a),a||(a={});for(var u=c(n),f=u.length,s=i(a,o,r),p=0;f>p;p++)u[p].apply(s,t);return s}function a(e,n){f[e]=c(e).concat(n)}function c(e){return f[e]||[]}function u(){return t(n)}var f={};return{on:a,emit:n,create:u,listeners:c,_events:f}}function r(){return{}}var o="nr@context",i=e("gos");n.exports=t()},{gos:"7eSDFh"}],ee:[function(e,n){n.exports=e("QJf3ax")},{}],3:[function(e,n){function t(e){return function(){r(e,[(new Date).getTime()].concat(i(arguments)))}}var r=e("handle"),o=e(1),i=e(2);"undefined"==typeof window.newrelic&&(newrelic=window.NREUM);var a=["setPageViewName","addPageAction","setCustomAttribute","finished","addToTrace","inlineHit","noticeError"];o(a,function(e,n){window.NREUM[n]=t("api-"+n)}),n.exports=window.NREUM},{1:12,2:13,handle:"D5DuLP"}],"7eSDFh":[function(e,n){function t(e,n,t){if(r.call(e,n))return e[n];var o=t();if(Object.defineProperty&&Object.keys)try{return Object.defineProperty(e,n,{value:o,writable:!0,enumerable:!1}),o}catch(i){}return e[n]=o,o}var r=Object.prototype.hasOwnProperty;n.exports=t},{}],gos:[function(e,n){n.exports=e("7eSDFh")},{}],handle:[function(e,n){n.exports=e("D5DuLP")},{}],D5DuLP:[function(e,n){function t(e,n,t){return r.listeners(e).length?r.emit(e,n,t):(o[e]||(o[e]=[]),void o[e].push(n))}var r=e("ee").create(),o={};n.exports=t,t.ee=r,r.q=o},{ee:"QJf3ax"}],id:[function(e,n){n.exports=e("XL7HBI")},{}],XL7HBI:[function(e,n){function t(e){var n=typeof e;return!e||"object"!==n&&"function"!==n?-1:e===window?0:i(e,o,function(){return r++})}var r=1,o="nr@id",i=e("gos");n.exports=t},{gos:"7eSDFh"}],G9z0Bl:[function(e,n){function t(){var e=d.info=NREUM.info,n=f.getElementsByTagName("script")[0];if(e&&e.licenseKey&&e.applicationID&&n){c(p,function(n,t){n in e||(e[n]=t)});var t="https"===s.split(":")[0]||e.sslForHttp;d.proto=t?"https://":"http://",a("mark",["onload",i()]);var r=f.createElement("script");r.src=d.proto+e.agent,n.parentNode.insertBefore(r,n)}}function r(){"complete"===f.readyState&&o()}function o(){a("mark",["domContent",i()])}function i(){return(new Date).getTime()}var a=e("handle"),c=e(1),u=(e(2),window),f=u.document,s=(""+location).split("?")[0],p={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",agent:"js-agent.newrelic.com/nr-632.min.js"},d=n.exports={offset:i(),origin:s,features:{}};f.addEventListener?(f.addEventListener("DOMContentLoaded",o,!1),u.addEventListener("load",t,!1)):(f.attachEvent("onreadystatechange",r),u.attachEvent("onload",t)),a("mark",["firstbyte",i()])},{1:12,2:3,handle:"D5DuLP"}],loader:[function(e,n){n.exports=e("G9z0Bl")},{}],12:[function(e,n){function t(e,n){var t=[],o="",i=0;for(o in e)r.call(e,o)&&(t[i]=n(o,e[o]),i+=1);return t}var r=Object.prototype.hasOwnProperty;n.exports=t},{}],13:[function(e,n){function t(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,o=t-n||0,i=Array(0>o?0:o);++r<o;)i[r]=e[n+r];return i}n.exports=t},{}]},{},["G9z0Bl"]);</script>
# <link href="https://www.airbnb.com/locations/new-york" rel="canonical"/>
# <link href="https://www.airbnb.com/locations/new-york" hreflang="en" rel="alternate"/>
# <link href="https://www.airbnb.co.uk/locations/new-york" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.airbnb.com.sg/locations/new-york" hreflang="en-SG" rel="alternate"/>
# <link href="https://www.airbnb.com.au/locations/new-york" hreflang="en-AU" rel="alternate"/>
# <link href="https://www.airbnb.co.nz/locations/new-york" hreflang="en-NZ" rel="alternate"/>
# <link href="https://www.airbnb.ca/locations/new-york" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.airbnb.ie/locations/new-york" hreflang="en-IE" rel="alternate"/>
# <meta content="From dawn until dusk until dawn again, trendsetting New York City never sleeps and never lets up." name="description"/>
# <meta content="138566025676" property="fb:app_id"/>
# <meta content="Airbnb" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="https://a1.muscache.com/locations/uploads/city/hero/22/0_2831_95_1567_hero_USA_Manhattan_Skyline_061_EO.jpg" property="og:image"/>
# <meta content="From dawn until dusk until dawn again, trendsetting New York City never sleeps and never lets up." property="og:description"/>
# <meta content="https://www.airbnb.com/locations/new-york" property="og:url"/>
# <meta content="New York Travel Guide - Airbnb Neighborhoods" property="og:title"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="fdu+2JUnZHQKQTY+4MbdBMdDaqi6ROMVI9wDc07SroQ=" name="csrf-token"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#       <script src="https://a2.muscache.com/airbnb/nabelove/locations/assets-pretzel/html5shiv-28192591f66ca0d346cc395bc6159593.js" type="text/javascript"></script>
#       <style type="text/css">
#         .svg {
#           display: none !important;
#         }
#       </style>
#     <![endif]-->
# <!--[if lte IE 9]>
#       <link href="https://a1.muscache.com/airbnb/nabelove/locations/assets-pretzel/ie-40380616ba9fc401419189cdd9f46ab2.css" media="all" rel="stylesheet" type="text/css" />
#     <![endif]-->
# <meta content="width=1000,maximum-scale=1.0" name="viewport"/>
# <link href="https://a1.muscache.com/airbnb/nabelove/locations/assets-pretzel/airbnb_logo.png" rel="image_src"/>
# <link href="/opensearch.xml" rel="search" title="Airbnb" type="application/opensearchdescription+xml"/>
# <link href="https://a2.muscache.com/airbnb/nabelove/locations/assets-pretzel/application-019cf366f6762dfecb6f98ced96ecf94.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/genome/cities-9f341dc2947cc0da65581016eda1d956.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# </head>
# <body class=" en" id="cities_show_page">
# <div id="fb-root"></div>
# <div class="navbar navbar-top clearfix" id="header">
# <div class="navbar-inner">
# <div class="container container-full-width page-container page-container-responsive navbar-container">
# <a class="brand airbnb" href="/">
# <img height="32" src="https://a1.muscache.com/airbnb/nabelove/locations/assets-pretzel/header/logo3-07d13112bba070dbdad538156b307fcf.png" width="102"/>
# </a>
# <ul class="nav">
# <li id="header-search">
# <form action="/s" id="search-form">
# <div id="search-bar">
# <i class="icon icon-search"></i>
# <input autocomplete="off" id="header-location" name="location" placeholder="Where are you going?" type="text"/>
# </div>
# <div id="header-search-settings">
# <label class="checkin">Check in <input class="checkin" id="header-search-checkin" name="checkin" placeholder="mm/dd/yyyy" type="text"/></label>
# <label class="checkout">Check out <input class="checkout" id="header-search-checkout" name="checkout" placeholder="mm/dd/yyyy" type="text"/></label>
# <label class="guests">Guests
#                  <select id="header-search-guests" name="guests">
# <option value="1">1</option><option value="2">2</option><option value="3">3</option><option value="4">4</option><option value="5">5</option><option value="6">6</option><option value="7">7</option><option value="8">8</option><option value="9">9</option><option value="10">10</option><option value="11">11</option><option value="12">12</option><option value="13">13</option><option value="14">14</option><option value="15">15</option><option value="16">16</option>
# </select>
# </label>
# <label>Room type</label>
# <label class="checkbox" for="room_type_0"><input id="room_type_0" name="room_types[]" type="checkbox" value="Entire home/apt"/> Entire home/apt</label>
# <label class="checkbox" for="room_type_1"><input id="room_type_1" name="room_types[]" type="checkbox" value="Private room"/> Private room</label>
# <label class="checkbox" for="room_type_2"><input id="room_type_2" name="room_types[]" type="checkbox" value="Shared room"/> Shared room</label>
# <button class="btn blue" type="submit"><i class="icon icon-search"></i> Find a place</button>
# </div>
# </form>
# </li>
# <li class="dropdown item_explore">
# <a class="dropdown-toggle" href="javascript:void(0)"> Browse <b class="caret"></b></a>
# <ul class="dropdown-menu dropdown-bordered">
# <li><a href="/locations"><i class="icon icon-neighborhoods"></i> Neighborhoods</a></li>
# <li><a href="/wishlists/popular"><i class="icon icon-fire"></i> Popular</a></li>
# </ul>
# </li>
# </ul>
# <ul class="nav pull-right help-menu" style="margin-left:0;">
# <li class="dropdown">
# <a class="dropdown-toggle help-toggle" href="javascript:void(0)"> Help <b class="caret"></b></a>
# <ul class="dropdown-menu help-dropdown dropdown-bordered">
# <li class="nav-header"><a class="lighter small unstyled help-center-link hidden" href="/help">Visit the Help Center »</a></li>
# <li class="loading"></li>
# <li class="hidden mt10"><a class="" href="/trust">Visit our Trust &amp; Safety Center</a></li>
# <li class="all_faqs hidden"><a href="/help/topic/hosting">See all FAQs</a></li>
# </ul>
# </li>
# <li class="list-your-space"><a class="yellow btn" href="/rooms/new" id="list-your-space">List your space</a></li>
# </ul>
# <ul class="nav pull-right logged-out">
# <li id="sign_up"><a href="/signup_login" rel="nofollow">Sign Up</a>
# </li><li id="login"><a href="/login" rel="nofollow">Log In</a>
# </li></ul>
# <ul class="nav pull-right logged-in">
# <li class="dropdown user-item">
# <a class="dropdown-toggle" href="javascript:void(0)">
# <div class="mini-media-box user-profile-image"><img height="20" id="header-profile-image" src="" width="20"/></div> <span class="value_name">User</span> <b class="caret"></b>
# </a>
# <ul class="dropdown-menu dropdown-bordered">
# <li><a class="no-crawl" data-href="/home/dashboard" href="#">Dashboard</a>
# </li><li>
# <a class="no-crawl" data-href="/rooms" href="#">
# <span class="singular" style="display: none;">Your Listing</span>
# <span class="plural">Your Listings</span>
# </a>
# </li>
# <li><a class="no-crawl" data-href="/trips/upcoming" href="#">Your Trips</a>
# </li><li><a class="no-crawl" data-href="/wishlists/my" href="#" id="wishlists">Wish Lists</a>
# </li><li><a class="no-crawl" data-href="/users/edit" href="#">Edit Profile</a>
# </li><li><a class="no-crawl" data-href="/account" href="#">Account</a>
# </li><li><a class="no-crawl" data-href="/logout" href="#" id="header-logout">Log Out</a></li>
# </ul>
# </li>
# <li class="divider-vertical"></li>
# <li id="inbox-item">
# <a class="no-crawl" data-href="/inbox" href="#"><i class="icon icon-envelope"><span class="text-hide">Inbox</span></i><i class="alert-count position-super fade">0</i></a>
# </li>
# <li class="divider-vertical"></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="cities-wrapper">
# <div class="navbar navbar-black" id="sticky_nav">
# <div class="navbar-inner clearfix">
# <div id="neighborhood_cart"></div>
# <ul class="nav" id="neighborhood_nav" itemprop="breadcrumb">
# <li itemscope="" itemtype="http://www.data-vocabulary.org/Breadcrumb/">
# <a href="/locations" itemprop="url">
# <span itemprop="title">Cities
#                 <i class="icon icon-chevron-right"></i>
# </span>
# </a>
# </li>
# <li>
# <a href="#"><span>New York</span></a>
# </li>
# </ul>
# <ul class="nav saved">
# <li>
# <a href="#">
# <span class="message">
#                 Saved neighborhoods
#               </span> <span class="pip neighborhood-count">0</span>
# </a>
# <div class="flyout"></div>
# </li>
# </ul>
# </div>
# </div>
# <div class="city-page page" id="city">
# <div class="city hero img-overlay fullscreen" style="background-image: url('https://a1.muscache.com/locations/uploads/city/hero/22/0_2831_95_1567_hero_USA_Manhattan_Skyline_061_EO.jpg');">
# <img alt="hero USA Manhattan Skyline EO" class="background" data-height="676" data-width="1300" src="https://a1.muscache.com/locations/uploads/city/hero/22/0_2831_95_1567_hero_USA_Manhattan_Skyline_061_EO.jpg"/>
# <div class="title overlay">
# <div class="container">
# <h1 class="circularbold">New York</h1>
# <h2>From dawn until dusk until dawn again, trendsetting New York City never sleeps and never lets up.</h2>
# <a class="btn large" href="/locations/new-york/neighborhoods">Find a neighborhood</a>
# </div>
# </div>
# </div>
# <div id="jumbo_map">
# <div id="map-frame"></div>
# </div>
# <section class="city-summary section section-offset" id="city_summary">
# <div class="container">
# <div class="row space2">
# <div class="span3 widget">
# <h5 class="city-attributes-title">Get around with</h5>
# <big class="circularbold">Public Transit</big>
# <div class="extra">
# <p>New Yorkers get around primarily via the subway and taxi system. New York's subway system is one of the best in the world and you can get virtually anywhere in the city for a flat fee of $2.50 24 hours a day. Taxis are readily available across central and downtown Manhattan and conveniently, they take credit cards. Driving your own car is only possible in the outer neighborhoods unless you want to spend a fortune on parking and pass many hours sitting in traffic.</p>
# </div>
# </div>
# <div class="span3 widget">
# <h5 class="city-attributes-title">Places to stay</h5>
# <a href="/s/New-York?" target="_blank">See all listings</a>
# </div>
# <div class="span6 widget">
# <h5 class="city-attributes-title">Known for</h5>
# <p>Bright lights, long nights, tall buildings, high fashion, Lady Liberty, Central Park, Broadway, Wall Street, museums, the cutting edge, setting trends</p>
# </div>
# </div>
# <div class="row detail-tiles">
# <div class="span6">
# <div class="panel-background-light panel-border">
# <h3 class="header panel-header-gray">
#     Locals Love
#   </h3>
# <div class="panel-padding">
# <div class="row row-fluid">
# <div class="span2 center">
# <img alt="Locals Love" height="60" src="https://a2.muscache.com/airbnb/nabelove/locations/assets-pretzel/icons/locals-heart-f498816904a73e4a624d975fdd36b94f.png" width="60"/>
# </div>
# <div class="span9">
# <p>
#         Themselves, a good slice, bagels and schmear, the corner bodega, take-out, delivery, 24-hour diners, late night clubs, weekend getaways, moving to Brooklyn
#         </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="span6">
# <div class="panel-background-light panel-border">
# <h3 class="header panel-header-gray">
#     Locals Complain About
#   </h3>
# <div class="panel-padding">
# <div class="row row-fluid">
# <div class="span2 center">
# <img alt="Locals Complain About" height="60" src="https://a2.muscache.com/airbnb/nabelove/locations/assets-pretzel/icons/locals-complain-2df10a856243a9782a75361fee5934a1.png" width="60"/>
# </div>
# <div class="span9">
# <p>
#         Slow walkers, inept subway riders, sewer rats, the smell of summer garbage, apartments described as “cozy,” paying $15 for a cocktail (and doing it anyway)
#         </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div class="featured-neighborhoods section">
# <div class="container">
# <div class="row">
# <div class="span12 center">
# <h2 class="circularbold">
#               Featured Neighborhoods
#             </h2>
# <p class="lede">Explore 60 New York neighborhoods. Which are right for you?</p>
# <ul class=" neighborhoods">
# <li class=" tile " data-neighborhood-id="486" data-neighborhood-permalink="nolita" style="">
# <a href="/locations/new-york/nolita">
# <div class="beveled-media-box img-overlay" style="background-image:url('https://a1.muscache.com/locations/uploads/neighborhood/hero/486/5_1004_0_666_tile_USA_NYC_Nolita_CameronBlaylock32.jpg');">
# <div class="center panel-padding">
# <h2>Nolita</h2>
# <p>Sophisticated simplicity in NYC.</p>
# </div>
# </div>
# <div class="blurb">
# <div class="panel-padding center clearfix neighborhood-tags">
# <div class="neighborhood-tag">europeans
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">trendy
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">boutiques
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">great dining
# </div>
# </div>
# </div>
# <div class="sub friends" style="display: none;">
# <ul>
# </ul>
# <p>
# </p>
# </div>
# </a>
# </li>
# <li class=" tile " data-neighborhood-id="662" data-neighborhood-permalink="hell-s-kitchen" style="">
# <a href="/locations/new-york/hell-s-kitchen">
# <div class="beveled-media-box img-overlay" style="background-image:url('https://a0.muscache.com/locations/uploads/neighborhood/hero/662/0_4199_0_2800_tile_USA_NYC_hellskitchen_001_JR.jpg');">
# <div class="center panel-padding">
# <h2>Hell's Kitchen</h2>
# <p>If you can’t stand the heat…</p>
# </div>
# </div>
# <div class="blurb">
# <div class="panel-padding center clearfix neighborhood-tags">
# <div class="neighborhood-tag">convenient location
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">affordable
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">young
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">great food
# </div>
# </div>
# </div>
# <div class="sub friends" style="display: none;">
# <ul>
# </ul>
# <p>
# </p>
# </div>
# </a>
# </li>
# <li class=" tile " data-neighborhood-id="1301" data-neighborhood-permalink="red-hook" style="">
# <a href="/locations/new-york/red-hook">
# <div class="beveled-media-box img-overlay" style="background-image:url('https://a0.muscache.com/locations/uploads/neighborhood/hero/1301/0_4200_4_2804_tile_USA_RedHook_CameronBlaylock34.jpg');">
# <div class="center panel-padding">
# <h2>Red Hook</h2>
# <p>Artists fall for this neighborhood- hook, line, and sinker.</p>
# </div>
# </div>
# <div class="blurb">
# <div class="panel-padding center clearfix neighborhood-tags">
# <div class="neighborhood-tag">residustrial
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">underrated
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">no subway
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">waterfront
# </div>
# </div>
# </div>
# <div class="sub friends" style="display: none;">
# <ul>
# </ul>
# <p>
# </p>
# </div>
# </a>
# </li>
# </ul>
# <a class="btn large center" href="/locations/new-york/neighborhoods">Find a neighborhood</a>
# </div>
# </div>
# </div>
# </div>
# <div class="neighborhood-list section section-offset">
# <div class="container">
# <div class="row">
# <div class="span12">
# <h2 class="circularbold">All Neighborhoods</h2>
# </div>
# </div>
# <div class="row">
# <a name="all-neighborhoods"></a>
# <div class="span3">
# <ul>
# <li><a href="/locations/new-york/alphabet-city">Alphabet City</a></li>
# <li><a href="/locations/new-york/astoria">Astoria</a></li>
# <li><a href="/locations/new-york/battery-park-city">Battery Park City</a></li>
# <li><a href="/locations/new-york/bedford-stuyvesant">Bedford-Stuyvesant</a></li>
# <li><a href="/locations/new-york/boerum-hill">Boerum Hill</a></li>
# <li><a href="/locations/new-york/brooklyn-heights">Brooklyn Heights</a></li>
# <li><a href="/locations/new-york/bushwick">Bushwick</a></li>
# <li><a href="/locations/new-york/carroll-gardens">Carroll Gardens</a></li>
# <li><a href="/locations/new-york/chelsea">Chelsea</a></li>
# <li><a href="/locations/new-york/chinatown">Chinatown</a></li>
# <li><a href="/locations/new-york/civic-center">Civic Center</a></li>
# <li><a href="/locations/new-york/clinton-hill">Clinton Hill</a></li>
# <li><a href="/locations/new-york/cobble-hill">Cobble Hill</a></li>
# <li><a href="/locations/new-york/crown-heights">Crown Heights</a></li>
# <li><a href="/locations/new-york/downtown-brooklyn">Downtown Brooklyn</a></li>
# </ul>
# </div>
# <div class="span3">
# <ul>
# <li><a href="/locations/new-york/dumbo">DUMBO</a></li>
# <li><a href="/locations/new-york/east-harlem">East Harlem</a></li>
# <li><a href="/locations/new-york/east-village">East Village</a></li>
# <li><a href="/locations/new-york/financial-district">Financial District</a></li>
# <li><a href="/locations/new-york/flatbush">Flatbush</a></li>
# <li><a href="/locations/new-york/flatiron-district">Flatiron District</a></li>
# <li><a href="/locations/new-york/flushing">Flushing</a></li>
# <li><a href="/locations/new-york/fort-greene">Fort Greene</a></li>
# <li><a href="/locations/new-york/gowanus">Gowanus</a></li>
# <li><a href="/locations/new-york/gramercy-park">Gramercy Park</a></li>
# <li><a href="/locations/new-york/greenpoint">Greenpoint</a></li>
# <li><a href="/locations/new-york/greenwich-village">Greenwich Village</a></li>
# <li><a href="/locations/new-york/harlem">Harlem</a></li>
# <li><a href="/locations/new-york/hell-s-kitchen">Hell's Kitchen</a></li>
# <li><a href="/locations/new-york/hudson-square">Hudson Square</a></li>
# </ul>
# </div>
# <div class="span3">
# <ul>
# <li><a href="/locations/new-york/inwood">Inwood</a></li>
# <li><a href="/locations/new-york/jackson-heights">Jackson Heights</a></li>
# <li><a href="/locations/new-york/kensington">Kensington</a></li>
# <li><a href="/locations/new-york/kips-bay">Kips Bay</a></li>
# <li><a href="/locations/new-york/lefferts-garden">Lefferts Garden</a></li>
# <li><a href="/locations/new-york/little-italy">Little Italy</a></li>
# <li><a href="/locations/new-york/long-island-city">Long Island City</a></li>
# <li><a href="/locations/new-york/lower-east-side">Lower East Side</a></li>
# <li><a href="/locations/new-york/meatpacking-district">Meatpacking District</a></li>
# <li><a href="/locations/new-york/midtown">Midtown</a></li>
# <li><a href="/locations/new-york/midtown-east">Midtown East</a></li>
# <li><a href="/locations/new-york/morningside-heights">Morningside Heights</a></li>
# <li><a href="/locations/new-york/murray-hill">Murray Hill</a></li>
# <li><a href="/locations/new-york/noho">Noho</a></li>
# <li><a href="/locations/new-york/nolita">Nolita</a></li>
# </ul>
# </div>
# <div class="span3">
# <ul>
# <li><a href="/locations/new-york/park-slope">Park Slope</a></li>
# <li><a href="/locations/new-york/prospect-heights">Prospect Heights</a></li>
# <li><a href="/locations/new-york/red-hook">Red Hook</a></li>
# <li><a href="/locations/new-york/ridgewood">Ridgewood</a></li>
# <li><a href="/locations/new-york/soho">Soho</a></li>
# <li><a href="/locations/new-york/south-street-seaport">South Street Seaport</a></li>
# <li><a href="/locations/new-york/times-square-theatre-district">Times Square/Theatre District</a></li>
# <li><a href="/locations/new-york/tribeca">Tribeca</a></li>
# <li><a href="/locations/new-york/union-square">Union Square</a></li>
# <li><a href="/locations/new-york/upper-east-side">Upper East Side</a></li>
# <li><a href="/locations/new-york/upper-west-side">Upper West Side</a></li>
# <li><a href="/locations/new-york/washington-heights">Washington Heights</a></li>
# <li><a href="/locations/new-york/west-village">West Village</a></li>
# <li><a href="/locations/new-york/williamsburg">Williamsburg</a></li>
# <li><a href="/locations/new-york/windsor-terrace">Windsor Terrace</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="footer">
# <div class="container">
# <div class="row">
# <div class="span3">
# <div class="language-curr-picker clearfix">
# <span class="language-picker"></span>
# <span class="currency-picker"></span>
# </div>
# </div>
# <div class="span3">
# <h6>Company</h6>
# <ul class="unstyled">
# <li><a class="link-contrast" href="/about/about-us">About</a></li>
# <li><a class="link-contrast" href="/careers">Careers</a></li>
# <li><a class="link-contrast" href="/press/news">Press</a></li>
# <li><a class="link-contrast" href="http://blog.airbnb.com">Blog</a></li>
# <li><a class="link-contrast" href="/help">Help</a></li>
# <li><a class="link-contrast" href="/policies">Policies</a></li>
# <li><a class="link-contrast" href="/disaster-response">Disaster Response</a></li>
# <li><a class="link-contrast" href="/terms">Terms &amp; Privacy</a></li>
# </ul>
# </div>
# <div class="span3">
# <h6>Discover</h6>
# <ul class="unstyled">
# <li><a class="link-contrast" href="/trust">Trust &amp; Safety</a></li>
# <li><a class="link-contrast" href="/wishlists/airbnb_picks">Airbnb Picks</a></li>
# <li><a class="link-contrast" href="/mobile">Mobile</a></li>
# <li><a class="link-contrast" href="https://www.airbnbnyc.com">Support NYC</a></li>
# <li><a class="link-contrast" href="/business-travel-management">Business Travel</a></li>
# <li><a class="link-contrast" href="/sitemaps">Site Map</a></li> </ul>
# </div>
# <div class="span3 col-3 hide-phone">
# <h6>Hosting</h6>
# <ul class="unstyled list-layout">
# <li><a href="/host">Why Host</a></li>
# <li><a href="/hospitality">Hospitality</a></li>
# <li><a href="/help/responsible-hosting">Responsible Hosting</a></li>
# <li><a href="/home-safety">Home Safety</a></li>
# <li><a href="/stories">Stories</a></li>
# </ul>
# </div>
# </div>
# <div class="row footer-slim center">
# <div class="span8 offset2">
# <h3 class="external-links-header">Join us on</h3>
# <ul class="unstyled js-external-links list-inline">
# <li>
# <a class="link-contrast footer-icon-container" href="//www.facebook.com/airbnb" target="_blank">
# <i class="icon footer-icon icon-facebook"></i>
# </a> </li>
# <li>
# <a class="link-contrast footer-icon-container" href="https://plus.google.com/+airbnb" target="_blank">
# <i class="icon footer-icon icon-google-plus"></i>
# </a> </li>
# <li>
# <a class="link-contrast footer-icon-container" href="//twitter.com/airbnb" target="_blank">
# <i class="icon footer-icon icon-twitter"></i>
# </a> </li>
# <li>
# <a class="link-contrast footer-icon-container" href="http://www.linkedin.com/company/airbnb" target="_blank">
# <i class="icon footer-icon icon-linkedin"></i>
# </a> </li>
# <li>
# <a class="link-contrast footer-icon-container" href="http://www.pinterest.com/airbnb/" target="_blank">
# <i class="icon footer-icon icon-pinterest"></i>
# </a> </li>
# <li>
# <a class="link-contrast footer-icon-container" href="http://www.youtube.com/airbnb" target="_blank">
# <i class="icon footer-icon icon-youtube"></i>
# </a> </li>
# </ul>
# <div id="copyright">
#           © Airbnb, Inc.
#         </div>
# </div>
# </div>
# </div>
# </div>
# <script src="//maps.googleapis.com/maps/api/js?channel=location-prod&amp;client=gme-airbnbinc&amp;libraries=places&amp;locale=en&amp;sensor=true&amp;v=3.10" type="text/javascript"></script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-2725447-1', 'auto');
#   ga('send', 'pageview');
# </script>
# <script src="https://a1.muscache.com/airbnb/nabelove/locations/assets-pretzel/application-11020898eb2fcf72fd1f85beb27a65c9.js" type="text/javascript"></script>
# <script>
#       $.noConflict();
#     </script>
# <script>
#       (function() {
#         I18n.init({"currencies":{"ARS":{"symbol":"$","code_required":true,"options":null},"AUD":{"symbol":"$","code_required":true,"options":null},"BRL":{"symbol":"R$","code_required":false,"options":{"space_between_price_and_symbol":true}},"CAD":{"symbol":"$","code_required":true,"options":null},"CHF":{"symbol":"CHF","code_required":false,"options":{"position":"after","space_between_price_and_symbol":true}},"CNY":{"symbol":"&yen;","code_required":false,"options":{"unicode_symbol":"¥"}},"CZK":{"symbol":"&#75;&#269;","code_required":false,"options":{"unicode_symbol":"Kč"}},"DKK":{"symbol":"kr","code_required":true,"options":{"position":"after","space_between_price_and_symbol":true,"explicit_currency_not_aesthetic":true}},"EUR":{"symbol":"&euro;","code_required":false,"options":{"unicode_symbol":"€","position":"special"}},"GBP":{"symbol":"&pound;","code_required":false,"options":{"unicode_symbol":"£"}},"HKD":{"symbol":"$","code_required":true,"options":null},"HUF":{"symbol":"Ft","code_required":false,"options":null},"IDR":{"symbol":"Rp","code_required":false,"options":null},"ILS":{"symbol":"&#8362;","code_required":false,"options":{"unicode_symbol":"₪","space_between_price_and_symbol":true}},"INR":{"symbol":"&#8377;","code_required":false,"options":{"unicode_symbol":"₹"}},"JPY":{"symbol":"&yen;","code_required":false,"options":{"unicode_symbol":"¥","space_between_price_and_symbol":true}},"KRW":{"symbol":"&#8361;","code_required":false,"options":{"unicode_symbol":"₩","space_between_price_and_symbol":true}},"MYR":{"symbol":"&#82;&#77;","code_required":false,"options":{"unicode_symbol":"RM"}},"MXN":{"symbol":"$","code_required":true,"options":null},"NOK":{"symbol":"kr","code_required":true,"options":{"position":"after","space_between_price_and_symbol":true,"explicit_currency_not_aesthetic":true}},"NZD":{"symbol":"$","code_required":true,"options":null},"PHP":{"symbol":"&#8369;","code_required":false,"options":{"unicode_symbol":"₱"}},"PLN":{"symbol":"z&#22;&#322;","code_required":false,"options":{"unicode_symbol":"zł"}},"RUB":{"symbol":"&#1088;","code_required":false,"options":{"unicode_symbol":"р","position":"after"}},"SEK":{"symbol":"kr","code_required":true,"options":{"position":"after","space_between_price_and_symbol":true,"explicit_currency_not_aesthetic":true}},"SGD":{"symbol":"$","code_required":true,"options":null},"THB":{"symbol":"&#3647;","code_required":false,"options":{"unicode_symbol":"฿"}},"TRY":{"symbol":"&#84;&#76;","code_required":false,"options":{"unicode_symbol":"TL","position":"after","space_between_price_and_symbol":true}},"TWD":{"symbol":"$","code_required":true,"options":null},"USD":{"symbol":"$","code_required":false,"options":null},"VND":{"symbol":"&#8363;","code_required":false,"options":{"unicode_symbol":"₫"}},"ZAR":{"symbol":"R","code_required":true,"options":null}},"current_locale_name":"English","languages":[{"locale_name":"Bahasa Indonesia","locale":"id"},{"locale_name":"Bahasa Melayu","locale":"ms"},{"locale_name":"Català","locale":"ca"},{"locale_name":"Dansk","locale":"da"},{"locale_name":"Deutsch","locale":"de"},{"locale_name":"English","locale":"en"},{"locale_name":"Español","locale":"es"},{"locale_name":"Eλληνικά","locale":"el"},{"locale_name":"Français","locale":"fr"},{"locale_name":"Italiano","locale":"it"},{"locale_name":"Magyar","locale":"hu"},{"locale_name":"Nederlands","locale":"nl"},{"locale_name":"Norsk","locale":"no"},{"locale_name":"Polski","locale":"pl"},{"locale_name":"Português","locale":"pt"},{"locale_name":"Suomi","locale":"fi"},{"locale_name":"Svenska","locale":"sv"},{"locale_name":"Türkçe","locale":"tr"},{"locale_name":"Íslenska","locale":"is"},{"locale_name":"Čeština","locale":"cs"},{"locale_name":"Русский","locale":"ru"},{"locale_name":"ภาษาไทย","locale":"th"},{"locale_name":"中文 (简体)","locale":"zh"},{"locale_name":"中文 (繁體)","locale":"zh-TW"},{"locale_name":"日本語","locale":"ja"},{"locale_name":"한국어","locale":"ko"}]});
#         I18n.extend({"genome.cart.saved_this_neighborhood":"Saved this neighborhood!","genome.saved_neighborhoods":"Saved neighborhoods","genome.cart.save_this_neighborhood":"Save this neighborhood","genome.see_neighborhood_listings":"See all places to stay here","genome.cart.see_listings_in_saved_neighborhoods":"See listings in all saved neighborhoods","genome.feedback.know_this_neighborhood?":"Know this Neighborhood?","genome.feedback.share_your_local_knowledge":"Share your local knowledge","genome.feedback.looking_to_make_better":"We worked closely with our community to create this guide. Share your thoughts with us so that we can continue bringing it to life. What do you find inspiring about this neighborhood?","genome.feedback.suggest_a_tag":"Suggest a tag","genome.feedback.let_us_know_what_you_think":"We appreciate your taking the time to provide your insights. We rely on our community to bring these guides to life.","genome.feedback.submit":"Submit","genome.feedback.submit_tag":"Submit Tag","genome.feedback.what_word_or_phrase_comes_to_mind":"What word or phrase comes to mind when you think of this neighborhood?","genome.feedback.confirmation":"Thank you so much for contributing to this page! We do our best to build these community pages out from contributions like yours.","genome.feedback.thanks_for_the_tag_bro":"Thanks for your tag suggestion! You might see it on the site soon.","genome.neighborhood_tile.neighborhoods_count":"%{smart_count} neighborhood.||||%{smart_count} neighborhoods.","shared.Close":"Close","shared.Thanks":"Thanks","shared.Thank you":"Thank you","shared.Email":"Email","genome.feedback.please_enter_email":"Please enter an email address","genome.neighborhood_tile.neighborhoods_count_with_traits":"%{smart_count} neighborhood matches %{trait_list}.||||%{smart_count} neighborhoods match %{trait_list}.","genome.neighborhood_tile.see_all_listings":"See all listings","genome.neighborhood_tile.friends_here":"%{smart_count} friend here.||||%{smart_count} friends here.","shared.choose_language":"Choose language","shared.choose_currency":"Choose currency"})
#
#
#         var initOptions = {
#           locale: "en"
#         };
#         Airbnb.init(initOptions);
#         Airbnb.LangCurrPicker.init();
#         Airbnb.header = new Airbnb.Header();
#
#         if (Airbnb.Tracking) {
#           Airbnb.Tracking.addDefaultContext();
#           Airbnb.Tracking.addContext({
#             source: "locations",
#             controller: "cities",
#             action: "show",
#           });
#           Airbnb.Tracking.init();
#           Airbnb.Tracking.logEvent({
#             event_name: 'impression',
#             event_data: {source: 'location'}
#           });
#         }
#       })();
#       (function() {
#         Airbnb.apiKey = "d306zoyjsyarp7ifhu67rjxn52tv0t20";
#       })();
#         $(function() {
#     !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#
#     var e = document.createElement('script');
#     e.async = true;
#     e.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.3&appId=138566025676";
#     document.getElementById('fb-root').appendChild(e);
#
#     var po = document.createElement('script');
#     po.type = 'text/javascript';
#     po.async = true;
#     po.src = 'https://apis.google.com/js/plusone.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(po, s);
#
#     e = document.createElement('script');
#     e.async = true;
#     e.src = "//assets.pinterest.com/js/pinit.js";
#     var target = document.getElementsByTagName('script')[0];
#     target.parentNode.insertBefore(e, target);
#
#     var startPage = document.location.toString();
#     var router = window.framedRouter = new Genome.FramedRouter({startPage: startPage});
#     var pushState = !!(window.history && window.history.pushState);
#     var history = Backbone.history.start({pushState: pushState, hashChange: false});
#
#     if (!pushState) {
#       Backbone.history.loadUrl(window.location.pathname);
#     }
#   });
#
#     </script>
# </body>
# </html>
# <!-- ver.  -->
# >

# %%
#Lets find a nice list of neighborhoods to work with
neighborhood_list_raw = soup.find('div', {'class':'neighborhood-list'}).find_all('a')[1:]    # the 0 index is a link to 'all-neighborhoods'
neighborhood_list_raw[:5]
# Out:
# [<a href="/locations/new-york/alphabet-city">Alphabet City</a>,
#  <a href="/locations/new-york/astoria">Astoria</a>,
#  <a href="/locations/new-york/battery-park-city">Battery Park City</a>,
#  <a href="/locations/new-york/bedford-stuyvesant">Bedford-Stuyvesant</a>,
#  <a href="/locations/new-york/boerum-hill">Boerum Hill</a>]

# %%
#Lets extract the data we need from them
neighborhoods = []

for i, hood in enumerate(neighborhood_list_raw):
    hood_name = hood.get_text()
    hood_url = hood['href']
    neighborhoods.append((i, hood_name, hood_url))

hood_df = pd.DataFrame(neighborhoods, columns=["neighborhood_id", "neighborhood", "neighborhood_url"])
hood_df.head()
# Out:
#    neighborhood_id        neighborhood                        neighborhood_url
# 0                0       Alphabet City       /locations/new-york/alphabet-city
# 1                1             Astoria             /locations/new-york/astoria
# 2                2   Battery Park City   /locations/new-york/battery-park-city
# 3                3  Bedford-Stuyvesant  /locations/new-york/bedford-stuyvesant
# 4                4         Boerum Hill         /locations/new-york/boerum-hill

# %% [markdown]
# Using the above code as a template, I was able to create **'scrape_neighborhood_list.py'**
#
# This script is used to grab neighborhoods from cities
# * takes in a file ('../data/city_list.csv')
# * grabs the neighborhoods we wish to scrape from the file
# * scrapes AirBnB's city guide for each of the cities to grab the hoods
#
# Note: In the script, I exported the neighborhodo list to a csv ('../data/neighborhood_list.csv'), as it wasn't large enough to warrent a full database. If I plan to scale this project, a PostgreSQL database would do the trick just fine.

# %% [markdown]
# ###Extracting neighborhoods data from AirBnB's neighborhood guides

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
city_df = pd.read_csv('../data/city_list.csv')
hood_df = pd.read_csv('../data/neighborhood_list.csv')
hood_df.head()
# Out:
#    neighborhood_id    neighborhood                         neighborhood_url  \
# 0                0    Alamo Square    /locations/san-francisco/alamo-square
# 1                1         Bayview         /locations/san-francisco/bayview
# 2                2  Bernal Heights  /locations/san-francisco/bernal-heights
# 3                3       Chinatown       /locations/san-francisco/chinatown
# 4                4    Civic Center    /locations/san-francisco/civic-center
#
#    city_id           city
# 0        1  san-francisco
# 1        1  san-francisco
# 2        1  san-francisco
# 3        1  san-francisco
# 4        1  san-francisco

# %%
#Lets find my old stomping grounds, Carroll Gardens, Brooklyn!
hood_df[hood_df['neighborhood']=="Carroll Gardens"]
# Out:
#     neighborhood_id     neighborhood                     neighborhood_url  \
# 49               49  Carroll Gardens  /locations/new-york/carroll-gardens
#
#     city_id      city
# 49        2  new-york

# %%
# lets scrape an example neighborhood ('https://www.airbnb.com/locations/new-york/carroll-gardens') to see what we're working with
r = requests.get('https://www.airbnb.com/locations/new-york/carroll-gardens')

# %%
soup = BeautifulSoup(r.content)
soup.prettify
# Out:
# <bound method BeautifulSoup.prettify of <!DOCTYPE html>
# <html lang="en" xmlns:fb="http://ogp.me/ns/fb#">
# <head>
# <meta charset="utf-8"/>
# <script>
#   sherlock_firstbyte = Number(new Date());
# </script>
# <title>Carroll Gardens, New York Guide - Airbnb Neighborhoods</title>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"fc09a36731","applicationID":"1024027","transactionName":"dlwMQktaWAgBEB1cVlxUClRWR1wLCwZBHUBdXBU=","queueTime":17,"applicationTime":318,"ttGuid":"","agentToken":null,"agent":"js-agent.newrelic.com/nr-632.min.js"}</script>
# <script type="text/javascript">window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o?o:n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({QJf3ax:[function(e,n){function t(e){function n(n,t,a){e&&e(n,t,a),a||(a={});for(var u=c(n),f=u.length,s=i(a,o,r),p=0;f>p;p++)u[p].apply(s,t);return s}function a(e,n){f[e]=c(e).concat(n)}function c(e){return f[e]||[]}function u(){return t(n)}var f={};return{on:a,emit:n,create:u,listeners:c,_events:f}}function r(){return{}}var o="nr@context",i=e("gos");n.exports=t()},{gos:"7eSDFh"}],ee:[function(e,n){n.exports=e("QJf3ax")},{}],3:[function(e,n){function t(e){return function(){r(e,[(new Date).getTime()].concat(i(arguments)))}}var r=e("handle"),o=e(1),i=e(2);"undefined"==typeof window.newrelic&&(newrelic=window.NREUM);var a=["setPageViewName","addPageAction","setCustomAttribute","finished","addToTrace","inlineHit","noticeError"];o(a,function(e,n){window.NREUM[n]=t("api-"+n)}),n.exports=window.NREUM},{1:12,2:13,handle:"D5DuLP"}],"7eSDFh":[function(e,n){function t(e,n,t){if(r.call(e,n))return e[n];var o=t();if(Object.defineProperty&&Object.keys)try{return Object.defineProperty(e,n,{value:o,writable:!0,enumerable:!1}),o}catch(i){}return e[n]=o,o}var r=Object.prototype.hasOwnProperty;n.exports=t},{}],gos:[function(e,n){n.exports=e("7eSDFh")},{}],handle:[function(e,n){n.exports=e("D5DuLP")},{}],D5DuLP:[function(e,n){function t(e,n,t){return r.listeners(e).length?r.emit(e,n,t):(o[e]||(o[e]=[]),void o[e].push(n))}var r=e("ee").create(),o={};n.exports=t,t.ee=r,r.q=o},{ee:"QJf3ax"}],id:[function(e,n){n.exports=e("XL7HBI")},{}],XL7HBI:[function(e,n){function t(e){var n=typeof e;return!e||"object"!==n&&"function"!==n?-1:e===window?0:i(e,o,function(){return r++})}var r=1,o="nr@id",i=e("gos");n.exports=t},{gos:"7eSDFh"}],G9z0Bl:[function(e,n){function t(){var e=d.info=NREUM.info,n=f.getElementsByTagName("script")[0];if(e&&e.licenseKey&&e.applicationID&&n){c(p,function(n,t){n in e||(e[n]=t)});var t="https"===s.split(":")[0]||e.sslForHttp;d.proto=t?"https://":"http://",a("mark",["onload",i()]);var r=f.createElement("script");r.src=d.proto+e.agent,n.parentNode.insertBefore(r,n)}}function r(){"complete"===f.readyState&&o()}function o(){a("mark",["domContent",i()])}function i(){return(new Date).getTime()}var a=e("handle"),c=e(1),u=(e(2),window),f=u.document,s=(""+location).split("?")[0],p={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",agent:"js-agent.newrelic.com/nr-632.min.js"},d=n.exports={offset:i(),origin:s,features:{}};f.addEventListener?(f.addEventListener("DOMContentLoaded",o,!1),u.addEventListener("load",t,!1)):(f.attachEvent("onreadystatechange",r),u.attachEvent("onload",t)),a("mark",["firstbyte",i()])},{1:12,2:3,handle:"D5DuLP"}],loader:[function(e,n){n.exports=e("G9z0Bl")},{}],12:[function(e,n){function t(e,n){var t=[],o="",i=0;for(o in e)r.call(e,o)&&(t[i]=n(o,e[o]),i+=1);return t}var r=Object.prototype.hasOwnProperty;n.exports=t},{}],13:[function(e,n){function t(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,o=t-n||0,i=Array(0>o?0:o);++r<o;)i[r]=e[n+r];return i}n.exports=t},{}]},{},["G9z0Bl"]);</script>
# <link href="https://www.airbnb.com/locations/new-york/carroll-gardens" rel="canonical"/>
# <link href="https://www.airbnb.com/locations/new-york/carroll-gardens" hreflang="en" rel="alternate"/>
# <link href="https://www.airbnb.co.uk/locations/new-york/carroll-gardens" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.airbnb.com.sg/locations/new-york/carroll-gardens" hreflang="en-SG" rel="alternate"/>
# <link href="https://www.airbnb.com.au/locations/new-york/carroll-gardens" hreflang="en-AU" rel="alternate"/>
# <link href="https://www.airbnb.co.nz/locations/new-york/carroll-gardens" hreflang="en-NZ" rel="alternate"/>
# <link href="https://www.airbnb.ca/locations/new-york/carroll-gardens" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.airbnb.ie/locations/new-york/carroll-gardens" hreflang="en-IE" rel="alternate"/>
# <meta content="Carroll Gardens has established itself as a Brooklyn favorite. Although flush with hip bars, boutiques, and restaurants, this neighborhood has never lost its old-NYC mystique. Quintessential brownstones line tree-trimmed sidewalks and local retailers and Italian eateries populate its cheerful main street. For a stroll or a stay, Carroll Gardens promises a healthy dose of Brooklyn's cool candor." name="description"/>
# <meta content="138566025676" property="fb:app_id"/>
# <meta content="Airbnb" property="og:site_name"/>
# <meta content="place" property="og:type"/>
# <meta content="https://a0.muscache.com/locations/uploads/neighborhood/hero/1257/USA_NYC_CARROLGARDENS_0217_JBK.jpg" property="image"/>
# <meta content="https://a2.muscache.com/locations/uploads/neighborhood/hero/1257/0_4200_0_2800_tile_USA_NYC_CARROLGARDENS_0217_JBK.jpg" property="og:image"/>
# <meta content="Carroll Gardens has established itself as a Brooklyn favorite. Although flush with hip bars, boutiques, and restaurants, this neighborhood has neve..." property="og:description"/>
# <meta content="40.6800542773292" property="place:location:latitude"/>
# <meta content="-73.9972475763005" property="place:location:longitude"/>
# <meta content="https://www.airbnb.com/locations/new-york/carroll-gardens" property="og:url"/>
# <meta content="Carroll Gardens, New York Guide - Airbnb Neighborhoods" property="og:title"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="UoV5ZTSUiHSAmY1uJJPO81z1h5QsvtzeQSd0IN3EqUA=" name="csrf-token"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#       <script src="https://a2.muscache.com/airbnb/nabelove/locations/assets-pretzel/html5shiv-28192591f66ca0d346cc395bc6159593.js" type="text/javascript"></script>
#       <style type="text/css">
#         .svg {
#           display: none !important;
#         }
#       </style>
#     <![endif]-->
# <!--[if lte IE 9]>
#       <link href="https://a1.muscache.com/airbnb/nabelove/locations/assets-pretzel/ie-40380616ba9fc401419189cdd9f46ab2.css" media="all" rel="stylesheet" type="text/css" />
#     <![endif]-->
# <meta content="width=1000,maximum-scale=1.0" name="viewport"/>
# <link href="https://a1.muscache.com/airbnb/nabelove/locations/assets-pretzel/airbnb_logo.png" rel="image_src"/>
# <link href="/opensearch.xml" rel="search" title="Airbnb" type="application/opensearchdescription+xml"/>
# <link href="https://a2.muscache.com/airbnb/nabelove/locations/assets-pretzel/application-019cf366f6762dfecb6f98ced96ecf94.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://a1.muscache.com/airbnb/nabelove/locations/assets-pretzel/genome/neighborhoods-97abdfc6e23cc2cdee80c7550c4d85e5.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# </head>
# <body class=" en" id="neighborhoods_show_page">
# <div id="fb-root"></div>
# <div class="navbar navbar-top clearfix" id="header">
# <div class="navbar-inner">
# <div class="container container-full-width page-container page-container-responsive navbar-container">
# <a class="brand airbnb" href="/">
# <img height="32" src="https://a1.muscache.com/airbnb/nabelove/locations/assets-pretzel/header/logo3-07d13112bba070dbdad538156b307fcf.png" width="102"/>
# </a>
# <ul class="nav">
# <li id="header-search">
# <form action="/s" id="search-form">
# <div id="search-bar">
# <i class="icon icon-search"></i>
# <input autocomplete="off" id="header-location" name="location" placeholder="Where are you going?" type="text"/>
# </div>
# <div id="header-search-settings">
# <label class="checkin">Check in <input class="checkin" id="header-search-checkin" name="checkin" placeholder="mm/dd/yyyy" type="text"/></label>
# <label class="checkout">Check out <input class="checkout" id="header-search-checkout" name="checkout" placeholder="mm/dd/yyyy" type="text"/></label>
# <label class="guests">Guests
#                  <select id="header-search-guests" name="guests">
# <option value="1">1</option><option value="2">2</option><option value="3">3</option><option value="4">4</option><option value="5">5</option><option value="6">6</option><option value="7">7</option><option value="8">8</option><option value="9">9</option><option value="10">10</option><option value="11">11</option><option value="12">12</option><option value="13">13</option><option value="14">14</option><option value="15">15</option><option value="16">16</option>
# </select>
# </label>
# <label>Room type</label>
# <label class="checkbox" for="room_type_0"><input id="room_type_0" name="room_types[]" type="checkbox" value="Entire home/apt"/> Entire home/apt</label>
# <label class="checkbox" for="room_type_1"><input id="room_type_1" name="room_types[]" type="checkbox" value="Private room"/> Private room</label>
# <label class="checkbox" for="room_type_2"><input id="room_type_2" name="room_types[]" type="checkbox" value="Shared room"/> Shared room</label>
# <button class="btn blue" type="submit"><i class="icon icon-search"></i> Find a place</button>
# </div>
# </form>
# </li>
# <li class="dropdown item_explore">
# <a class="dropdown-toggle" href="javascript:void(0)"> Browse <b class="caret"></b></a>
# <ul class="dropdown-menu dropdown-bordered">
# <li><a href="/locations"><i class="icon icon-neighborhoods"></i> Neighborhoods</a></li>
# <li><a href="/wishlists/popular"><i class="icon icon-fire"></i> Popular</a></li>
# </ul>
# </li>
# </ul>
# <ul class="nav pull-right help-menu" style="margin-left:0;">
# <li class="dropdown">
# <a class="dropdown-toggle help-toggle" href="javascript:void(0)"> Help <b class="caret"></b></a>
# <ul class="dropdown-menu help-dropdown dropdown-bordered">
# <li class="nav-header"><a class="lighter small unstyled help-center-link hidden" href="/help">Visit the Help Center »</a></li>
# <li class="loading"></li>
# <li class="hidden mt10"><a class="" href="/trust">Visit our Trust &amp; Safety Center</a></li>
# <li class="all_faqs hidden"><a href="/help/topic/hosting">See all FAQs</a></li>
# </ul>
# </li>
# <li class="list-your-space"><a class="yellow btn" href="/rooms/new" id="list-your-space">List your space</a></li>
# </ul>
# <ul class="nav pull-right logged-out">
# <li id="sign_up"><a href="/signup_login" rel="nofollow">Sign Up</a>
# </li><li id="login"><a href="/login" rel="nofollow">Log In</a>
# </li></ul>
# <ul class="nav pull-right logged-in">
# <li class="dropdown user-item">
# <a class="dropdown-toggle" href="javascript:void(0)">
# <div class="mini-media-box user-profile-image"><img height="20" id="header-profile-image" src="" width="20"/></div> <span class="value_name">User</span> <b class="caret"></b>
# </a>
# <ul class="dropdown-menu dropdown-bordered">
# <li><a class="no-crawl" data-href="/home/dashboard" href="#">Dashboard</a>
# </li><li>
# <a class="no-crawl" data-href="/rooms" href="#">
# <span class="singular" style="display: none;">Your Listing</span>
# <span class="plural">Your Listings</span>
# </a>
# </li>
# <li><a class="no-crawl" data-href="/trips/upcoming" href="#">Your Trips</a>
# </li><li><a class="no-crawl" data-href="/wishlists/my" href="#" id="wishlists">Wish Lists</a>
# </li><li><a class="no-crawl" data-href="/users/edit" href="#">Edit Profile</a>
# </li><li><a class="no-crawl" data-href="/account" href="#">Account</a>
# </li><li><a class="no-crawl" data-href="/logout" href="#" id="header-logout">Log Out</a></li>
# </ul>
# </li>
# <li class="divider-vertical"></li>
# <li id="inbox-item">
# <a class="no-crawl" data-href="/inbox" href="#"><i class="icon icon-envelope"><span class="text-hide">Inbox</span></i><i class="alert-count position-super fade">0</i></a>
# </li>
# <li class="divider-vertical"></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="cities-wrapper">
# <div class="navbar navbar-black" id="sticky_nav">
# <div class="navbar-inner clearfix">
# <div id="neighborhood_cart"></div>
# <ul class="nav" id="neighborhood_nav" itemprop="breadcrumb">
# <li itemscope="" itemtype="http://www.data-vocabulary.org/Breadcrumb/">
# <a href="/locations" itemprop="url">
# <span itemprop="title">Cities
#                 <i class="icon icon-chevron-right"></i>
# </span>
# </a>
# </li>
# <li itemscope="" itemtype="http://www.data-vocabulary.org/Breadcrumb/">
# <a href="/locations/new-york" itemprop="url">
# <span itemprop="title">New York
#                 <i class="icon icon-chevron-right"></i>
# </span>
# </a>
# </li>
# <li>
# <a href="#"><span>Carroll Gardens</span></a>
# </li>
# </ul>
# <ul class="nav saved">
# <li class="see-neighborhood-listings">
# <a href="/s/New-York?neighborhoods%5B%5D=Carroll+Gardens" target="_blank">
# <span>
#               See all places to stay here
#             </span>
# </a> </li>
# <li>
# </li><li>
# <a href="#">
# <span class="message">
#                 Saved neighborhoods
#               </span> <span class="pip neighborhood-count">0</span>
# </a>
# <div class="flyout"></div>
# </li>
# </ul>
# </div>
# </div>
# <div class="neighborhood-page page" data-id="1257" id="neighborhood">
# <div class="hero img-overlay" style="background-image: url('https://a1.muscache.com/locations/uploads/neighborhood/hero/1257/25_4186_0_1809_hero_USA_NYC_CARROLGARDENS_0217_JBK.jpg');">
# <div class="overlay">
# <div class="title">
# <div class="container center">
# <h1 class="circularbold">Carroll Gardens</h1>
# <div class="center description">
#               Carroll Gardens' brownstones, boutiques, and brunch spots are equal parts cool, calm, and collected.
#             </div>
# <div class="container" id="neighborhood_traits">
# <ul class="traits">
# <li><a class="large gray btn" href="/locations/new-york/neighborhoods?tags[]=13"><span class="name">Peace &amp; Quiet</span></a></li>
# <li><a class="large gray btn" href="/locations/new-york/neighborhoods?tags[]=5"><span class="name">Nightlife</span></a></li>
# <li><a class="large gray btn" href="/locations/new-york/neighborhoods?tags[]=3"><span class="name">Dining</span></a></li>
# <li><a class="large gray btn" href="/locations/new-york/neighborhoods?tags[]=66"><span class="name">Loved by New Yorkers</span></a></li>
# <li><a class="large gray btn" href="/locations/new-york/neighborhoods?tags[]=12"><span class="name">Great Transit</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="content">
# <div class="section">
# <div class="container">
# <div class="row main">
# <div class="span8">
# <p class="lede">Carroll Gardens has established itself as a Brooklyn favorite. Although flush with hip bars, boutiques, and restaurants, this neighborhood has never lost its old-NYC mystique. Quintessential brownstones line tree-trimmed sidewalks and local retailers and Italian eateries populate its cheerful main street. For a stroll or a stay, Carroll Gardens promises a healthy dose of Brooklyn's cool candor.</p>
# <a class="btn" href="/s/New-York?neighborhoods%5B%5D=Carroll+Gardens" id="listings_button" target="_blank">
#               See places to stay
#             </a>
# <a class="cta save-neighborhood-cta" data-city-id="22" data-city-name="New York" data-city-permalink="new-york" data-neighborhood-id="new-york/carroll-gardens" data-neighborhood-name="Carroll Gardens" data-neighborhood-url="http://www.airbnb.com/locations/new-york/carroll-gardens" href="#">Save this neighborhood</a>
# </div>
# <div class="span4 sidebar">
# <ul class="share-box">
# <li class="share-item">
# <a class="twitter-share-button" data-count="none" href="http://twitter.com/share?text=Love+the+Carroll+Gardens+neighborhood+page+on+%40airbnb&amp;url=https%3A%2F%2Fwww.airbnb.com%2Flocations%2Fnew-york%2Fcarroll-gardens&amp;related=airbnb" rel="nofollow" target="_blank">Tweet</a>
# </li>
# <li class="share-item">
# <a class="pin-it-button" count-layout="none" data-pin-do="buttonBookmark" href="//pinterest.com/pin/create/button/?description=Love+the+Carroll+Gardens+neighborhood+page+on+Airbnb.com" rel="nofollow" target="_blank">
# <img alt="Pin It" src="https://a1.muscache.com/airbnb/nabelove/locations/assets-pretzel/icons/pin-it-7fce68c288a40aafeb695eb15f40aa64.png" title="Pin It"/>
# </a>
# </li>
# <li class="share-item">
# <div class="g-plusone" data-annotation="none" data-href="https://www.airbnb.com/locations/new-york/carroll-gardens" data-size="medium">
# </div>
# </li>
# <li class="share-item">
# <div class="fb-like" data-action="like" data-href="https://www.airbnb.com/locations/new-york/carroll-gardens" data-layout="button_count" data-share="false" data-show-faces="false"></div>
# </li>
# </ul>
# <div class="friends" style="display:none;">
# <h4>Your friends here</h4>
# <ul class="facepile">
# </ul>
# </div>
# <h4>The community says:</h4>
# <div class="neighborhood-tags clearfix">
# <div class="neighborhood-tag">sought-after
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">beautiful
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">quiet
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">trendy
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">family friendly
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">foodie
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">front gardens
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">hipsters
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">historic
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">professional
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">italian-american
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">calm
# </div>
# </div>
# <div class="add">
# <div class="js-feedback-adder" data-object-id="tag-neighborhood-1257" data-object-type="tag"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section">
# <div class="container">
# <h2 class="circularbold">On the Map</h2>
# <p class="lede center">
#           Carroll Gardens is within <a href="/locations/neighborhoods/3795">Brooklyn</a> and bordered by <a href="/locations/neighborhoods/1260">Cobble Hill</a>, <a href="/locations/neighborhoods/1304">Columbia Street Waterfront</a>, <a href="/locations/neighborhoods/1213">Boerum Hill</a>, <a href="/locations/neighborhoods/1298">Gowanus</a>, <a href="/locations/neighborhoods/1347">Greenwood Heights</a>, and <a href="/locations/neighborhoods/1301">Red Hook</a>
# </p>
# <div id="neighborhood_map">
# <div data-bbox="[[40.672059160796316,-74.00372818474148],[40.685654529334656,-73.98959548275297]]" data-x="-73.9972475763005" data-y="40.6800542773292" id="inner-map"></div>
# <div class="caption bar">
# <div class="primary">
# <p>LaGuardia Airport: 20 minutes by cab without traffic<br/>JFK Airport: 30 minutes by cab without traffic<br/>Times Square: 31 minutes by subway<br/>Wall Street / Financial District: 17 minutes by subway</p>
# </div>
# <ul class="secondary">
# <li class="easy"><i class="icon icon-ok-circle"></i>
#                       Public transit is <strong>Easy</strong>
# </li>
# <li class="possible"><i class="icon icon-ok-circle"></i>
#                       Having a car is <strong>Possible</strong>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="section section-offset">
# <div class="container">
# <section>
# <h2>Carroll Gardens: Italian Comforts in a Stylish Place to Dwell</h2>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="ny black gold records jbk0169" class="feature" data-lazy="https://a1.muscache.com/locations/uploads/photo/image/551/0_4200_0_2800_one_ny-black-gold-records-jbk0169.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# <div class="primary">
# <p>A touch trendier than its neighbors, Boerum Hill and Cobble Hill, Carroll Gardens' brownstones, boutiques, and butcher shops lend the neighborhood a hip feel and an Italian flavor.</p>
# </div>
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span4">
# <img alt="carroll gardens boutique jbk0161" class="feature" data-lazy="https://a1.muscache.com/locations/uploads/photo/image/546/558_3642_0_2800_three_carroll-gardens-boutique-jbk0161.jpg" height="286" width="315"/>
# </div>
# <div class="span4">
# <img alt="nyc brownstones jbk0080" class="feature" data-lazy="https://a0.muscache.com/locations/uploads/photo/image/301/558_3642_0_2800_three_nyc-brownstones-jbk0080.jpg" height="286" width="315"/>
# </div>
# <div class="span4">
# <img alt="frankies brooklyn jbk0164" class="feature" data-lazy="https://a1.muscache.com/locations/uploads/photo/image/545/558_3642_0_2800_three_frankies-457-brooklyn-jbk0164.jpg" height="286" width="315"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="us flag carroll gardens residential jbk0177" class="feature" data-lazy="https://a1.muscache.com/locations/uploads/photo/image/1573/0_4200_0_2800_one_us-flag-carroll-gardens-residential-jbk0177.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="nyc smith union market jbk0086" class="feature" data-lazy="https://a0.muscache.com/locations/uploads/photo/image/295/0_4200_0_2800_one_nyc-smith-union-market-jbk0086.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# </section>
# <section>
# <div class="quote row">
# <div class="span8">
# <blockquote>Experience the charm of Carroll Gardens, Brooklyn! A traditionally Italian-American neighborhood, it is now dotted with lovely boutiques, shops and cafes, and yet has retained many of its long-standing family run businesses."</blockquote>
# </div>
# <div class="span4">
# <div class="row-fluid">
# <div class="span4 profile-image">
# <img alt="Pixel" data-lazy="https://a1.muscache.com/users/2423269/profile_pic/1357687515/square_225.jpg" height="80" src="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/pixel-e441e078c1979277c580cbd031cb8e83.png" width="80"/>
# </div>
# <div class="span8">
# <cite>
# <h3 class="circularbold">Amy</h3>
# <p>Hosts <a href="/rooms/638380">Historic Carroll Gardens 2 Bedroom</a></p>
# </cite>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section>
# <h2>Distinctive Dining and Hand-Crafted Drinks at Brooklyn's Finest</h2>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="ciros on smith brooklyn jbk0092" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/306/0_4200_0_2800_one_ciros-on-smith-brooklyn-jbk0092.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# <div class="primary">
# <p>Carroll Gardens's popular restaurants, pizzerias, and cafes lure you to gather for a meal with friends.</p>
# </div>
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="nyc abilene outdoor seating jbk0142" class="feature" data-lazy="https://a0.muscache.com/locations/uploads/photo/image/305/0_4200_0_2800_one_nyc-abilene-outdoor-seating-jbk0142.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span6">
# <img alt="buschenschank nyc jbk0055" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/1540/0_4200_84_2716_two_buschenschank-nyc-jbk0055.jpg" height="304" width="485"/>
# </div>
# <div class="span6">
# <img alt="buschenschank brooklyn beer sausage jbk0059" class="feature" data-lazy="https://a1.muscache.com/locations/uploads/photo/image/550/0_4200_84_2716_two_buschenschank-brooklyn-beer-sausage-jbk0059.jpg" height="304" width="485"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="staubitz market ny jbk0019" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/308/0_4200_0_2800_one_staubitz-market-ny-jbk0019.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="brooklyn mastellone italian deli jbk0043" class="feature" data-lazy="https://a0.muscache.com/locations/uploads/photo/image/549/0_4200_0_2800_one_brooklyn-mastellone-italian-deli-jbk0043.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="sams restaurant italian cuisine jbk0027" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/307/0_4200_0_2800_one_sams-restaurant-italian-cuisine-jbk0027.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# </section>
# <section>
# <div class="quote row">
# <div class="span8">
# <blockquote>The neighborhood is family-oriented with several schools and playgrounds close by; there is also a neighborhood pool not too far. Fortunately, Carroll Gardens does not sacrifice its nightlife and social scene for its homely family vibe. Smith Street and Court Street have plenty of restaurants, coffee shops, bars, and shopping to choose from."</blockquote>
# </div>
# <div class="span4">
# <div class="row-fluid">
# <div class="span4 profile-image">
# <img alt="Pixel" data-lazy="https://a2.muscache.com/users/5611897/profile_pic/1364350973/square_225.jpg" height="80" src="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/pixel-e441e078c1979277c580cbd031cb8e83.png" width="80"/>
# </div>
# <div class="span8">
# <cite>
# <h3 class="circularbold">Maggie</h3>
# <p>Visited in 2013</p>
# </cite>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section>
# <h2>Recreational Therapy in NYC</h2>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="brooklyn bikers jbk0073" class="feature" data-lazy="https://a0.muscache.com/locations/uploads/photo/image/314/0_4200_0_2800_one_brooklyn-bikers-jbk0073.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# <div class="primary">
# <p>Although the neighborhood is undeniably urban, Carroll Gardens embraces the great outdoors.</p>
# </div>
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span6">
# <img alt="little boy biking carroll gardens jbk0034" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/315/0_4200_84_2716_two_little-boy-biking-carroll-gardens-jbk0034.jpg" height="304" width="485"/>
# </div>
# <div class="span6">
# <img alt="nyc squirrel jbk0101" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/311/0_4200_84_2716_two_nyc-squirrel-jbk0101.jpg" height="304" width="485"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="family friendly basketball court carroll gardens jbk0123" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/554/0_4200_0_2800_one_family-friendly-basketball-court-carroll-gardens-jbk0123.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span6">
# <img alt="carroll gardens pick up basketball jbk0127" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/309/0_4200_84_2716_two_carroll-gardens-pick-up-basketball-jbk0127.jpg" height="304" width="485"/>
# </div>
# <div class="span6">
# <img alt="brooklyn park childrens scooter jbk0120" class="feature" data-lazy="https://a0.muscache.com/locations/uploads/photo/image/555/0_4200_84_2716_two_brooklyn-park-childrens-scooter-jbk0120.jpg" height="304" width="485"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="carroll gardens foot bridge jbk0226" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/552/0_4200_0_2800_one_carroll-gardens-foot-bridge-jbk0226.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# <div class="primary">
# <p>By foot or by bike, it's easy to get around in Carroll Gardens.</p>
# </div>
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="parked bicycles brooklyn jbk0217" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/1556/0_4200_0_2800_one_parked-bicycles-brooklyn-jbk0217.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span6">
# <img alt="carroll gardens children swinging playground jbk0113" class="feature" data-lazy="https://a1.muscache.com/locations/uploads/photo/image/1546/0_4200_84_2716_two_carroll-gardens-children-swinging-playground-jbk0113.jpg" height="304" width="485"/>
# </div>
# <div class="span6">
# <img alt="brooklyn sidewalk couple kissing jbk0076" class="feature" data-lazy="https://a0.muscache.com/locations/uploads/photo/image/1544/0_4200_84_2716_two_brooklyn-sidewalk-couple-kissing-jbk0076.jpg" height="304" width="485"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# </section>
# <section>
# <h2>Carroll Gardens' Residential Calm</h2>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="carroll gardens tree lined streets jbk0071" class="feature" data-lazy="https://a0.muscache.com/locations/uploads/photo/image/1543/0_4200_0_2800_one_carroll-gardens-tree-lined-streets-jbk0071.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# <div class="primary">
# <p>People treat Carroll Gardens like the neighborhood it is. It's quite possible that you'll hear friendly chatter rather than honking horns.</p>
# </div>
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="brooklyn cross walk pedestrians jbk0096" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/1545/0_4200_0_2800_one_brooklyn-cross-walk-pedestrians-jbk0096.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span6">
# <img alt="carroll gardens quiet intersection jbk0151" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/1549/0_4200_84_2716_two_carroll-gardens-quiet-intersection-jbk0151.jpg" height="304" width="485"/>
# </div>
# <div class="span6">
# <img alt="nyc flying bird jbk0198" class="feature" data-lazy="https://a1.muscache.com/locations/uploads/photo/image/1560/0_4200_84_2716_two_nyc-flying-bird-jbk0198.jpg" height="304" width="485"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="carroll gardens quiet residential street jbk0143" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/1548/0_4200_0_2800_one_carroll-gardens-quiet-residential-street-jbk0143.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span6">
# <img alt="brooklyn home jbk0147" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/1547/0_4200_84_2716_two_brooklyn-home-jbk0147.jpg" height="304" width="485"/>
# </div>
# <div class="span6">
# <img alt="carroll gardens row homes stoops jbk0182" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/1551/0_4200_84_2716_two_carroll-gardens-row-homes-stoops-jbk0182.jpg" height="304" width="485"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# <div>
# <div class="row-fluid">
# <div class="span12">
# <img alt="father daughter sidewalk jbk0190" class="feature" data-lazy="https://a2.muscache.com/locations/uploads/photo/image/1553/0_4200_0_2800_one_father-daughter-sidewalk-jbk0190.jpg" height="663" width="995"/>
# </div>
# </div>
# <div class="center caption">
# </div>
# </div>
# </section>
# </div>
# </div>
# <div class="section">
# <div class="container">
# <h2>Photography</h2>
# <p class="lede center">Airbnb works with local photographers to capture the spirit of neighborhoods all around the world. The photography on this page includes work by:</p>
# <div class="quote row photographer">
# <div class="span2">
# <a href="/users/show/1370951">
# <img alt="Pixel" class="avatar" data-lazy="https://a2.muscache.com/locations/uploads/photographer/avatar/1/profile_Jacob-Headshot-1.jpg" height="80" src="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/pixel-e441e078c1979277c580cbd031cb8e83.png" width="80"/>
# </a> </div>
# <div class="span3">
# <cite>
# <h3 class="circularbold">Jacob Krupnick</h3>
# <p>
# <a href="http://www.jacobkrupnick.com/" target="_blank">View website</a></p>
# </cite>
# </div>
# <div class="span7">
# <blockquote>Jacob Krupnick is a director and photographer from Brooklyn.  In 2011, he released the feature-length dance film "Girl Walk // All Day", a non-stop music video shot entirely in the streets of NYC. Since then, he’s spent his time creating one-of-a-kind, immersive screening experiences all over the world. Shooting for Airbnb was a great excuse for Jacob to wander the city with a camera in hand, thinking about what best defines the feel of a neighborhood.</blockquote>
# </div>
# </div>
# </div> <!--// end photographers container -->
# </div>
# <div class="section section-offset">
# <div class="container">
# <h2>Popular Places to Stay</h2>
# <div class="row">
# <div class="span12 jumbo featured-listing">
# <a href="/rooms/638380">
# <img alt="Historic Carroll Gardens 2 Bedroom" data-lazy="https://a1.muscache.com/pictures/9075101/x_large.jpg" height="664" src="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/pixel-e441e078c1979277c580cbd031cb8e83.png" width="995"/>
# </a>
# <img alt="Pixel" class="profile-pic" data-lazy="https://a1.muscache.com/users/2423269/profile_pic/1357687515/small.jpg" height="50" src="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/pixel-e441e078c1979277c580cbd031cb8e83.png" width="50"/>
# <div class="localized-price" data-id="638380">0.0</div>
# <div class="cite">
# <p>
# <a href="/rooms/638380">Historic Carroll Gardens 2 Bedroom</a>
# <small>
#               By Amy
#             </small>
# </p>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="span6 jumbo featured-listing">
# <a href="/rooms/749362">
# <img alt="Red-Brick Brooklyn Bungalow 2" data-lazy="https://a2.muscache.com/pictures/11995330/large.jpg" height="323" src="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/pixel-e441e078c1979277c580cbd031cb8e83.png" width="485"/>
# </a>
# <img alt="Pixel" class="profile-pic" data-lazy="https://a0.muscache.com/users/2776635/profile_pic/1340938650/small.jpg" height="50" src="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/pixel-e441e078c1979277c580cbd031cb8e83.png" width="50"/>
# <div class="localized-price" data-id="749362">0.0</div>
# <div class="cite">
# <p>
# <a href="/rooms/749362">Red-Brick Brooklyn Bungalow 2</a>
# <small>
#               By Manisha
#             </small>
# </p>
# </div>
# </div>
# <div class="span6 jumbo featured-listing">
# <a href="/rooms/301801">
# <img alt="Beautiful apartment ON Smith Street" data-lazy="https://a2.muscache.com/pictures/3564670/large.jpg" height="323" src="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/pixel-e441e078c1979277c580cbd031cb8e83.png" width="485"/>
# </a>
# <img alt="Pixel" class="profile-pic" data-lazy="https://a1.muscache.com/users/1554689/profile_pic/1368979723/small.jpg" height="50" src="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/pixel-e441e078c1979277c580cbd031cb8e83.png" width="50"/>
# <div class="localized-price" data-id="301801">0.0</div>
# <div class="cite">
# <p>
# <a href="/rooms/301801">Beautiful apartment ON Smith Street</a>
# <small>
#               By julia
#             </small>
# </p>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="span6 jumbo featured-listing">
# <a href="/rooms/876983">
# <img alt="Beautiful Brooklyn Brownstone " data-lazy="https://a1.muscache.com/pictures/12765621/large.jpg" height="323" src="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/pixel-e441e078c1979277c580cbd031cb8e83.png" width="485"/>
# </a>
# <img alt="Pixel" class="profile-pic" data-lazy="https://a0.muscache.com/users/4632229/profile_pic/1357677846/small.jpg" height="50" src="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/pixel-e441e078c1979277c580cbd031cb8e83.png" width="50"/>
# <div class="localized-price" data-id="876983">0.0</div>
# <div class="cite">
# <p>
# <a href="/rooms/876983">Beautiful Brooklyn Brownstone </a>
# <small>
#               By Megan
#             </small>
# </p>
# </div>
# </div>
# <div class="span6 jumbo featured-listing">
# <a href="/rooms/287845">
# <img alt="Carroll Gardens Gem  -new 2 BR apt " data-lazy="https://a2.muscache.com/pictures/3106986/large.jpg" height="323" src="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/pixel-e441e078c1979277c580cbd031cb8e83.png" width="485"/>
# </a>
# <img alt="Pixel" class="profile-pic" data-lazy="https://a2.muscache.com/users/1496847/profile_pic/1323704656/small.jpg" height="50" src="https://a0.muscache.com/airbnb/nabelove/locations/assets-pretzel/pixel-e441e078c1979277c580cbd031cb8e83.png" width="50"/>
# <div class="localized-price" data-id="287845">0.0</div>
# <div class="cite">
# <p>
# <a href="/rooms/287845">Carroll Gardens Gem  -new 2 BR apt </a>
# <small>
#               By Paul &amp; Ewa
#             </small>
# </p>
# </div>
# </div>
# </div>
# <a class="btn" href="/s/New-York?neighborhoods%5B%5D=Carroll+Gardens" id="listings_button" target="_blank">
#             See places to stay
#           </a>
# <a class="cta save-neighborhood-cta" data-city-id="22" data-city-name="New York" data-city-permalink="new-york" data-neighborhood-id="new-york/carroll-gardens" data-neighborhood-name="Carroll Gardens" data-neighborhood-url="http://www.airbnb.com/locations/new-york/carroll-gardens" href="#">Save this neighborhood</a>
# </div>
# </div>
# <div class="section">
# <div class="container">
# <section>
# <h2>Similar to Carroll Gardens</h2>
# <ul class="trait-neighborhoods neighborhoods">
# <li class="trait-tile tile " data-neighborhood-id="1262" data-neighborhood-permalink="park-slope" style="">
# <a href="/locations/new-york/park-slope">
# <div class="beveled-media-box img-overlay" style="background-image:url('https://a2.muscache.com/locations/uploads/neighborhood/hero/1262/0_5616_0_3744_tile_SusieCushner_New_York_Brooklyn_Slope_Side_162.jpg');">
# <div class="center panel-padding">
# <h2>Park Slope</h2>
# <p>Well-behaved children and immaculate park spaces.</p>
# </div>
# </div>
# <div class="blurb">
# <div class="panel-padding center clearfix neighborhood-tags">
# <div class="neighborhood-tag">strollers
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">brownstone
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">family-friendly
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">lesbian friendly
# </div>
# </div>
# </div>
# <div class="sub friends" style="display: none;">
# <ul>
# </ul>
# <p>
# </p>
# </div>
# </a>
# </li>
# <li class="trait-tile tile " data-neighborhood-id="1260" data-neighborhood-permalink="cobble-hill" style="">
# <a href="/locations/new-york/cobble-hill">
# <div class="beveled-media-box img-overlay" style="background-image:url('https://a2.muscache.com/locations/uploads/neighborhood/hero/1260/0_4200_0_2800_tile_USA_NYC_COBBLEHILL_0419_JBK.jpg');">
# <div class="center panel-padding">
# <h2>Cobble Hill</h2>
# <p>Cute shops and cuter babies.</p>
# </div>
# </div>
# <div class="blurb">
# <div class="panel-padding center clearfix neighborhood-tags">
# <div class="neighborhood-tag">families
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">restaurants/bars
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">italian
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">court st.
# </div>
# </div>
# </div>
# <div class="sub friends" style="display: none;">
# <ul>
# </ul>
# <p>
# </p>
# </div>
# </a>
# </li>
# <li class="trait-tile tile " data-neighborhood-id="1213" data-neighborhood-permalink="boerum-hill" style="">
# <a href="/locations/new-york/boerum-hill">
# <div class="beveled-media-box img-overlay" style="background-image:url('https://a1.muscache.com/locations/uploads/neighborhood/hero/1213/0_4200_0_2800_tile_USA_NYC_BOERUMHILL_0042_JBK.jpg');">
# <div class="center panel-padding">
# <h2>Boerum Hill</h2>
# <p>A well-balanced Brooklyn neighborhood.</p>
# </div>
# </div>
# <div class="blurb">
# <div class="panel-padding center clearfix neighborhood-tags">
# <div class="neighborhood-tag">family friendly
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">quaint
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">strategically located
#     <div class="dot"></div>
# </div>
# <div class="neighborhood-tag">vibrant
# </div>
# </div>
# </div>
# <div class="sub friends" style="display: none;">
# <ul>
# </ul>
# <p>
# </p>
# </div>
# </a>
# </li>
# </ul>
# </section>
# </div>
# </div>
# <div class="section section-offset">
# <div class="container">
# <div class="js-feedback-adder" data-object-id="Neighborhood-1257-page"></div>
# </div>
# </div>
# <div class="neighborhood-list section section-offset">
# <div class="container">
# <div class="row">
# <div class="span12">
# <h2 class="circularbold">All Neighborhoods</h2>
# </div>
# </div>
# <div class="row">
# <a name="all-neighborhoods"></a>
# <div class="span3">
# <ul>
# <li><a href="/locations/new-york/alphabet-city">Alphabet City</a></li>
# <li><a href="/locations/new-york/astoria">Astoria</a></li>
# <li><a href="/locations/new-york/battery-park-city">Battery Park City</a></li>
# <li><a href="/locations/new-york/bedford-stuyvesant">Bedford-Stuyvesant</a></li>
# <li><a href="/locations/new-york/boerum-hill">Boerum Hill</a></li>
# <li><a href="/locations/new-york/brooklyn-heights">Brooklyn Heights</a></li>
# <li><a href="/locations/new-york/bushwick">Bushwick</a></li>
# <li><a href="/locations/new-york/carroll-gardens">Carroll Gardens</a></li>
# <li><a href="/locations/new-york/chelsea">Chelsea</a></li>
# <li><a href="/locations/new-york/chinatown">Chinatown</a></li>
# <li><a href="/locations/new-york/civic-center">Civic Center</a></li>
# <li><a href="/locations/new-york/clinton-hill">Clinton Hill</a></li>
# <li><a href="/locations/new-york/cobble-hill">Cobble Hill</a></li>
# <li><a href="/locations/new-york/crown-heights">Crown Heights</a></li>
# <li><a href="/locations/new-york/downtown-brooklyn">Downtown Brooklyn</a></li>
# </ul>
# </div>
# <div class="span3">
# <ul>
# <li><a href="/locations/new-york/dumbo">DUMBO</a></li>
# <li><a href="/locations/new-york/east-harlem">East Harlem</a></li>
# <li><a href="/locations/new-york/east-village">East Village</a></li>
# <li><a href="/locations/new-york/financial-district">Financial District</a></li>
# <li><a href="/locations/new-york/flatbush">Flatbush</a></li>
# <li><a href="/locations/new-york/flatiron-district">Flatiron District</a></li>
# <li><a href="/locations/new-york/flushing">Flushing</a></li>
# <li><a href="/locations/new-york/fort-greene">Fort Greene</a></li>
# <li><a href="/locations/new-york/gowanus">Gowanus</a></li>
# <li><a href="/locations/new-york/gramercy-park">Gramercy Park</a></li>
# <li><a href="/locations/new-york/greenpoint">Greenpoint</a></li>
# <li><a href="/locations/new-york/greenwich-village">Greenwich Village</a></li>
# <li><a href="/locations/new-york/harlem">Harlem</a></li>
# <li><a href="/locations/new-york/hell-s-kitchen">Hell's Kitchen</a></li>
# <li><a href="/locations/new-york/hudson-square">Hudson Square</a></li>
# </ul>
# </div>
# <div class="span3">
# <ul>
# <li><a href="/locations/new-york/inwood">Inwood</a></li>
# <li><a href="/locations/new-york/jackson-heights">Jackson Heights</a></li>
# <li><a href="/locations/new-york/kensington">Kensington</a></li>
# <li><a href="/locations/new-york/kips-bay">Kips Bay</a></li>
# <li><a href="/locations/new-york/lefferts-garden">Lefferts Garden</a></li>
# <li><a href="/locations/new-york/little-italy">Little Italy</a></li>
# <li><a href="/locations/new-york/long-island-city">Long Island City</a></li>
# <li><a href="/locations/new-york/lower-east-side">Lower East Side</a></li>
# <li><a href="/locations/new-york/meatpacking-district">Meatpacking District</a></li>
# <li><a href="/locations/new-york/midtown">Midtown</a></li>
# <li><a href="/locations/new-york/midtown-east">Midtown East</a></li>
# <li><a href="/locations/new-york/morningside-heights">Morningside Heights</a></li>
# <li><a href="/locations/new-york/murray-hill">Murray Hill</a></li>
# <li><a href="/locations/new-york/noho">Noho</a></li>
# <li><a href="/locations/new-york/nolita">Nolita</a></li>
# </ul>
# </div>
# <div class="span3">
# <ul>
# <li><a href="/locations/new-york/park-slope">Park Slope</a></li>
# <li><a href="/locations/new-york/prospect-heights">Prospect Heights</a></li>
# <li><a href="/locations/new-york/red-hook">Red Hook</a></li>
# <li><a href="/locations/new-york/ridgewood">Ridgewood</a></li>
# <li><a href="/locations/new-york/soho">Soho</a></li>
# <li><a href="/locations/new-york/south-street-seaport">South Street Seaport</a></li>
# <li><a href="/locations/new-york/times-square-theatre-district">Times Square/Theatre District</a></li>
# <li><a href="/locations/new-york/tribeca">Tribeca</a></li>
# <li><a href="/locations/new-york/union-square">Union Square</a></li>
# <li><a href="/locations/new-york/upper-east-side">Upper East Side</a></li>
# <li><a href="/locations/new-york/upper-west-side">Upper West Side</a></li>
# <li><a href="/locations/new-york/washington-heights">Washington Heights</a></li>
# <li><a href="/locations/new-york/west-village">West Village</a></li>
# <li><a href="/locations/new-york/williamsburg">Williamsburg</a></li>
# <li><a href="/locations/new-york/windsor-terrace">Windsor Terrace</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="footer">
# <div class="container">
# <div class="row">
# <div class="span3">
# <div class="language-curr-picker clearfix">
# <span class="language-picker"></span>
# <span class="currency-picker"></span>
# </div>
# </div>
# <div class="span3">
# <h6>Company</h6>
# <ul class="unstyled">
# <li><a class="link-contrast" href="/about/about-us">About</a></li>
# <li><a class="link-contrast" href="/careers">Careers</a></li>
# <li><a class="link-contrast" href="/press/news">Press</a></li>
# <li><a class="link-contrast" href="http://blog.airbnb.com">Blog</a></li>
# <li><a class="link-contrast" href="/help">Help</a></li>
# <li><a class="link-contrast" href="/policies">Policies</a></li>
# <li><a class="link-contrast" href="/disaster-response">Disaster Response</a></li>
# <li><a class="link-contrast" href="/terms">Terms &amp; Privacy</a></li>
# </ul>
# </div>
# <div class="span3">
# <h6>Discover</h6>
# <ul class="unstyled">
# <li><a class="link-contrast" href="/trust">Trust &amp; Safety</a></li>
# <li><a class="link-contrast" href="/wishlists/airbnb_picks">Airbnb Picks</a></li>
# <li><a class="link-contrast" href="/mobile">Mobile</a></li>
# <li><a class="link-contrast" href="https://www.airbnbnyc.com">Support NYC</a></li>
# <li><a class="link-contrast" href="/business-travel-management">Business Travel</a></li>
# <li><a class="link-contrast" href="/sitemaps">Site Map</a></li> </ul>
# </div>
# <div class="span3 col-3 hide-phone">
# <h6>Hosting</h6>
# <ul class="unstyled list-layout">
# <li><a href="/host">Why Host</a></li>
# <li><a href="/hospitality">Hospitality</a></li>
# <li><a href="/help/responsible-hosting">Responsible Hosting</a></li>
# <li><a href="/home-safety">Home Safety</a></li>
# <li><a href="/stories">Stories</a></li>
# </ul>
# </div>
# </div>
# <div class="row footer-slim center">
# <div class="span8 offset2">
# <h3 class="external-links-header">Join us on</h3>
# <ul class="unstyled js-external-links list-inline">
# <li>
# <a class="link-contrast footer-icon-container" href="//www.facebook.com/airbnb" target="_blank">
# <i class="icon footer-icon icon-facebook"></i>
# </a> </li>
# <li>
# <a class="link-contrast footer-icon-container" href="https://plus.google.com/+airbnb" target="_blank">
# <i class="icon footer-icon icon-google-plus"></i>
# </a> </li>
# <li>
# <a class="link-contrast footer-icon-container" href="//twitter.com/airbnb" target="_blank">
# <i class="icon footer-icon icon-twitter"></i>
# </a> </li>
# <li>
# <a class="link-contrast footer-icon-container" href="http://www.linkedin.com/company/airbnb" target="_blank">
# <i class="icon footer-icon icon-linkedin"></i>
# </a> </li>
# <li>
# <a class="link-contrast footer-icon-container" href="http://www.pinterest.com/airbnb/" target="_blank">
# <i class="icon footer-icon icon-pinterest"></i>
# </a> </li>
# <li>
# <a class="link-contrast footer-icon-container" href="http://www.youtube.com/airbnb" target="_blank">
# <i class="icon footer-icon icon-youtube"></i>
# </a> </li>
# </ul>
# <div id="copyright">
#           © Airbnb, Inc.
#         </div>
# </div>
# </div>
# </div>
# </div>
# <script src="//maps.googleapis.com/maps/api/js?channel=location-prod&amp;client=gme-airbnbinc&amp;libraries=places&amp;locale=en&amp;sensor=true&amp;v=3.10" type="text/javascript"></script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-2725447-1', 'auto');
#   ga('send', 'pageview');
# </script>
# <script src="https://a1.muscache.com/airbnb/nabelove/locations/assets-pretzel/application-11020898eb2fcf72fd1f85beb27a65c9.js" type="text/javascript"></script>
# <script>
#       $.noConflict();
#     </script>
# <script>
#       (function() {
#         I18n.init({"currencies":{"ARS":{"symbol":"$","code_required":true,"options":null},"AUD":{"symbol":"$","code_required":true,"options":null},"BRL":{"symbol":"R$","code_required":false,"options":{"space_between_price_and_symbol":true}},"CAD":{"symbol":"$","code_required":true,"options":null},"CHF":{"symbol":"CHF","code_required":false,"options":{"position":"after","space_between_price_and_symbol":true}},"CNY":{"symbol":"&yen;","code_required":false,"options":{"unicode_symbol":"¥"}},"CZK":{"symbol":"&#75;&#269;","code_required":false,"options":{"unicode_symbol":"Kč"}},"DKK":{"symbol":"kr","code_required":true,"options":{"position":"after","space_between_price_and_symbol":true,"explicit_currency_not_aesthetic":true}},"EUR":{"symbol":"&euro;","code_required":false,"options":{"unicode_symbol":"€","position":"special"}},"GBP":{"symbol":"&pound;","code_required":false,"options":{"unicode_symbol":"£"}},"HKD":{"symbol":"$","code_required":true,"options":null},"HUF":{"symbol":"Ft","code_required":false,"options":null},"IDR":{"symbol":"Rp","code_required":false,"options":null},"ILS":{"symbol":"&#8362;","code_required":false,"options":{"unicode_symbol":"₪","space_between_price_and_symbol":true}},"INR":{"symbol":"&#8377;","code_required":false,"options":{"unicode_symbol":"₹"}},"JPY":{"symbol":"&yen;","code_required":false,"options":{"unicode_symbol":"¥","space_between_price_and_symbol":true}},"KRW":{"symbol":"&#8361;","code_required":false,"options":{"unicode_symbol":"₩","space_between_price_and_symbol":true}},"MYR":{"symbol":"&#82;&#77;","code_required":false,"options":{"unicode_symbol":"RM"}},"MXN":{"symbol":"$","code_required":true,"options":null},"NOK":{"symbol":"kr","code_required":true,"options":{"position":"after","space_between_price_and_symbol":true,"explicit_currency_not_aesthetic":true}},"NZD":{"symbol":"$","code_required":true,"options":null},"PHP":{"symbol":"&#8369;","code_required":false,"options":{"unicode_symbol":"₱"}},"PLN":{"symbol":"z&#22;&#322;","code_required":false,"options":{"unicode_symbol":"zł"}},"RUB":{"symbol":"&#1088;","code_required":false,"options":{"unicode_symbol":"р","position":"after"}},"SEK":{"symbol":"kr","code_required":true,"options":{"position":"after","space_between_price_and_symbol":true,"explicit_currency_not_aesthetic":true}},"SGD":{"symbol":"$","code_required":true,"options":null},"THB":{"symbol":"&#3647;","code_required":false,"options":{"unicode_symbol":"฿"}},"TRY":{"symbol":"&#84;&#76;","code_required":false,"options":{"unicode_symbol":"TL","position":"after","space_between_price_and_symbol":true}},"TWD":{"symbol":"$","code_required":true,"options":null},"USD":{"symbol":"$","code_required":false,"options":null},"VND":{"symbol":"&#8363;","code_required":false,"options":{"unicode_symbol":"₫"}},"ZAR":{"symbol":"R","code_required":true,"options":null}},"current_locale_name":"English","languages":[{"locale_name":"Bahasa Indonesia","locale":"id"},{"locale_name":"Bahasa Melayu","locale":"ms"},{"locale_name":"Català","locale":"ca"},{"locale_name":"Dansk","locale":"da"},{"locale_name":"Deutsch","locale":"de"},{"locale_name":"English","locale":"en"},{"locale_name":"Español","locale":"es"},{"locale_name":"Eλληνικά","locale":"el"},{"locale_name":"Français","locale":"fr"},{"locale_name":"Italiano","locale":"it"},{"locale_name":"Magyar","locale":"hu"},{"locale_name":"Nederlands","locale":"nl"},{"locale_name":"Norsk","locale":"no"},{"locale_name":"Polski","locale":"pl"},{"locale_name":"Português","locale":"pt"},{"locale_name":"Suomi","locale":"fi"},{"locale_name":"Svenska","locale":"sv"},{"locale_name":"Türkçe","locale":"tr"},{"locale_name":"Íslenska","locale":"is"},{"locale_name":"Čeština","locale":"cs"},{"locale_name":"Русский","locale":"ru"},{"locale_name":"ภาษาไทย","locale":"th"},{"locale_name":"中文 (简体)","locale":"zh"},{"locale_name":"中文 (繁體)","locale":"zh-TW"},{"locale_name":"日本語","locale":"ja"},{"locale_name":"한국어","locale":"ko"}]});
#         I18n.extend({"genome.cart.saved_this_neighborhood":"Saved this neighborhood!","genome.saved_neighborhoods":"Saved neighborhoods","genome.cart.save_this_neighborhood":"Save this neighborhood","genome.see_neighborhood_listings":"See all places to stay here","genome.cart.see_listings_in_saved_neighborhoods":"See listings in all saved neighborhoods","genome.feedback.know_this_neighborhood?":"Know this Neighborhood?","genome.feedback.share_your_local_knowledge":"Share your local knowledge","genome.feedback.looking_to_make_better":"We worked closely with our community to create this guide. Share your thoughts with us so that we can continue bringing it to life. What do you find inspiring about this neighborhood?","genome.feedback.suggest_a_tag":"Suggest a tag","genome.feedback.let_us_know_what_you_think":"We appreciate your taking the time to provide your insights. We rely on our community to bring these guides to life.","genome.feedback.submit":"Submit","genome.feedback.submit_tag":"Submit Tag","genome.feedback.what_word_or_phrase_comes_to_mind":"What word or phrase comes to mind when you think of this neighborhood?","genome.feedback.confirmation":"Thank you so much for contributing to this page! We do our best to build these community pages out from contributions like yours.","genome.feedback.thanks_for_the_tag_bro":"Thanks for your tag suggestion! You might see it on the site soon.","genome.neighborhood_tile.neighborhoods_count":"%{smart_count} neighborhood.||||%{smart_count} neighborhoods.","shared.Close":"Close","shared.Thanks":"Thanks","shared.Thank you":"Thank you","shared.Email":"Email","genome.feedback.please_enter_email":"Please enter an email address","genome.neighborhood_tile.neighborhoods_count_with_traits":"%{smart_count} neighborhood matches %{trait_list}.||||%{smart_count} neighborhoods match %{trait_list}.","genome.neighborhood_tile.see_all_listings":"See all listings","genome.neighborhood_tile.friends_here":"%{smart_count} friend here.||||%{smart_count} friends here.","shared.choose_language":"Choose language","shared.choose_currency":"Choose currency"})
#
#
#         var initOptions = {
#           locale: "en"
#         };
#         Airbnb.init(initOptions);
#         Airbnb.LangCurrPicker.init();
#         Airbnb.header = new Airbnb.Header();
#
#         if (Airbnb.Tracking) {
#           Airbnb.Tracking.addDefaultContext();
#           Airbnb.Tracking.addContext({
#             source: "locations",
#             controller: "neighborhoods",
#             action: "show",
#           });
#           Airbnb.Tracking.init();
#           Airbnb.Tracking.logEvent({
#             event_name: 'impression',
#             event_data: {source: 'location'}
#           });
#         }
#       })();
#       (function() {
#         Airbnb.apiKey = "d306zoyjsyarp7ifhu67rjxn52tv0t20";
#       })();
#         $(function() {
#     !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#
#     var e = document.createElement('script');
#     e.async = true;
#     e.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.3&appId=138566025676";
#     document.getElementById('fb-root').appendChild(e);
#
#     var po = document.createElement('script');
#     po.type = 'text/javascript';
#     po.async = true;
#     po.src = 'https://apis.google.com/js/plusone.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(po, s);
#
#     e = document.createElement('script');
#     e.async = true;
#     e.src = "//assets.pinterest.com/js/pinit.js";
#     var target = document.getElementsByTagName('script')[0];
#     target.parentNode.insertBefore(e, target);
#
#     var startPage = document.location.toString();
#     var router = window.framedRouter = new Genome.FramedRouter({startPage: startPage});
#     var pushState = !!(window.history && window.history.pushState);
#     var history = Backbone.history.start({pushState: pushState, hashChange: false});
#
#     if (!pushState) {
#       Backbone.history.loadUrl(window.location.pathname);
#     }
#   });
#
#     </script>
# </body>
# </html>
# <!-- ver.  -->
# >

# %%
# Lets grab a bunch of information that we might need:
def extract_features(soup):

    headline = soup.find('div', {'class':'center description'}).get_text().strip()

    description = soup.find('meta', {'name':'description'})['content']

    # Note: Not all neighborhoods in this guide have traits, we we can't just chain the .find_all('span')
    traits = []    
    traits_html = soup.find('ul', {'class':'traits'}).find_all('span')
    for trait in traits_html:
        traits.append(trait.get_text())

    tags = []    
    for tag in soup.find_all('div', {'class':'neighborhood-tag'}):
        tags.append(tag.get_text().strip())

    similar_hoods = []
    similar_hood_html = soup.find('ul', {'class':'trait-neighborhoods neighborhoods'})
    for similar_hood in similar_hood_html.find_all('li'):
        similar_hoods.append(similar_hood['data-neighborhood-permalink'])

    neighboring_hoods = []
    for neighboring_hood in soup.find('p', {'class':'lede center'}).find_all('a'):
        neighboring_hoods.append(neighboring_hood.get_text())

    caption_bar = soup.find('div', {'class':'caption bar'}).find_all('li')
    public_trans = caption_bar[0].strong.get_text()
    having_a_car = caption_bar[1].strong.get_text()

    data_bbox = soup.find('div', {'id':'inner-map'})['data-bbox']
    data_x = float(soup.find('div', {'id':'inner-map'})['data-x'])
    data_y = float(soup.find('div', {'id':'inner-map'})['data-y'])
    
    print "HEADLINE: \n%s\n" % headline
    print "DESCRIPTION: \n%s\n" % description
    print "TRAITS: \n%s\n" % traits
    print "TAGS: \n%s\n" % tags
    print "SIMILAR HOODS: \n%s\n" % similar_hoods
    print "NEIGHBORING HOODS: \n%s\n" % neighboring_hoods
    print "PUBLIC TRANS: %s" % public_trans
    print "HAVING A CAR: %s" % having_a_car
    print 
    print "GEO INFORMATION: \n%s, \n%s, %s" % (data_bbox, data_x, data_y)

# %%
extract_features(soup)
# Out:
# HEADLINE:
# Carroll Gardens' brownstones, boutiques, and brunch spots are equal parts cool, calm, and collected.
#
# DESCRIPTION:
# Carroll Gardens has established itself as a Brooklyn favorite. Although flush with hip bars, boutiques, and restaurants, this neighborhood has never lost its old-NYC mystique. Quintessential brownstones line tree-trimmed sidewalks and local retailers and Italian eateries populate its cheerful main street. For a stroll or a stay, Carroll Gardens promises a healthy dose of Brooklyn's cool candor.
#
# TRAITS:
# [u'Peace & Quiet', u'Nightlife', u'Dining', u'Loved by New Yorkers', u'Great Transit']
#
# TAGS:
# [u'sought-after', u'beautiful', u'quiet', u'trendy', u'family friendly', u'foodie', u'front gardens', u'hipsters', u'historic', u'professional', u'italian-american', u'calm', u'strollers', u'brownstone', u'family-friendly', u'lesbian friendly', u'families', u'restaurants/bars', u'italian', u'court st.', u'family friendly', u'quaint', u'strategically located', u'vibrant']
#
# SIMILAR HOODS:
# ['park-slope', 'cobble-hill', 'boerum-hill']
#
# NEIGHBORING HOODS:
# [u'Brooklyn', u'Cobble Hill', u'Columbia Street Waterfront', u'Boerum Hill', u'Gowanus', u'Greenwood Heights', u'Red Hook']
#
# PUBLIC TRANS: Easy
# HAVING A CAR: Possible
#
# GEO INFORMATION:
# [[40.672059160796316,-74.00372818474148],[40.685654529334656,-73.98959548275297]],
# -73.9972475763, 40.6800542773

# %% [markdown]
# Scanning the above, I completely agree with nearly all of the above!
#
# Callouts:
# - Interesting to see that a neighborhood can have both "Peace & Quiet" as well as "Nightlife" as traights,
# but CG has it all!
# - I wouldn't call Greenwood Heights 'neighboring' to Caroll Gardens.
# - I had a car and felt it easy, though in a recent trip back my secret spots down 1st & Gowanus are now condos.
# - The odd thing is that "Brooklyn" is *neighboring* Carroll Gardens.  Lets look at that a little more:

# %%
# Why is Brooklyn a 'neighbor' of Carroll Gardens?:
soup.find('p', {'class':'lede center'})
# Out:
# <p class="lede center">
#           Carroll Gardens is within <a href="/locations/neighborhoods/3795">Brooklyn</a> and bordered by <a href="/locations/neighborhoods/1260">Cobble Hill</a>, <a href="/locations/neighborhoods/1304">Columbia Street Waterfront</a>, <a href="/locations/neighborhoods/1213">Boerum Hill</a>, <a href="/locations/neighborhoods/1298">Gowanus</a>, <a href="/locations/neighborhoods/1347">Greenwood Heights</a>, and <a href="/locations/neighborhoods/1301">Red Hook</a>
# </p>

# %% [markdown]
# So the extract_features doesn't pull this information out. It's something to keep in mind, however considering a listing for place in Williamsburg will note that it's in Williamsburg and NOT Brooklyn, this isn't too much of a concern for our purposes.

# %%
# lets scrape an example neighborhood SF hood! Again, using my own hood as an example
# 'https://www.airbnb.com/locations/san-francisco/duboce-triangle')
r = requests.get('https://www.airbnb.com/locations/san-francisco/duboce-triangle')

# %%
soup = BeautifulSoup(r.content)
extract_features(soup)
# Out:
# HEADLINE:
# Be in the center of everything without having to brave the crowds or the noise.
#
# DESCRIPTION:
# Although Duboce Triangle’s main attraction is its humble namesake park, this quaint residential neighborhood’s centrality contributes to its sought-after status. While this put-together neighborhood is distinctly tranquil, the bustling nightlife and shopping options of The Castro and the Mission are mere steps away. When you want to trek to more distant San Francisco destinations, Duboce Triangle’s multiple MUNI lines make it easy.
#
# TRAITS:
# [u'Great Transit']
#
# TAGS:
# [u'attractive', u'central', u'public transport', u'victorians', u'park', u'well kempt', u'sunny', u'greenery', u'dogs', u'residential', u'desirable', u'location', u'charming', u'community', u'quaint', u'trails', u'family', u'strollers', u'desirable', u'hip', u'waterfront', u'hip', u'trendy', u'chic']
#
# SIMILAR HOODS:
# ['glen-park', 'noe-valley', 'south-beach']
#
# NEIGHBORING HOODS:
# [u'Lower Haight', u'Hayes Valley', u'Haight-Ashbury', u'The Castro', u'SoMa', u'Mission District']
#
# PUBLIC TRANS: Easy
# HAVING A CAR: Difficult
#
# GEO INFORMATION:
# [[37.762649768540896,-122.4368826416511],[37.77218261689287,-122.42314973149485]],
# -122.431381638, 37.768450446

# %% [markdown]
# Whoa! AirBnB's Content team is good!
#
# Again, the piece of information I'm happy, but not in love with are Neighboring Hoods (SoMa & Duboce?!).
#
# I still have my car, so I'll pretend that having a car is difficult... (you better not take my spot!)

# %% [markdown]
# Using the above code as a template, I was able to create **'scrape_neighborhoods.py'**
#
# This script is used to scrape the neighborhood pages for its content
# * takes in a file ('../data/neighborhood_list.csv')
# * scrapes AirBnB's neighborhood guide for neighborhoods
#
# I also run the **'extract_features_from_neighborhoods.py'** file, which extracts features from the Neighborhoods & extends the MongoDB document for each neighborhood with this information.
#
# The reason for the above split was to scrape the data from AirBnB (/slash/ not get banned) and to seperate the scraping from the feature extraction
#
# The majority of the functions are based on the AirBnBNeighborhood class in **'airbnb/airbnbneighborhood.py'**, whose methods help.
#
# Notes:
# * The above extract_features() function in this notebook does NOT handle when a neighborhood didn't have a piece of information. Some neighborhoods don't have traits, similar hoods, or neighboring hoods. I take care of that in production code.
# * As mentioned above, So the extract_features doesn't discern when a hood is within another hood (i.e. Carroll Gardens'is within' Brooklyn). It's something to keep in mind, however considering a listing for place in Williamsburg will note that it's in Williamsburg and NOT Brooklyn, this isn't too much of a concern for our purposes.
# * When saving the r.content object to a MongoDB database, then reimporting that string and BeautifulSoup-ing it, I ran into some issues. As a work around, I pickle the requests object to save to the collection, then unpickle it to parse through it with BeautifulSoup.

# %% [markdown]
# ###Extracting data from AirBnB's Listings

# %%
import requests
from bs4 import BeautifulSoup
import html5lib

# %%
# lets scrape an example search result to see what we're working with
# https://www.airbnb.com/s/Portland--OR--United-States?checkin=09%2F16%2F2015&checkout=09%2F22%2F2015&guests=4&price_max=300
# we see we have the city, state & country in the search URL, and all of the other information are passed via parameters
r = requests.get('https://www.airbnb.com/s/Portland--OR--United-States?checkin=09%2F16%2F2015&checkout=09%2F22%2F2015&guests=4&price_max=300')

# %%
r.content
# Out:
# '<!DOCTYPE html>\n\n<!--[if lt IE 8]>\n\n<html lang="en"\n      \n      xmlns:fb="http://ogp.me/ns/fb#"\n      class="ie">\n\n<![endif]-->\n\n<!--[if IE 8]>\n\n<html lang="en"\n      \n      xmlns:fb="http://ogp.me/ns/fb#"\n      class="ie ie8">\n\n<![endif]-->\n\n<!--[if IE 9]>\n\n  <html lang="en"\n      \n      xmlns:fb="http://ogp.me/ns/fb#"\n      class="ie ie9">\n\n<![endif]-->\n\n<!--[if (gt IE 9)|!(IE)]><!-->\n<html lang="en"\n      \n      xmlns:fb="http://ogp.me/ns/fb#">\n\n<!--<![endif]-->\n\n  <head>\n      <link rel="dns-prefetch" href="//maps.googleapis.com">\n      <link rel="dns-prefetch" href="//maps.gstatic.com">\n      <link rel="dns-prefetch" href="//mts0.googleapis.com">\n      <link rel="dns-prefetch" href="//mts1.googleapis.com">\n\n    <!--[if IE]><![endif]-->\n    <meta charset="utf-8">\n\n    <!--[if IE 8]>\n      <link href="https://a1.muscache.com/airbnb/static/packages/common_o2.1_ie8-8341a24cc71ce465b36585d097252e3d.css" media="all" rel="stylesheet" type="text/css" />\n    <![endif]-->\n    <!--[if !(IE 8)]><!-->\n      <link href="https://a2.muscache.com/airbnb/static/packages/common_o2.1-8df429488967e76a242511e286c9cf15.css" media="all" rel="stylesheet" type="text/css" />\n    <!--<![endif]-->\n\n    <!--[if lt IE 9]>\n      <link href="https://a0.muscache.com/airbnb/static/compatibility/airglyphs-ie8-7dbf8372f80fb3fd70a35c7acaf4b6ec.css" media="all" rel="stylesheet" type="text/css" />\n    <![endif]-->\n\n    <link href="https://a2.muscache.com/airbnb/static/packages/map_search-24434d1ab8689a997bbf02443fcb37a9.css" media="screen" rel="stylesheet" type="text/css" />\n    \n\n    <meta id="csrf-param-meta-tag" name="csrf-param" content="authenticity_token"/>\n    <meta id="csrf-token-meta-tag" name="csrf-token" content=""/>\n\n    <script>\n\n      var sherlock_firstbyte = Number(new Date());\n</script>\n\n    <title>Portland Vacation Rentals & Short Term Rentals - Airbnb</title>\n\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\n      <link rel="canonical" href="https://www.airbnb.com/s/Portland--OR">\n      <link rel="next" href="https://www.airbnb.com/s/Portland--OR?page=2">\n          <link rel="alternate" href="https://es.airbnb.com/s/Portland--Oreg\xc3\xb3n" hreflang="es">\n          <link rel="alternate" href="https://fr.airbnb.be/s/Portland--Oregon" hreflang="fr-BE">\n          <link rel="alternate" href="https://fr.airbnb.ca/s/Portland--Oregon" hreflang="fr-CA">\n          <link rel="alternate" href="https://fr.airbnb.ch/s/Portland--Oregon" hreflang="fr-CH">\n          <link rel="alternate" href="https://it.airbnb.ch/s/Portland--Oregon" hreflang="it-CH">\n          <link rel="alternate" href="https://th.airbnb.com/s/\xe0\xb8\x9e\xe0\xb8\xad\xe0\xb8\xa3\xe0\xb9\x8c\xe0\xb8\x95\xe0\xb9\x81\xe0\xb8\xa5\xe0\xb8\x99\xe0\xb8\x94\xe0\xb9\x8c--\xe0\xb9\x82\xe0\xb8\xad\xe0\xb9\x80\xe0\xb8\xa3\xe0\xb8\x81\xe0\xb8\xad\xe0\xb8\x99" hreflang="th">\n          <link rel="alternate" href="https://www.airbnb.at/s/Portland--Oregon" hreflang="de-AT">\n          <link rel="alternate" href="https://www.airbnb.be/s/Portland--Oregon" hreflang="nl-BE">\n          <link rel="alternate" href="https://www.airbnb.ca/s/Portland--OR" hreflang="en-CA">\n          <link rel="alternate" href="https://www.airbnb.cat/s/Portland--Oregon" hreflang="ca">\n          <link rel="alternate" href="https://www.airbnb.ch/s/Portland--Oregon" hreflang="de-CH">\n          <link rel="alternate" href="https://www.airbnb.cl/s/Portland--Oreg\xc3\xb3n" hreflang="es-CL">\n          <link rel="alternate" href="https://www.airbnb.co.cr/s/Portland--Oreg\xc3\xb3n" hreflang="es-CR">\n          <link rel="alternate" href="https://www.airbnb.co.id/s/Portland--Oregon" hreflang="id">\n          <link rel="alternate" href="https://www.airbnb.co.in/s/Portland--OR" hreflang="en-IN">\n          <link rel="alternate" href="https://www.airbnb.co.kr/s/\xed\x8f\xac\xed\x8b\x80\xeb\x9e\x9c\xeb\x93\x9c--\xec\x98\xa4\xeb\xa0\x88\xea\xb3\x ...

# %%
soup = BeautifulSoup(r.content)
soup
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 8]>
#
# <html lang="en"
#
#       xmlns:fb="http://ogp.me/ns/fb#"
#       class="ie">
#
# <![endif]--><!--[if IE 8]>
#
# <html lang="en"
#
#       xmlns:fb="http://ogp.me/ns/fb#"
#       class="ie ie8">
#
# <![endif]--><!--[if IE 9]>
#
#   <html lang="en"
#
#       xmlns:fb="http://ogp.me/ns/fb#"
#       class="ie ie9">
#
# <![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html lang="en" xmlns:fb="http://ogp.me/ns/fb#">
# <!--<![endif]-->
# <head>
# <link href="//maps.googleapis.com" rel="dns-prefetch"/>
# <link href="//maps.gstatic.com" rel="dns-prefetch"/>
# <link href="//mts0.googleapis.com" rel="dns-prefetch"/>
# <link href="//mts1.googleapis.com" rel="dns-prefetch"/>
# <!--[if IE]><![endif]-->
# <meta charset="utf-8"/>
# <!--[if IE 8]>
#       <link href="https://a1.muscache.com/airbnb/static/packages/common_o2.1_ie8-8341a24cc71ce465b36585d097252e3d.css" media="all" rel="stylesheet" type="text/css" />
#     <![endif]-->
# <!--[if !(IE 8)]><!-->
# <link href="https://a2.muscache.com/airbnb/static/packages/common_o2.1-8df429488967e76a242511e286c9cf15.css" media="all" rel="stylesheet" type="text/css"/>
# <!--<![endif]-->
# <!--[if lt IE 9]>
#       <link href="https://a0.muscache.com/airbnb/static/compatibility/airglyphs-ie8-7dbf8372f80fb3fd70a35c7acaf4b6ec.css" media="all" rel="stylesheet" type="text/css" />
#     <![endif]-->
# <link href="https://a2.muscache.com/airbnb/static/packages/map_search-24434d1ab8689a997bbf02443fcb37a9.css" media="screen" rel="stylesheet" type="text/css"/>
# <meta content="authenticity_token" id="csrf-param-meta-tag" name="csrf-param"/>
# <meta content="" id="csrf-token-meta-tag" name="csrf-token"/>
# <script>
#
#       var sherlock_firstbyte = Number(new Date());
# </script>
# <title>Portland Vacation Rentals &amp; Short Term Rentals - Airbnb</title>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="https://www.airbnb.com/s/Portland--OR" rel="canonical"/>
# <link href="https://www.airbnb.com/s/Portland--OR?page=2" rel="next"/>
# <link href="https://es.airbnb.com/s/Portland--Oregón" hreflang="es" rel="alternate"/>
# <link href="https://fr.airbnb.be/s/Portland--Oregon" hreflang="fr-BE" rel="alternate"/>
# <link href="https://fr.airbnb.ca/s/Portland--Oregon" hreflang="fr-CA" rel="alternate"/>
# <link href="https://fr.airbnb.ch/s/Portland--Oregon" hreflang="fr-CH" rel="alternate"/>
# <link href="https://it.airbnb.ch/s/Portland--Oregon" hreflang="it-CH" rel="alternate"/>
# <link href="https://th.airbnb.com/s/พอร์ตแลนด์--โอเรกอน" hreflang="th" rel="alternate"/>
# <link href="https://www.airbnb.at/s/Portland--Oregon" hreflang="de-AT" rel="alternate"/>
# <link href="https://www.airbnb.be/s/Portland--Oregon" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.airbnb.ca/s/Portland--OR" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.airbnb.cat/s/Portland--Oregon" hreflang="ca" rel="alternate"/>
# <link href="https://www.airbnb.ch/s/Portland--Oregon" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.airbnb.cl/s/Portland--Oregón" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.airbnb.co.cr/s/Portland--Oregón" hreflang="es-CR" rel="alternate"/>
# <link href="https://www.airbnb.co.id/s/Portland--Oregon" hreflang="id" rel="alternate"/>
# <link href="https://www.airbnb.co.in/s/Portland--OR" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.airbnb.co.kr/s/포틀랜드--오레곤" hreflang="ko" rel="alternate"/>
# <link href="https://www.airbnb.co.nz/s/Portland--OR" hreflang="en-NZ" rel="alternate"/>
# <link href="https://www.airbnb.co.uk/s/Portland--OR" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.airbnb.co.ve/s/Portland--Oregón" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.airbnb.com/s/Portland--OR" hreflang="en" rel="alternate"/>
# <link href="https://www.airbnb.com.ar/s/Portland--Oregón" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.airbnb.com.au/s/Portland--OR" hreflang="en-AU" rel="alternate"/>
# <link href="https://www.airbnb.com.bo/s/Portland--Oregón" hreflang="es-BO" rel="alternate"/>
# <link href="https://www.airbnb.com.br/s/Portland--Oregon" hreflang="pt" rel="alternate"/>
# <link href="https://www.airbnb.com.bz/s/Portland--Oregón" hreflang="es-BZ" rel="alternate"/>
# <link href="https://www.airbnb.com.co/s/Portland--Oregón" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.airbnb.com.ec/s/Portland--Oregón" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.airbnb.com.gt/s/Portland--Oregón" hreflang="es-GT" rel="alternate"/>
# <link href="https://www.airbnb.com.hk/s/波特蘭--俄勒岡州" hreflang="zh-HK" rel="alternate"/>
# <link href="https://www.airbnb.com.hn/s/Portland--Oregón" hreflang="es-HN" rel="alternate"/>
# <link href="https://www.airbnb.com.mt/s/Portland--OR" hreflang="en-MT" rel="alternate"/>
# <link href="https://www.airbnb.com.my/s/Portland--Oregon" hreflang="ms" rel="alternate"/>
# <link href="https://www.airbnb.com.ni/s/Portland--Oregón" hreflang="es-NI" rel="alternate"/>
# <link href="https://www.airbnb.com.pa/s/Portland--Oregón" hreflang="es-PA" rel="alternate"/>
# <link href="https://www.airbnb.com.pe/s/Portland--Oregón" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.airbnb.com.py/s/Portland--Oregón" hreflang="es-PY" rel="alternate"/>
# <link href="https://www.airbnb.com.sg/s/Portland--OR" hreflang="en-SG" rel="alternate"/>
# <link href="https://www.airbnb.com.sv/s/Portland--Oregón" hreflang="es-SV" rel="alternate"/>
# <link href="https://www.airbnb.com.tr/s/Portland--Oregon" hreflang="tr" rel="alternate"/>
# <link href="https://www.airbnb.com.tw/s/波特蘭--俄勒岡州" hreflang="zh-TW" rel="alternate"/>
# <link href="https://www.airbnb.cz/s/Portland--Oregon" hreflang="cs" rel="alternate"/>
# <link href="https://www.airbnb.de/s/Portland--Oregon" hreflang="de" rel="alternate"/>
# <link href="https://www.airbnb.dk/s/Portland--Oregon" hreflang="da" rel="alternate"/>
# <link href="https://www.airbnb.es/s/Portland--Oregón" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.airbnb.fi/s/Portland--Oregon" hreflang="fi" rel="alternate"/>
# <link href="https://www.airbnb.fr/s/Portland--Oregon" hreflang="fr" rel="alternate"/>
# <link href="https://www.airbnb.gr/s/Πόρτλαντ--Όρεγκον" hreflang="el" rel="alternate"/>
# <link href="https://www.airbnb.gy/s/Portland--OR" hreflang="en-GY" rel="alternate"/>
# <link href="https://www.airbnb.hu/s/Portland--Oregon" hreflang="hu" rel="alternate"/>
# <link href="https://www.airbnb.ie/s/Portland--OR" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.airbnb.is/s/Portland--Oregon" hreflang="is" rel="alternate"/>
# <link href="https://www.airbnb.it/s/Portland--Oregon" hreflang="it" rel="alternate"/>
# <link href="https://www.airbnb.jp/s/ポートランド--オレゴン州" hreflang="ja" rel="alternate"/>
# <link href="https://www.airbnb.mx/s/Portland--Oregón" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.airbnb.nl/s/Portland--Oregon" hreflang="nl" rel="alternate"/>
# <link href="https://www.airbnb.no/s/Portland--Oregon" hreflang="no" rel="alternate"/>
# <link href="https://www.airbnb.pl/s/Portland--Oregon" hreflang="pl" rel="alternate"/>
# <link href="https://www.airbnb.pt/s/Portland--Oregon" hreflang="pt-PT" rel="alternate"/>
# <link href="https://www.airbnb.ru/s/Портленд--Орегон" hreflang="ru" rel="alternate"/>
# <link href="https://www.airbnb.se/s/Portland--Oregon" hreflang="sv" rel="alternate"/>
# <link href="https://zh.airbnb.com/s/Portland--OR" hreflang="zh" rel="alternate"/>
# <meta content="Rent from people in Portland from $70/night. Find unique places to stay with local hosts in 190 countries. Belong anywhere with Airbnb." name="description"/>
# <meta content="https://a2.muscache.com/airbnb/static/logos/belo-400x400-084661b96df1341091ee5764587d8ed8.png" property="og:image"/>
# <meta content="on" name="twitter:widgets:csp"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://a2.muscache.com/airbnb/static/logos/belo-200x200-4d851c5b28f61931bf1df28dd15e60ef.png" rel="image_src"/>
# <link href="/opensearch.xml" rel="search" title="Airbnb" type="application/opensearchdescription+xml"/>
# <!--[if lte IE 9]>
#       <script src="https://a2.muscache.com/airbnb/static/packages/libs_ie_support-b79daf6f8ced9b9ee1d841fbcc88d2a7.js" type="text/javascript"></script>
#       <link href="https://a0.muscache.com/airbnb/respond-proxy.html" id="respond-proxy" rel="respond-proxy" />
#       <link href="/respond.proxy.gif" id="respond-redirect" rel="respond-redirect" />
#       <script src="/respond.proxy.js?cb=1"></script>
#     <![endif]-->
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="#f5f5f5" name="theme-color"/>
# <link href="https://a1.muscache.com/airbnb/static/icons/apple-touch-icon-76x76-29b6a802ddcbcada3e98c1336b078985.png" rel="apple-touch-icon"/>
# <link href="https://a1.muscache.com/airbnb/static/icons/apple-touch-icon-76x76-29b6a802ddcbcada3e98c1336b078985.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://a2.muscache.com/airbnb/static/icons/apple-touch-icon-120x120-f755fee8bec28959299b265351f0dee2.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://a1.muscache.com/airbnb/static/icons/apple-touch-icon-152x152-51479ae43400e03b95a33f5119c65262.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://a2.muscache.com/airbnb/static/icons/apple-touch-icon-180x180-830c8479ce4d0a3c9df95fdfeddf6faa.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://a0.muscache.com/airbnb/static/icons/android-icon-192x192-ab82dea1266beaa15c85fbed5bc45702.png" rel="icon" sizes="192x192"/>
# <link href="https://a1.muscache.com/airbnb/static/logotype_favicon-21cc8e6c6a2cca43f061d2dcabdf6e58.ico" rel="shortcut icon" sizes="76x76" type="image/x-icon"/>
# </head>
# <body class="">
# <a class="screen-reader-only screen-reader-only-focusable skip-to-content" data-hook="skip-to-content" href="#site-content" tabindex="1">
#       Skip to content
#     </a>
# <span class="screen-reader-only">
#       Airbnb
#     </span>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-46MK" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div aria-hidden="true" class="smart-banner" role="banner">
# <a class="icon icon-remove icon-size-1 pull-left link-reset banner-close" href="#">
# <span class="screen-reader-only">
#       Close
#     </span>
# </a>
# <a class="pull-left app-icon install-link action-link" data-href="http://r.yoz.io/l.c.hsjS" data-href-alt="http://r.yoz.io/l.c.hskj" href="#">
# <span class="screen-reader-only">
#       Install
#     </span>
# </a>
# <div class="banner-content">
# <div class="banner-title space-top-sm-1 space-top-md-3">
# <strong class="icon-dark-gray ios-item">
#         Airbnb for iOS
#       </strong>
# <strong class="icon-dark-gray android-item hide">
#         Airbnb for Android
#       </strong>
# <br class="android-item hide"/>
# <br class="ios-item hide-sm"/>
# <div class="star-rating">
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-star icon-light-gray"></i>
# </div>
# <small class="banner-reviews icon-gray ios-item">(5,268)</small>
# <small class="banner-reviews icon-gray android-item hide">(60,813)</small>
# </div>
# <div class="banner-buttons text-right space-top-sm-2 space-top-md-4">
# <a class="link-reset btn btn-primary btn-small banner-button install-link action-link" data-href="http://r.yoz.io/l.c.hsjS" data-href-alt="http://r.yoz.io/l.c.hskj" href="#">
#         Install
#       </a>
# <a class="btn btn-small banner-button open-in-app-button action-link" data-backup-href="http://r.yoz.io/l.c.hsjS" data-backup-href-alt="http://r.yoz.io/l.c.hskj" data-href="airbnb://" href="airbnb://">
#          Open in App
#       </a>
# </div>
# </div>
# </div>
# <div class="airbnb-header new " id="header">
# <header aria-hidden="true" class="header--sm show-sm" role="banner">
# <a aria-label="Homepage" class="link-reset burger--sm" data-prevent-default="" href="#">
# <i class="icon icon-reorder icon-rausch"></i>
# <span class="screen-reader-only">
#       Airbnb
#     </span>
# </a>
# <div class="title--sm text-center">
# <button class="btn btn-block search-btn--sm search-modal-trigger">
# <i class="icon icon-search icon-gray"></i>
# <span class="search-placeholder--sm">
#           Where are you going?
#         </span>
# </button>
# </div>
# <div class="action--sm"></div>
# <nav class="nav--sm" role="navigation"></nav>
# <div class="search-modal-container"></div>
# </header>
# <header class="regular-header clearfix hide-sm" id="old-header" role="banner">
# <a aria-label="Homepage" class="header-belo pull-left" href="/">
# <span class="screen-reader-only">
#       Airbnb
#     </span>
# </a>
# <ul class="nav pull-left hide-sm list-unstyled search-form-container" id="search-form-header">
# <li class="search-bar-wrapper pull-left medium-right-margin" id="header-search">
# <form action="/s" class="search-form" id="search-form">
# <div class="search-bar">
# <i class="icon icon-search icon-gray h4"></i>
# <label class="screen-reader-only" for="input-location">
#           Where are you going?
#         </label>
# <input autocomplete="off" class="location" data-date-placeholder="mm/dd/yyyy" data-p2="true" id="input-location" name="location" placeholder="Where are you going?" type="text" value="Portland, OR, United States"/>
# <input name="source" type="hidden" value="hdr"/>
# </div>
# </form>
# </li>
# <li class="dropdown-trigger pull-left large-right-margin hide-sm hide" data-behavior="recently-viewed__container">
# <a class="no-crawl link-reset" data-behavior="recently-viewed__trigger" data-href="/history#docked-filters" href="#">
# <span class="show-lg recently-viewed__label">
#         Recently Viewed
#       </span>
# <span class="hide-lg recently-viewed__label">
# <i class="icon icon-recently-viewed icon-gray h4"></i>
# </span>
# <i class="icon icon-caret-down icon-light-gray h5"></i>
# </a>
# <div class="tooltip tooltip-top-left dropdown-menu recently-viewed__dropdown" data-behavior="recently-viewed__dropdown">
# </div>
# </li>
# <li class="browse-container dropdown-trigger pull-left hide-md">
# <a class="link-reset header-browse-trigger" data-prevent-default="" href="#" id="header-browse-trigger">
#   Browse
#    <i class="icon icon-caret-down icon-light-gray h5"></i>
# </a>
# <ul class="tooltip tooltip-top-left dropdown-menu list-unstyled">
# <li>
# <a class="link-reset menu-item header-browse-popular" href="/wishlists/popular">
#       Popular
#     </a>
# </li>
# <li>
# <a class="link-reset menu-item header-browse-friends" href="/wishlists/friends">
#       Friends
#     </a>
# </li>
# <li>
# <a class="link-reset menu-item header-browse-neighborhoods" href="/locations">
#       Neighborhoods
#     </a>
# </li>
# <li class="groups hide">
# <a class="no-crawl link-reset menu-item header-browse-groups" data-href="/groups" href="#" rel="nofollow">
#       Groups
#     </a>
# </li>
# <li>
# <a class="link-reset menu-item header-browse-vacation-rentals" href="/vacation-rentals">
#       Vacation Rentals
#     </a>
# </li>
# </ul>
# </li>
# </ul>
# <ul class="nav pull-right help-menu list-unstyled">
# <li class="help-menu-container pull-left large-right-margin hide-md dropdown-trigger" id="header-help-menu">
# <a class="help-toggle link-reset" href="/help" id="header-help-trigger">
#       Help
#       <i class="icon icon-caret-down icon-light-gray h5"></i>
# </a>
# <div class="tooltip tooltip-top-right dropdown-menu help-dropdown">
# <ul class="list-layout">
# <li class="search-bar--help hide">
# <form action="/help/search" class="search-form--help menu-item">
# <div class="input-addon">
# <input autocomplete="off" class="input-stem" name="q" placeholder="Search the help center" type="text"/>
# <input name="search_from" type="hidden" value="hdr"/>
# <i class="btn btn-primary icon icon-search input-suffix form-submit--help"></i>
# </div>
# </form>
# </li>
# <li class="visit-helpcenter-cta hide">
# <a class="help-center-link menu-item" href="/help">
#       Visit the Help Center »
#     </a>
# </li>
# <li class="loading"></li>
# <li class="all_faqs hide">
# <a class="link-reset menu-item" href="/help">
#       See all FAQs
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li class="list-your-space pull-left">
# <a class="btn btn-special list-your-space-btn hide" href="/rooms/new" id="list-your-space">
#           List Your Space
#         </a>
# </li>
# </ul>
# <ul class="nav pull-right logged-out list-unstyled medium-right-margin">
# <li class="pull-left medium-right-margin" id="sign_up">
# <a class="link-reset" data-header-view="true" data-redirect="redirect_params[action]=index&amp;redirect_params[checkin]=09%2F16%2F2015&amp;redirect_params[checkout]=09%2F22%2F2015&amp;redirect_params[controller]=search&amp;redirect_params[guests]=4&amp;redirect_params[location]=Portland%2C+OR%2C+United+States&amp;redirect_params[path_location]=Portland--OR--United-States&amp;redirect_params[price_max]=300" data-signup-modal="" href="/signup_login">
#       Sign Up
#     </a>
# </li>
# <li class="pull-left" id="login">
# <a class="link-reset" data-login-modal="" data-redirect="redirect_params[action]=index&amp;redirect_params[checkin]=09%2F16%2F2015&amp;redirect_params[checkout]=09%2F22%2F2015&amp;redirect_params[controller]=search&amp;redirect_params[guests]=4&amp;redirect_params[location]=Portland%2C+OR%2C+United+States&amp;redirect_params[path_location]=Portland--OR--United-States&amp;redirect_params[price_max]=300" href="/login">
#       Log In
#     </a>
# </li>
# </ul>
# <ul class="nav pull-right logged-in list-unstyled medium-right-margin">
# <li class="inbox-item pull-left dropdown-trigger js-inbox-comp" id="inbox-item">
# <a class="no-crawl link-reset inbox-icon" data-href="/inbox" href="#" rel="nofollow">
# <i class="alert-count fade text-center">0</i>
# <i class="icon icon-envelope icon-gray">
# <span class="text-hide hide">
#           Inbox
#         </span>
# </i>
# </a>
# <div class="tooltip tooltip-top-right dropdown-menu list-unstyled header-dropdown notifications-dropdown hide">
# </div>
# </li>
# </ul>
# <ul class="nav pull-right logged-in list-unstyled" role="navigation">
# <li class="user-item pull-left medium-right-margin dropdown-trigger">
# <a class="link-reset header-avatar-trigger" href="#" id="header-avatar-trigger">
# <div class="media-photo media-round user-profile-image"></div>
# <span class="value_name">
#         User
#       </span>
# <i class="icon icon-caret-down icon-light-gray h5"></i>
# </a>
# <ul class="tooltip tooltip-top-right dropdown-menu list-unstyled header-dropdown">
# <li>
# <a class="no-crawl link-reset menu-item item-dashboard" data-href="/home/dashboard" href="#" rel="nofollow">
#           Dashboard
#         </a>
# </li>
# <li class="listings">
# <a class="no-crawl link-reset menu-item item-listing" data-href="/rooms" href="#" rel="nofollow">
# <span class="singular" style="display: none;">
#             Your Listing
#           </span>
# <span class="plural">
#             Your Listings
#           </span>
# </a>
# </li>
# <li class="reservations" style="display: none;">
# <a class="no-crawl link-reset menu-item item-reservation" data-href="/my_reservations" href="#" rel="nofollow">
#            Your Reservations
#         </a>
# </li>
# <li>
# <a class="no-crawl link-reset menu-item item-trips" data-href="/trips/upcoming" href="#" rel="nofollow">
#           Your Trips
#         </a>
# </li>
# <li>
# <a class="no-crawl link-reset menu-item item-wishlists" data-href="/wishlists/my" href="#" id="wishlists">
#           Wish Lists
#         </a>
# </li>
# <li class="groups">
# <a class="no-crawl link-reset menu-item item-groups" data-href="/groups" href="#" rel="nofollow">
#           Groups
#         </a>
# </li>
# <li>
# <a class="no-crawl link-reset menu-item item-invite-friends" data-href="/invite?r=3" href="#">
#           Invite Friends
#           <span class="label label-pink label-new">
#             New
#           </span>
# </a>
# </li>
# <li>
# <a class="no-crawl link-reset menu-item item-user-edit" data-href="/users/edit" href="#" rel="nofollow">
#           Edit Profile
#         </a>
# </li>
# <li>
# <a class="no-crawl link-reset menu-item item-account" data-href="/account" href="#" rel="nofollow">
#           Account
#         </a>
# </li>
# <li class="business-travel hide">
# <a class="no-crawl link-reset menu-item item-business-travel" data-href="/business" href="#" rel="nofollow">
#           Business Travel
#         </a>
# </li>
# <li>
# <a class="no-crawl link-reset menu-item header-logout" data-href="/logout" href="#" rel="nofollow">
#           Log Out
#         </a>
# </li>
# </ul>
# </li>
# </ul>
# </header>
# <div class="regular-header regular-header--new clearfix hide-sm" id="new-header">
# <div class="comp pull-left">
# <a class="hdr-btn link-reset belo-container" href="/">
# <i class="icon icon-pos--lower icon-rausch icon-airbnb-alt h2 show-login"></i>
# <i class="icon icon-pos--lower icon-rausch icon-airbnb show-logout"></i>
# </a>
# </div>
# <div class="comp pull-left search-bar-wrapper">
# <form action="/s" class="search-form">
# <div class="search-bar">
# <i class="icon icon-search icon-gray h4"></i>
# <input autocomplete="off" class="location" data-date-placeholder="mm/dd/yyyy" data-p2="true" name="location" placeholder="Where are you going?" type="text" value="Portland, OR, United States"/>
# <input name="source" type="hidden" value="hdr"/>
# </div>
# </form>
# </div>
# <div id="header-help-menu">
# <div class="comp pull-right help-trigger-wrapper no-border background-light-gray ">
# <a class="hdr-btn help-toggle link-reset" href="/help">
# <span class="margin-right--tiny">Help</span>
# <i class="icon-chevron-down-alt hide-md icon-chevron-down-alt-gray"></i>
# </a>
# </div>
# </div>
# <div class="comp-on-right">
# <div class="comp pull-right show-host">
# <a class="no-crawl hdr-btn link-reset " data-href="/dashboard" href="#" rel="nofollow">
# <i class="icon icon-host-home-alt h3 margin-right--small icon-pos--lower icon-gray"></i>
# <span class="hide-md margin-right--tiny">
#       Host
#     </span>
# <i class="icon-chevron-down-alt hide-md icon-chevron-down-alt-gray"></i>
# </a>
# <div class="panel tooltip tooltip-top-right drop-down-menu host-tooltip--new">
# <ul class="menu-list list-layout">
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/dashboard" href="#">Dashboard</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/rooms" href="#">Manage Listings</a>
# </li>
# <li class="menu-list__item">
# <a class="menu-list__item-block link-reset" href="/rooms/new">List Your Space</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/my_reservations" href="#">Your Reservations</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/users/reviews" href="#">Reviews</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/groups" href="#">Groups</a>
# </li>
# <li class="menu-list__item">
# <a class="menu-list__item-block link-reset" href="/hospitality">Hospitality</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="comp pull-right hide-host">
# <a class="hdr-btn link-reset " href="/rooms/new">
# <i class="icon icon-host-home-alt h3 margin-right--small icon-pos--lower icon-gray"></i>
# <span class="hide-md margin-right--tiny">
#       Become a Host
#     </span>
# </a>
# </div>
# </div>
# <div class="comp pull-right show-login">
# <a class="no-crawl hdr-btn link-reset js-inbox-comp " data-href="/inbox" href="#" rel="nofollow">
# <div class="inbox-icon-container text-center">
# <i class="icon icon-envelope h3 icon-pos--lower icon-gray">
# <span class="text-hide hide">Inbox</span>
# </i>
# <i class="alert-count text-center fade">0</i>
# </div>
# </a>
# <div class="tooltip tooltip-top-right panel drop-down-menu notifications-dropdown hide">
# </div>
# </div>
# <div class="comp pull-right show-login">
# <a class="no-crawl hdr-btn link-reset header-avatar-trigger" data-href="/dashboard" data-href-host="/trips" href="#" rel="nofollow">
# <div class="media-photo media-round normal-line-height user-profile-image margin-right--tiny"></div>
# <span class="value_name margin-right--tiny hide-md"></span>
# <i class="icon-chevron-down-alt hide-md icon-chevron-down-alt-gray"></i>
# </a>
# <div class="panel tooltip tooltip-top-right drop-down-menu avatar-tooltip--new">
# <ul class="menu-list list-layout">
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/trips" href="#">Your Trips</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/wishlists/popular" href="#">Wish Lists</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/users/edit" href="#">Edit Profile</a>
# </li>
# <li class="menu-list__item">
# <a class="menu-list__item-block link-reset" href="/invite">Invite Friends</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/users/notifications" href="#">Account Settings</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/logout" href="#">Log Out</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="comp pull-right show-logout">
# <a class="hdr-btn link-reset" data-header-view="true" data-redirect="redirect_params[action]=index&amp;redirect_params[checkin]=09%2F16%2F2015&amp;redirect_params[checkout]=09%2F22%2F2015&amp;redirect_params[controller]=search&amp;redirect_params[guests]=4&amp;redirect_params[location]=Portland%2C+OR%2C+United+States&amp;redirect_params[path_location]=Portland--OR--United-States&amp;redirect_params[price_max]=300" data-signup-modal="" href="/signup_login">
#     Sign Up
#   </a>
# </div>
# <div class="comp pull-right show-logout">
# <a class="hdr-btn link-reset" data-login-modal="" data-redirect="redirect_params[action]=index&amp;redirect_params[checkin]=09%2F16%2F2015&amp;redirect_params[checkout]=09%2F22%2F2015&amp;redirect_params[controller]=search&amp;redirect_params[guests]=4&amp;redirect_params[location]=Portland%2C+OR%2C+United+States&amp;redirect_params[path_location]=Portland--OR--United-States&amp;redirect_params[price_max]=300" href="/login">
#     Log In
#   </a>
# </div>
# <div class="comp-on-left">
# <div class="comp pull-right show-host">
# <a class="no-crawl hdr-btn link-reset " data-href="/dashboard" href="#" rel="nofollow">
# <i class="icon icon-host-home-alt h3 margin-right--small icon-pos--lower icon-gray"></i>
# <span class="hide-md margin-right--tiny">
#       Host
#     </span>
# <i class="icon-chevron-down-alt hide-md icon-chevron-down-alt-gray"></i>
# </a>
# <div class="panel tooltip tooltip-top-right drop-down-menu host-tooltip--new">
# <ul class="menu-list list-layout">
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/dashboard" href="#">Dashboard</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/rooms" href="#">Manage Listings</a>
# </li>
# <li class="menu-list__item">
# <a class="menu-list__item-block link-reset" href="/rooms/new">List Your Space</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/my_reservations" href="#">Your Reservations</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/users/reviews" href="#">Reviews</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/groups" href="#">Groups</a>
# </li>
# <li class="menu-list__item">
# <a class="menu-list__item-block link-reset" href="/hospitality">Hospitality</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="comp pull-right hide-host">
# <a class="hdr-btn link-reset " href="/rooms/new">
# <i class="icon icon-host-home-alt h3 margin-right--small icon-pos--lower icon-gray"></i>
# <span class="hide-md margin-right--tiny">
#       Become a Host
#     </span>
# </a>
# </div>
# </div>
# <div class="comp pull-right hide" data-behavior="recently-viewed__container">
# <div>
# <a class="no-crawl hdr-btn link-reset " data-behavior="recently-viewed__trigger" data-href="/history#docked-filters" href="#">
# <i class="icon icon-recently-viewed h3 margin-right--small icon-pos--lower icon-gray"></i>
# <span class="hide-md margin-right--tiny">
#         Recently Viewed
#       </span>
# <i class="icon-chevron-down-alt hide-md icon-chevron-down-alt-gray"></i>
# </a>
# </div>
# <div class="panel tooltip tooltip-top-right drop-down-menu host-tooltip--new recently-viewed__dropdown" data-behavior="recently-viewed__dropdown">
# </div>
# </div>
# </div>
# </div>
# <noscript>
# <div class="alert alert-with-icon alert-error no-js-alert">
# <i class="icon alert-icon icon-alert-alt"></i>
#         We’re sorry, some parts of the Airbnb website don’t work properly without JavaScript enabled.
#
# </div>
# </noscript>
# <!-- This has to be here as field_guide3 is used in init() -->
# <meta content='{"flags":{"name":"flags","value":{"can_see_community":2,"og_publish":16,"has_wishlisted":32,"update_cached":64,"revert_to_admin":128,"facebook_connected":256,"erf_override":512,"has_search":1024,"search_help_dropdown":2048,"has_dates":4096,"can_see_notifications_tooltip":8192,"can_send_profile_messages":32768,"just_logged_in":65536,"has_been_host":131072,"should_drop_pellet":262144,"field_guide_preload":524288,"is_active_host":1048576,"is_business_travel_manager":2097152,"can_see_availability_rules":33554432,"is_vr_platform_powered_host":67108864,"can_see_meetups":134217728,"should_drop_sift_pellet":268435456,"can_see_groups":536870912,"has_verified_phone":1073741824,"has_profile_pic":2147483648}},"roles":{"name":"roles","value":{"is_content_manager":1048576,"is_stats_admin":16777216}},"user_attributes":{"name":"_user_attributes"}}' id="_bootstrap-user-attr-cookies"/>
# <meta content='{"use_business_travel_header":null}' id="_bootstrap-header-init"/>
# <meta content='{"inspectlet_on_guest":{"subject":"bev","buckets":2,"percent_exposed":1,"treatments":[{"name":"control","buckets":null},{"name":"inspectlet_active","buckets":null}]},"p2_remarketing_test":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"show_remarketing_ad","buckets":null}]},"p2_p3_encourage_dates_messaging_v2":{"subject":"bev","buckets":3,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"illustration_and_message","buckets":null},{"name":"simple_message","buckets":null}]},"p2_hoodie_all":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"neighborhoods","buckets":null}]},"p2_hoodie_exposed":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"neighborhoods","buckets":null}]},"p2_remove_keywords_filter":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"remove_keywords_filter","buckets":null}]},"p2_remove_language_filter":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"remove_language_filter","buckets":null}]},"p2_card_ib_tooltips":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"show_ib_tooltips","buckets":null}]},"china_p2_tour_1":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"only_checkin_date","buckets":null}]},"the_new_header_take_4":{"subject":"bev","buckets":3,"percent_exposed":100,"treatments":[{"name":"new_header_lys_on_left","buckets":null},{"name":"new_header_lys_on_right","buckets":null},{"name":"old_header","buckets":null}]},"global_recently_viewed":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"global_recently_viewed","buckets":null}]},"p1_search_autocomplete_bounds":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"experiment","buckets":null}]},"ipad_download_interstitial_modal":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"show_ipad_modal","buckets":null}]},"field_guide3":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"baseline","buckets":null},{"name":"show_guide","buckets":null}]}}' id="_bootstrap-erf"/>
# <script src="https://a2.muscache.com/airbnb/static/packages/header_cookie-ed18f63f212d3be1f78b58964982842c.js" type="text/javascript"></script>
# <script>
#
#       (function () {
#         var initData = BootstrapData.get('header-init');
#         var headerContainer = document.getElementById('header');
#         var newHeader = document.getElementById('new-header');
#         var oldHeader = document.getElementById('old-header');
#         var useBusinessTravelHeader = initData ? initData.use_business_travel_header : false;
#
#         var useNewHeaderLeft = function () {
#           J(document.body).addClass('with-new-header');
#           headerContainer.removeChild(oldHeader);
#           J(headerContainer).addClass('lys-on-left');
#         };
#         var useNewHeaderRight = function () {
#           J(document.body).addClass('with-new-header');
#           headerContainer.removeChild(oldHeader);
#           J(headerContainer).addClass('lys-on-right');
#         };
#         var useOldHeader = function () {
#           headerContainer.removeChild(newHeader);
#         };
#
#         // Don't affect header experiment if business header is enabled.
#         if (useBusinessTravelHeader) { return };
#
#         Airbnb.ERF.deliverExperiment(
#           'the_new_header_take_4',
#           {
#             new_header_lys_on_left: useNewHeaderLeft,
#             new_header_lys_on_right: useNewHeaderRight,
#             old_header: useOldHeader,
#             treatment_unknown: useOldHeader
#           }
#         );
#       })();
# </script>
# <div class="flash-container"></div>
# <main id="site-content" role="main">
# <div class="map-search" data-bootstrap-data='{"checkin":"09/16/2015","checkout":"09/22/2015","guests":"4","price_max":"300","controller":"search","action":"index","path_location":"Portland--OR--United-States","location":"Portland, OR, United States","visible_results_count":396,"results_count_string":"396 Rentals &amp;middot; Portland","urgent_header_string":null,"urgent_div_class":null,"per_month":false,"center_lat":45.5230622,"center_lng":-122.6764816,"geo":{"accuracy":4,"district":null,"city":"Portland","state":"Oregon","country":"United States","country_code":"US","state_short":"OR","natural_feature":null,"result_type":"locality","colloquial_area":null,"success?":true,"market":"Portland"},"s_tag":"zhhI","pagination_footer":"&lt;div class=\"results-footer\"&gt;\n\n  &lt;div class=\"pagination-buttons-container row-space-8\"&gt;\n    &lt;div class=\"results_count\"&gt;\n      &lt;p&gt;\n        1 &amp;ndash; 18 of 396 Rentals\n      &lt;/p&gt;\n    &lt;/div&gt;\n    &lt;div class=\"pagination pagination-responsive\"&gt;&lt;ul class=\"list-unstyled\"&gt; &lt;li class=\"active\"&gt;&lt;a rel=\"start\" target=\"1\" href=\"/s/Portland--OR--United-States\"&gt;1&lt;/a&gt;&lt;/li&gt; &lt;li&gt;&lt;a rel=\"next\" target=\"2\" href=\"/s/Portland--OR--United-States?page=2\"&gt;2&lt;/a&gt;&lt;/li&gt; &lt;li&gt;&lt;a target=\"3\" href=\"/s/Portland--OR--United-States?page=3\"&gt;3&lt;/a&gt;&lt;/li&gt; &lt;li class=\"gap\"&gt;&lt;span class=\"gap\"&gt;&amp;hellip;&lt;/span&gt;&lt;/li&gt; &lt;li&gt;&lt;a target=\"22\" href=\"/s/Portland--OR--United-States?page=22\"&gt;22&lt;/a&gt;&lt;/li&gt; &lt;li class=\"next next_page\"&gt;&lt;a target=\"2\" rel=\"next\" href=\"/s/Portland--OR--United-States?page=2\"&gt;&lt;span class=\"screen-reader-only\"&gt;Next&lt;/span&gt;&lt;i class=\"icon icon-caret-right\"&gt;&lt;/i&gt;&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/div&gt;\n  &lt;/div&gt;\n\n  &lt;div class=\"nearby-links\"&gt;\n    People also stay in &lt;span class=\"text-muted\"&gt;\n    &lt;a href=\"/s/Bend--OR\"&gt;\n      Bend\n    &lt;/a&gt; &amp;middot; \n    &lt;a href=\"/s/Eugene--OR\"&gt;\n      Eugene\n    &lt;/a&gt; &amp;middot; \n    &lt;a href=\"/s/Tacoma--WA\"&gt;\n      Tacoma\n    &lt;/a&gt; &amp;middot; \n    &lt;a href=\"/s/Hood-River--OR\"&gt;\n      Hood River\n    &lt;/a&gt; &amp;middot; \n    &lt;a href=\"/s/Vancouver--Canada\"&gt;\n      Vancouver\n    &lt;/a&gt;\n&lt;/span&gt;\n\n    &lt;div class=\"breadcrumbs row-space-top-1\" itemprop=\"breadcrumb\"&gt;\n        &lt;span itemscope itemtype=\"http://data-vocabulary.org/Breadcrumb\"&gt;\n          &lt;a href=\"/s/United-States\" itemprop=\"url\"&gt;\n            &lt;span itemprop=\"title\"&gt;United States&lt;/span&gt;\n          &lt;/a&gt;\n          &lt;i class=\"icon icon-chevron-right breadcrumb-spacer\"&gt;&lt;/i&gt;\n        &lt;/span&gt;\n        &lt;span itemscope itemtype=\"http://data-vocabulary.org/Breadcrumb\"&gt;\n          &lt;a href=\"/s/Oregon--United-States\" itemprop=\"url\"&gt;\n            &lt;span itemprop=\"title\"&gt;Oregon&lt;/span&gt;\n          &lt;/a&gt;\n          &lt;i class=\"icon icon-chevron-right breadcrumb-spacer\"&gt;&lt;/i&gt;\n        &lt;/span&gt;\n          &lt;a href=\"/getaways/Portland\"&gt;\n            &lt;span&gt;Portland&lt;/span&gt;\n          &lt;/a&gt;\n    &lt;/div&gt;\n  &lt;/div&gt;\n\n&lt;/div&gt;\n","page":1,"p2_ib_filter_on_last_minute_default":false}'>
# <div class="sidebar">
# <div class="alert alert-block hide-sm" id="tour-alert">
# <a class="alert-close close" href="#"></a>
# <div>
# <h4 id="tour-alert-title"></h4>
# <h6 id="tour-alert-text"></h6>
# <div class="hide" data-value="Portland" id="city-name"></div>
# </div>
# </div>
# <div class="hide hide-sm" id="tour-step-container">
# <div class="panel panel-quote panel-quote-right row-space-4">
# <a class="icon icon-size-1 icon-remove" href="#" id="step-close"></a>
# <div class="panel-body" id="step-panel">
# <div class="tour-step">
# <h5 id="step-title"></h5>
# <p id="step-text"></p>
# </div>
# </div>
# </div>
# <div class="clearfix" id="tour-step-footer">
# <div id="tour-step-footer-nav">
# </div>
# <div id="tour-step-footer-next">
# <a href="#" id="next-step"></a>
# </div>
# </div>
# </div>
# <div class="filters collapse">
# <div class="panel-header filters-section show-sm">
#         Filters
#       </div>
# <div class="filters-section intro-filter panel-body panel-light">
# <div class="row">
# <div class="col-lg-2 col-md-12 text-center-sm text-center-md row-space-sm-1 filter-label">
# <label>Dates</label>
# </div>
# <form class="col-lg-9 trip-form">
# <div class="row row-condensed">
# <div class="col-md-4 col-sm-6 row-space-1-sm">
# <label class="screen-reader-only" for="map-search-checkin">
#               Check In
#             </label>
# <input class="checkin tour-target" id="map-search-checkin" name="checkin" placeholder="Check In" type="text"/>
# </div>
# <div class="col-md-4 col-sm-6 row-space-1-sm">
# <label class="screen-reader-only" for="map-search-checkout">
#               Check Out
#             </label>
# <input class="checkout tour-target" id="map-search-checkout" name="checkout" placeholder="Check Out" type="text"/>
# </div>
# <div class="col-md-4 col-sm-12">
# <div class="select select-block">
# <label class="screen-reader-only" for="guest-select">
#                 Number of guests
#               </label>
# <select class="guest-select" data-prefill="4" id="guest-select" name="guests">
# <option value="1">1 Guest</option>
# <option value="2">2 Guests</option>
# <option value="3">3 Guests</option>
# <option value="4">4 Guests</option>
# <option value="5">5 Guests</option>
# <option value="6">6 Guests</option>
# <option value="7">7 Guests</option>
# <option value="8">8 Guests</option>
# <option value="9">9 Guests</option>
# <option value="10">10 Guests</option>
# <option value="11">11 Guests</option>
# <option value="12">12 Guests</option>
# <option value="13">13 Guests</option>
# <option value="14">14 Guests</option>
# <option value="15">15 Guests</option>
# <option value="16">16+ Guests</option>
# </select>
# </div>
# </div>
# </div>
# <div class="simple-dates-message-container hide">
# <div class="text-kazan space-top-2">
# <strong>
# <i class="icon icon-currency-usd"></i>
#               Enter dates for accurate prices and availability.
#             </strong>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div class="filters-section room-type-group intro-filter panel-body panel-light">
# <div class="row">
# <div class="col-lg-2 col-md-12 text-center-sm text-center-md filter-label">
# <label>
#           Room Type
#           <i class="icon icon-question hide-sm hide-md" id="room-type-tooltip"></i>
# </label>
# <div class="tooltip tooltip-left-middle show-lg" data-sticky="true" data-trigger="#room-type-tooltip" role="tooltip">
# <dl class="panel-body">
# <dt>Entire Place</dt>
# <dd>Listings where you have the whole place to yourself.</dd>
# <dt>Private Room</dt>
# <dd>Listings where you have your own room but share some common spaces.</dd>
# <dt>Shared Room</dt>
# <dd>Listings where you'll share your room or your room may be a common space.</dd>
# </dl>
# </div>
# </div>
# <div class="col-lg-9">
# <div class="row row-condensed" id="room-options">
# <div class="col-middle-alt col-sm-4">
# <label class="checkbox panel panel-dark">
# <input class="pull-right" name="room-type" type="checkbox" value="Entire home/apt"/>
# <i class="icon icon-entire-place h5 needsclick"></i>
#               Entire Place
#             </label>
# </div>
# <div class="col-middle-alt col-sm-4">
# <label class="checkbox panel panel-dark">
# <input class="pull-right" name="room-type" type="checkbox" value="Private room"/>
# <i class="icon icon-private-room h5 needsclick"></i>
#               Private Room
#             </label>
# </div>
# <div class="col-middle-alt col-sm-4">
# <label class="checkbox panel panel-dark">
# <input class="pull-right" name="room-type" type="checkbox" value="Shared room"/>
# <i class="icon icon-shared-room h5 needsclick"></i>
#               Shared Room
#             </label>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="filters-section intro-filter panel-body panel-light">
# <div class="row">
# <div class="col-lg-2 col-md-12 text-center-sm text-center-md filter-label">
# <label>Price Range</label>
# </div>
# <div class="col-lg-9 col-md-12">
# <div class="price-range-slider" data-avg-price="187" data-currency-symbol-left="$" data-currency-symbol-right="" data-histogram-data="" data-max-price-daily="1000" data-max-price-monthly="15000" data-min-price-daily="10" data-min-price-monthly="150">
# <div class="ui-slider">
# <div class="row-space-2 progress"></div>
# <div class="row">
# <div class="col-6">
#                 $<span class="price"></span>
# </div>
# <div class="col-6 text-right">
#                 $<span class="price"></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="filters-section size-group panel-body panel-light">
# <div class="row">
# <div class="col-lg-2 col-md-12 text-center-sm text-center-md filter-label">
# <label>Size</label>
# </div>
# <form class="col-lg-9">
# <div class="row row-condensed">
# <div class="col-md-4 col-sm-12 row-space-1">
# <div class="select select-block">
# <label class="screen-reader-only" for="map-search-min-bedrooms">
#                 Minimum number of bedrooms
#               </label>
# <select class="min-bedrooms" id="map-search-min-bedrooms" name="min_bedrooms">
# <option value="-1">Bedrooms</option>
# <option value="1">1 Bedroom</option>
# <option value="2">2 Bedrooms</option>
# <option value="3">3 Bedrooms</option>
# <option value="4">4 Bedrooms</option>
# <option value="5">5 Bedrooms</option>
# <option value="6">6 Bedrooms</option>
# <option value="7">7 Bedrooms</option>
# <option value="8">8 Bedrooms</option>
# <option value="9">9 Bedrooms</option>
# <option value="10">10 Bedrooms</option>
# </select>
# </div>
# </div>
# <div class="col-md-4 col-sm-12 row-space-1">
# <div class="select select-block">
# <label class="screen-reader-only" for="map-search-min-bathrooms">
#                 Minimum number of bathrooms
#               </label>
# <select class="min-bathrooms input-medium" id="map-search-min-bathrooms" name="min_bathrooms">
# <option value="-1">Bathrooms</option>
# <option value="0.0">0 Bathrooms</option>
# <option value="0.5">0.5 Bathrooms</option>
# <option value="1.0">1 Bathroom</option>
# <option value="1.5">1.5 Bathrooms</option>
# <option value="2.0">2 Bathrooms</option>
# <option value="2.5">2.5 Bathrooms</option>
# <option value="3.0">3 Bathrooms</option>
# <option value="3.5">3.5 Bathrooms</option>
# <option value="4.0">4 Bathrooms</option>
# <option value="4.5">4.5 Bathrooms</option>
# <option value="5.0">5 Bathrooms</option>
# <option value="5.5">5.5 Bathrooms</option>
# <option value="6.0">6 Bathrooms</option>
# <option value="6.5">6.5 Bathrooms</option>
# <option value="7.0">7 Bathrooms</option>
# <option value="7.5">7.5 Bathrooms</option>
# <option value="8">8+ Bathrooms</option>
# </select>
# </div>
# </div>
# <div class="col-md-4 col-sm-12">
# <div class="select select-block">
# <label class="screen-reader-only" for="map-search-min-beds">
#                 Minimum number of beds
#               </label>
# <select class="min-beds input-medium" id="map-search-min-beds" name="min_beds">
# <option value="-1">Beds</option>
# <option value="1">1 Bed</option>
# <option value="2">2 Beds</option>
# <option value="3">3 Beds</option>
# <option value="4">4 Beds</option>
# <option value="5">5 Beds</option>
# <option value="6">6 Beds</option>
# <option value="7">7 Beds</option>
# <option value="8">8 Beds</option>
# <option value="9">9 Beds</option>
# <option value="10">10 Beds</option>
# <option value="11">11 Beds</option>
# <option value="12">12 Beds</option>
# <option value="13">13 Beds</option>
# <option value="14">14 Beds</option>
# <option value="15">15 Beds</option>
# <option value="16">16+ Beds</option>
# </select>
# </div>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div class="filters-section panel-body panel-light">
# <div class="row">
# <div class="col-lg-2 col-md-12 filter-label">
# <label>Options</label>
# </div>
# <div class="col-lg-9">
# <div class="row row-condensed">
# <div class="col-lg-4 col-md-6">
# <label class="row row-condensed checkbox" id="superhost-tooltip">
# <div class="col-lg-2 col-md-1 col-middle-alt superhost">
# <input name="superhost" type="checkbox" value="superhost"/>
# </div>
# <div class="col-lg-10 col-md-11 col-middle-alt needsclick">
# <div class="superhost-badge"></div>
#                     Superhost
#                     <small class="text-muted needsclick">
#                       Stay with recognized hosts.
#                       <a href="/superhost" target="_blank">Learn More</a>
# </small>
# </div>
# </label>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="checkbox-group neighborhoods filters-section panel-body panel-light" data-name="neighborhoods">
# <div class="row">
# <div class="col-lg-2 col-md-12 filter-label">
# <label>Neighborhoods</label>
# </div>
# <div class="col-lg-9 col-md-11">
# <div class="row row-condensed filters-columns">
# <div class="col-md-4">
# <label class="media checkbox text-truncate" title="Northwest District">
# <input class="pull-left" name="neighborhood" type="checkbox" value="Northwest District"/>
#               Northwest District
#             </label>
# </div>
# <div class="col-md-4">
# <label class="media checkbox text-truncate" title="Richmond">
# <input class="pull-left" name="neighborhood" type="checkbox" value="Richmond"/>
#               Richmond
#             </label>
# </div>
# <div class="col-md-4">
# <label class="media checkbox text-truncate" title="Concordia">
# <input class="pull-left" name="neighborhood" type="checkbox" value="Concordia"/>
#               Concordia
#             </label>
# </div>
# </div>
# <div class="filters-more collapse">
# <hr/>
# <div class="row row-condensed filters-columns">
# <div class="col-md-4">
# <label class="media checkbox text-truncate" title="Alameda">
# <input class="pull-left" name="neighborhood" type="checkbox" value="Alameda"/>
#                 Alameda
#               </label>
# </div>
# <div class="col-md-4">
# <label class="media checkbox text-truncate" title="Arbor Lodge">
# <input class="pull-left" name="neighborhood" type="checkbox" value="Arbor Lodge"/>
#                 Arbor Lodge
#               </label>
# </div>
# <div class="col-md-4">
# <label class="media checkbox text-truncate" title="Argay">
# <input class="pull-left" name="neighborhood" type="checkbox" value="Argay"/>
#                 Argay
#               </label>
# </div>
# <div class="col-md-4">
# <label class="media checkbox text-truncate" title="Arlington Heights">
# <input class="pull-left" name="neighborhood" type="checkbox" value="Arlington Heights"/>
#                 Arlington Heights
#               </label>
# </div>
# <div class="col-md-4">
# ...
# <span class="screen-reader-only">Wishlist</span>
# <i class="icon icon-heart icon-rausch icon-size-2 rich-toggle-checked"></i>
# <i class="icon icon-heart wishlist-heart-unchecked icon-size-2 rich-toggle-unchecked"></i>
# <i class="icon icon-heart-alt icon-white icon-size-2"></i>
# </label>
# </span>
# </div>
# </div>
# <div class="panel-body panel-card-section">
# <div class="media">
# <a class="media-photo-badge pull-right card-profile-picture card-profile-picture-offset" href="/users/show/12727870">
# <div class="media-photo media-round">
# <img alt="" src="https://a0.muscache.com/ac/users/12727870/profile_pic/1416785156/original.jpg?interpolation=lanczos-none&amp;crop=w:w;*,*&amp;crop=h:h;*,*&amp;resize=68:*&amp;output-format=jpg&amp;output-quality=70"/>
# </div>
# </a>
# <a class="text-normal" href="/rooms/4652582?checkin=09%2F16%2F2015&amp;checkout=09%2F22%2F2015&amp;guests=4&amp;s=zhhI" target="listing_4652582">
# <h3 class="h5 listing-name text-truncate row-space-top-1" itemprop="name" title="Riverfront modern condo near Pearl">
#                     Riverfront modern condo near Pearl
#                   </h3>
# </a>
# <div class="text-muted listing-location text-truncate" itemprop="description"><a class="text-normal link-reset" href="/rooms/4652582?checkin=09%2F16%2F2015&amp;checkout=09%2F22%2F2015&amp;guests=4&amp;s=zhhI">
#   Entire home/apt
#      · <small> <div class="star-rating">
# <div class="foreground">
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# </div>
# <div class="background">
# <i class="icon icon-star icon-light-gray"></i>
# <i class="icon icon-star icon-light-gray"></i>
# <i class="icon icon-star icon-light-gray"></i>
# <i class="icon icon-star icon-light-gray"></i>
# <i class="icon icon-star icon-light-gray"></i>
# </div>
# </div>
# </small>
#      · 7 reviews
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-sm-12 row-space-2 col-md-6">
# <div class="listing" data-id="1943748" data-lat="45.52351979507172" data-lng="-122.64481835926598" data-name="Classic Close-In Portland" data-price="&lt;sup&gt;$&lt;/sup&gt;195&lt;sup&gt;&lt;/sup&gt;" data-url="/rooms/1943748?checkin=09%2F16%2F2015&amp;checkout=09%2F22%2F2015&amp;guests=4&amp;s=zhhI" data-user="10053932" itemscope="" itemtype="http://schema.org/Enumeration">
# <div class="panel-image listing-img">
# <div class="listing-description wl-data-1943748">
# <div class="summary">
# <p>
#                       My spacious 3 bedroom house is a classic "Portland style" home with hardwood floors and art by local artists throughout. Located about a mile from downtown it's centrally located and a great base for exploring the city on foot, by bike, public transit, or car.
#                         <a class="learn-more" href="#" id="tooltip-sticky-1943748">Learn More</a>
# </p>
# <div aria-hidden="true" class="tooltip tooltip-top-middle" data-trigger="#tooltip-sticky-1943748" role="tooltip">
# <p class="panel-body">
#
#
# The first floor has an open layout that includes a living room with a gas fireplace for chilly days. South-facing French doors open onto an elevated front deck that is surrounded by foliage, so you can watch the world go by without being on stage. The kitchen has a retro chrome cafe table for quick meals, and there's a formal dining room in the living room. There is a half bath off the kitchen and a stereo and turntable with lots of records and CDs.
#
# One bedroom, a media room, and the bathr...
#                         </p>
# </div>
# </div>
# <p class="address">Buckman, Portland</p>
# <div class="details row-space-2"><div class="row">
# <div class="col-5">
# <div>Room type: <strong>Entire home/apt</strong></div>
# <div>Property type: <strong>House</strong></div>
# <div>Accommodates: <strong>6</strong></div>
# </div>
# <div class="col-5">
# <div>Bedrooms: <strong>3</strong></div>
# <div>Bathrooms: <strong>1.5</strong></div>
# </div>
# </div>
# </div>
# </div>
# <a class="media-photo media-cover" href="/rooms/1943748?checkin=09%2F16%2F2015&amp;checkout=09%2F22%2F2015&amp;guests=4&amp;s=zhhI" target="listing_1943748">
# <div class="listing-img-container media-cover text-center">
# <img alt="Classic Close-In Portland" class="img-responsive-height hide" data-current="0" data-urls='["https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.muscache.com/ac/pictures/59246739/3ab7ba0f_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a2.muscache.com/ac/pictures/59246481/bb8a0dc7_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.muscache.com/ac/pictures/59246490/c1bcdd44_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.muscache.com/ac/pictures/59246504/2ff1575b_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.muscache.com/ac/pictures/59246518/c149667e_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a1.muscache.com/ac/pictures/59246525/f3d9e682_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a1.muscache.com/ac/pictures/59246540/50752183_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.muscache.com/ac/pictures/59246551/f243ff3c_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a2.muscache.com/ac/pictures/59246564/6310cc4c_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a2.muscache.com/ac/pictures/59246583/6b5bc4ed_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a2.muscache.com/ac/pictures/59246597/1fa30dc9_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.muscache.com/ac/pictures/59246613/30ec6ee6_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a1.muscache.com/ac/pictures/59246629/59c31ff5_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a1.muscache.com/ac/pictures/59246639/10097535_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a2.muscache.com/ac/pictures/59246663/f5ab77ce_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a1.muscache.com/ac/pictures/59246688/8489b354_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a1.muscache.com/ac/pictures/59246699/5a4d33d2_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.muscache.com/ac/pictures/59246713/0af54a98_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a2.muscache.com/ac/pictures/59246728/bc92e15d_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a2.muscache.com/ac/pictures/59246754/992f3bac_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a1.muscache.com/ac/pictures/59246764/9fcd1337_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a2.muscache.com/ac/pictures/59246780/29f7121b_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.muscache.com/ac/pictures/59246789/ee1d360d_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.muscache.com/ac/pictures/26987376/831090f9_original.jpg?interpolation=l ...
# </div>
# </a>
# <div class="target-prev target-control block-link">
# <i class="icon icon-chevron-left icon-size-2 icon-white"></i>
# </div>
# <a class="link-reset panel-overlay-bottom-left panel-overlay-label panel-overlay-listing-label" href="/rooms/1943748?checkin=09%2F16%2F2015&amp;checkout=09%2F22%2F2015&amp;guests=4&amp;s=zhhI" target="listing_1943748">
# <div>
# <sup class="h6 text-contrast">$</sup>
# <span class="h3 text-contrast price-amount">195</span>
# <sup class="h6 text-contrast"></sup>
# </div>
# </a>
# <div class="target-next target-control block-link">
# <i class="icon icon-chevron-right icon-size-2 icon-white"></i>
# </div>
# <div class="panel-overlay-top-right wl-social-connection-panel">
# <span class="rich-toggle wish_list_button wishlist-button" data-address="Buckman, Portland" data-hosting_id="1943748" data-img="https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70" data-name="Classic Close-In Portland">
# <input data-for-hosting="1943748" id="wishlist-widget-1943748" name="wishlist-widget-1943748" type="checkbox"/>
# <label class="hide-sm" for="wishlist-widget-1943748">
# <span class="screen-reader-only">Wishlist</span>
# <i class="icon icon-heart icon-rausch icon-size-2 rich-toggle-checked"></i>
# <i class="icon icon-heart wishlist-heart-unchecked icon-size-2 rich-toggle-unchecked"></i>
# <i class="icon icon-heart-alt icon-white icon-size-2"></i>
# </label>
# </span>
# </div>
# </div>
# <div class="panel-body panel-card-section">
# <div class="media">
# <a class="media-photo-badge pull-right card-profile-picture card-profile-picture-offset" href="/users/show/10053932">
# <div class="media-photo media-round">
# <img alt="" src="https://a2.muscache.com/ac/users/10053932/profile_pic/1384651532/original.jpg?interpolation=lanczos-none&amp;crop=w:w;*,*&amp;crop=h:h;*,*&amp;resize=68:*&amp;output-format=jpg&amp;output-quality=70"/>
# </div>
# </a>
# <a class="text-normal" href="/rooms/1943748?checkin=09%2F16%2F2015&amp;checkout=09%2F22%2F2015&amp;guests=4&amp;s=zhhI" target="listing_1943748">
# <h3 class="h5 listing-name text-truncate row-space-top-1" itemprop="name" title="Classic Close-In Portland">
#                     Classic Close-In Portland
#                   </h3>
# </a>
# <div class="text-muted listing-location text-truncate" itemprop="description"><a class="text-normal link-reset" href="/rooms/1943748?checkin=09%2F16%2F2015&amp;checkout=09%2F22%2F2015&amp;guests=4&amp;s=zhhI">
#   Entire home/apt
#      · <small> <div class="star-rating">
# <div class="foreground">
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# </div>
# <div class="background">
# <i class="icon icon-star icon-light-gray"></i>
# <i class="icon icon-star icon-light-gray"></i>
# <i class="icon icon-star icon-light-gray"></i>
# <i class="icon icon-star icon-light-gray"></i>
# <i class="icon icon-star icon-light-gray"></i>
# </div>
# </div>
# </small>
#      · 53 reviews
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-sm-12 row-space-2 col-md-6">
# <div class="listing" data-id="4923100" data-lat="45.50995521584085" data-lng="-122.6069179189456" data-name="Mt. Tabor Cozy Basement Suite" data-price="&lt;sup&gt;$&lt;/sup&gt;75&lt;sup&gt;&lt;/sup&gt;" data-url="/rooms/4923100?checkin=09%2F16%2F2015&amp;checkout=09%2F22%2F2015&amp;guests=4&amp;s=zhhI" data-user="25357111" itemscope="" itemtype="http://schema.org/Enumeration">
# <div class="panel-image listing-img">
# <div class="listing-description wl-data-4923100">
# <div class="summary">
# <p>
#                       Our Mt. Tabor suite sleeps 4, has radiant floors, tv/WiFi, wash/dryer, private bath and entrance. We are blocks from Hawthorne/Division district, food carts, Mt. Tabor Park. Take public transit downtown. We serve home-roasted coffee &amp; our hens' eggs.
#                         <a class="learn-more" href="#" id="tooltip-sticky-4923100">Learn More</a>
# </p>
# <div aria-hidden="true" class="tooltip tooltip-top-middle" data-trigger="#tooltip-sticky-4923100" role="tooltip">
# <p class="panel-body">
#
#
# We have a very bright basement suite, where guests will have private parking, a private entrance with a key code lock, a private bath and radiant floor heating. They will have the entire space to themselves. There is a small food preparation area with a mini-fridge and toaster-oven.
#
# We have a 50 inch TV and WiFi, as well as Netflix access.
# We roast our own coffee beans fresh the day before, and serve our own chicken and duck eggs for breakfast.
# If timing is right, you can enjoy fresh raspb...
#                         </p>
# </div>
# </div>
# <p class="address">Mt. Tabor, Portland</p>
# <div class="details row-space-2"><div class="row">
# <div class="col-5">
# <div>Room type: <strong>Private room</strong></div>
# <div>Property type: <strong>House</strong></div>
# <div>Accommodates: <strong>4</strong></div>
# </div>
# <div class="col-5">
# <div>Bedrooms: <strong>1</strong></div>
# <div>Bathrooms: <strong>1</strong></div>
# </div>
# </div>
# </div>
# </div>
# <a class="media-photo media-cover" href="/rooms/4923100?checkin=09%2F16%2F2015&amp;checkout=09%2F22%2F2015&amp;guests=4&amp;s=zhhI" target="listing_4923100">
# <div class="listing-img-container media-cover text-center">
# <img alt="Mt. Tabor Cozy Basement Suite" class="img-responsive-height hide" data-current="0" data-urls='["https://a1.muscache.com/ac/pictures/86065280/c7d49cc5_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.muscache.com/ac/pictures/78771539/06847680_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a1.muscache.com/ac/pictures/86437558/56cfc90b_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a1.muscache.com/ac/pictures/78771572/57fc53b4_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a1.muscache.com/ac/pictures/79089460/660e91af_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a2.muscache.com/ac/pictures/79089876/de50ef4f_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.muscache.com/ac/pictures/79089928/6582cdd2_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a1.muscache.com/ac/pictures/79197992/2832b373_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a1.muscache.com/ac/pictures/79203398/3f12d5f4_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.muscache.com/ac/pictures/79209355/dc749996_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.muscache.com/ac/pictures/79644635/aad5c58b_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a1.muscache.com/ac/pictures/79646186/285c5150_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.muscache.com/ac/pictures/79646902/2ca8efd0_original.jpg?interpolation=lanczos-none&amp;size=x_medium&amp;output-format=jpg&amp;output-quality=70", "https://a0.' src="https://a2.muscache.com/airbnb/static/page3/v3/room_default_no_photos-90b75fadaf2d12ac60c0fd29a8537387.png"/></div></a></div></div></div></div></div></div></div></div></div></main></body></html>

# %%
listings_raw = soup.find_all("div", {"class": "listing"})

len(listings_raw)
# Out:
# 8

# %% [markdown]
# It's here I must note, that there should be 18 listings on each page (or thereabouts, specifically if its on the first page). This is confirmed by doing ctrl-f on the page and searching for *class="listing"*. This gives you 18 results. However, in our parsed soup object, we only get 8 back.
#
# Based on the [BeautifulSoup documentation](http://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser), this might be due to old parsers.  I tried both html.parser & lxml. I couldn't get html5lib working on my machine. My guess is that there is something in the code, a broken tag or JS or divception with a broken tag somewhere, that is causing this.
#
# Again, for the purposes of our project, we just need a representative sample, and being able to get the top 8+ is useful enough.  In our EDA, we'll definately explore how many listings we find on each page.

# %%
# Lets grab a bunch of information that we'll need:
def extract_thumbnail_data(listing):
    cur_data = {}
    listing_id = listing['data-id']
    cur_data['listing_id'] = listing_id

    cur_data['lat'] = listing['data-lat']
    cur_data['lng'] = listing['data-lng']

    # cur_data['thumbnail_img'] = listing.find("img")['src']    # Old Image
    if listing.find('img') != None:
        tmp_img = listing.find('img')['data-urls'][2:]
        tmp_img = tmp_img[:tmp_img.find("\"")]
        cur_data['thumbnail_img'] = tmp_img
    else:
        cur_data['thumbnail_img'] = "/no_thumbnail.jpg"

    cur_data['blurb'] = listing['data-name']

    if listing.find("span"):
        cur_data['thumbnail_price'] = listing.find("span").get_text()
    else:
        cur_data['thumbnail_price'] = "n/a"

    if listing.find("div", {'itemprop':"description"}):
        if listing.find("div", {'itemprop':"description"}).find('a'):
            tmp = listing.find("div", {'itemprop':"description"}).find('a').get_text()
            if tmp.find(u'\xb7') != -1:
                tmp=tmp[:tmp.find(u'\xb7')]
            cur_data['listing_type'] = tmp
        else:
            cur_data['listing_type'] = "not available"
    else:
        cur_data['listing_type'] = "not available"


    return cur_data

# %%
for listing in listings_raw:
    t = extract_thumbnail_data(listing)
    for x in t:
        print "%s: %s" % (x, t[x])
# Out:
# listing_id: 4963976
# thumbnail_price: 167
# thumbnail_img: https://a2.muscache.com/ac/pictures/62186231/8ee4277e_original.jpg?interpolation=lanczos-none&size=x_medium&output-format=jpg&output-quality=70
# lat: 45.55706779081872
# lng: -122.63691374623141
# listing_type:
#   Entire home/apt
#
# blurb: Handbuilt Alberta Arts Cottage
# listing_id: 3167041
# thumbnail_price: 122
# thumbnail_img: https://a1.muscache.com/ac/pictures/41482889/c7c1259e_original.jpg?interpolation=lanczos-none&size=x_medium&output-format=jpg&output-quality=70
# lat: 45.557603765748595
# lng: -122.63400815862627
# listing_type:
#   Entire home/apt
#
# blurb: Awesome Alberta Arts loft apartment
# listing_id: 6560720
# thumbnail_price: 122
# thumbnail_img: https://a1.muscache.com/ac/pictures/83530370/1039e84a_original.jpg?interpolation=lanczos-none&size=x_medium&output-format=jpg&output-quality=70
# lat: 45.53139419479622
# lng: -122.69989668431994
# listing_type:
#   Entire home/apt
#
# blurb: Apartment in Portland's Nob Hill
# listing_id: 6302989
# thumbnail_price: 148
# thumbnail_img: https://a0.muscache.com/ac/pictures/84617954/f4e4b77d_original.jpg?interpolation=lanczos-none&size=x_medium&output-format=jpg&output-quality=70
# lat: 45.56168265933678
# lng: -122.65601225823345
# listing_type:
#   Entire home/apt
#
# blurb: Beautiful Alberta Arts Home
# listing_id: 6286834
# thumbnail_price: 140
# thumbnail_img: https://a0.muscache.com/ac/pictures/82342020/8aae9760_original.jpg?interpolation=lanczos-none&size=x_medium&output-format=jpg&output-quality=70
# lat: 45.52134345745293
# lng: -122.648815139839
# listing_type:
#   Entire home/apt
#
# blurb: Mid-Century Mid-PDX Designer Nest
# listing_id: 4652582
# thumbnail_price: 168
# thumbnail_img: https://a0.muscache.com/ac/pictures/58435894/fb85eaea_original.jpg?interpolation=lanczos-none&size=x_medium&output-format=jpg&output-quality=70
# lat: 45.52463260324067
# lng: -122.67055191370818
# listing_type:
#   Entire home/apt
#
# blurb: Riverfront modern condo near Pearl
# listing_id: 1943748
# thumbnail_price: 195
# thumbnail_img: https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&size=x_medium&output-format=jpg&output-quality=70
# lat: 45.52351979507172
# lng: -122.64481835926598
# listing_type:
#   Entire home/apt
#
# blurb: Classic Close-In Portland
# listing_id: 4923100
# thumbnail_price: n/a
# thumbnail_img: https://a1.muscache.com/ac/pictures/86065280/c7d49cc5_original.jpg?interpolation=lanczos-none&size=x_medium&output-format=jpg&output-quality=70
# lat: 45.50995521584085
# lng: -122.6069179189456
# listing_type: not available
# blurb: Mt. Tabor Cozy Basement Suite

# %% [markdown]
# Great! So for every listing in the search result, we now have great information about it, including:
# - The listing name & id
# - a blurb, or mini-description (seperate from the full description we'll scrape later)
# - an image to work with
# - the lat & lng of the listing (YASS!!!!!!)
# - listing type for most (though, not all)
# - the price for most (though, not all)
#
# Where this information will come in handy is when our app does live scrapes.  We'll want to grab a lot of the information to use before we ever scrape the listing.

# %% [markdown]
# Using the above code as a template, I was able to create **'scrape_search_results.py'**
#
# This script is used to scrape AirBnB's search result pages for its content
# * takes in a file ('../data/city_list.csv')
# * generates a sampling of dates (1)
# * scrapes AirBnB's searchlings
#
# (1) I keyed in on 2 day availabilities from Tues-Thurs & Fri-Sun from June-Dec), to get a good representative sample of listings
#
# I also run the **'extract_listings_from_search_results.py'** file, which inserts all of the listings found in search results into a listings collection. This essentially "initializes" the listings collection
#
# Again, the reason for the above split was to scrape the data from AirBnB (/slash/ not get banned) and to seperate the scraping from the feature extraction.
#
# The majority of the functions are based on the AirBnBNeighborhood class in **'airbnb/airbnbsearchresult.py'**, whose methods help.
#
# Notes:
# * I ran the **'scrape_search_results.py'** file multiple times.  There was one time where I closed my computer mid-run. Not cool. It corrupted a file in my MongoDB colleciton and I had to scrape all of the information again. Lesson Learned.
# * There is likely duplicate runs in the production database. For the most part, I don't care what search results are returned, so much as I have a bevy of listings from which to pull (or try to pull) data. It does not impact my project

# %% [markdown]
# ###Extracting data from AirBnB's Search Results

# %%
import requests
from bs4 import BeautifulSoup

# %%
# lets scrape an example search result to see what we're working with
# https://www.airbnb.com/rooms/1943748 (from above)
# Note, when clicking through from a search, you get the parameters passed in the URL
# https://www.airbnb.com/rooms/19463748?checkin=09%2F16%2F2015&checkout=09%2F22%2F2015&guests=4&s=XKml
r = requests.get('https://www.airbnb.com/rooms/1943748')

# %%
soup = BeautifulSoup(r.content)
soup.prettify
# Out:
# <bound method BeautifulSoup.prettify of <!DOCTYPE html>
# <!--[if lt IE 8]>
#
# <html lang="en"
#
#       xmlns:fb="http://ogp.me/ns/fb#"
#       class="ie">
#
# <![endif]--><!--[if IE 8]>
#
# <html lang="en"
#
#       xmlns:fb="http://ogp.me/ns/fb#"
#       class="ie ie8">
#
# <![endif]--><!--[if IE 9]>
#
#   <html lang="en"
#
#       xmlns:fb="http://ogp.me/ns/fb#"
#       class="ie ie9">
#
# <![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html lang="en" xmlns:fb="http://ogp.me/ns/fb#">
# <!--<![endif]-->
# <head>
# <link href="//maps.googleapis.com" rel="dns-prefetch"/>
# <link href="//maps.gstatic.com" rel="dns-prefetch"/>
# <link href="//mts0.googleapis.com" rel="dns-prefetch"/>
# <link href="//mts1.googleapis.com" rel="dns-prefetch"/>
# <!--[if IE]><![endif]-->
# <meta charset="utf-8"/>
# <!--[if IE 8]>
#       <link href="https://a1.muscache.com/airbnb/static/packages/common_o2.1_ie8-8341a24cc71ce465b36585d097252e3d.css" media="all" rel="stylesheet" type="text/css" />
#     <![endif]-->
# <!--[if !(IE 8)]><!-->
# <link href="https://a2.muscache.com/airbnb/static/packages/common_o2.1-8df429488967e76a242511e286c9cf15.css" media="all" rel="stylesheet" type="text/css"/>
# <!--<![endif]-->
# <!--[if lt IE 9]>
#       <link href="https://a0.muscache.com/airbnb/static/compatibility/airglyphs-ie8-7dbf8372f80fb3fd70a35c7acaf4b6ec.css" media="all" rel="stylesheet" type="text/css" />
#     <![endif]-->
# <!--[if IE]>
#   <link href="https://a1.muscache.com/airbnb/static/p3/p3_ie-51d81e0aeb02fc953c4ce5eb275fb1a3.css" media="screen" rel="stylesheet" type="text/css" />
#   <![endif]-->
# <link href="https://a2.muscache.com/airbnb/static/packages/p3-8dd7631ea8617cbca6303e8b296f583d.css" media="screen" rel="stylesheet" type="text/css"/>
# <meta content="authenticity_token" id="csrf-param-meta-tag" name="csrf-param"/>
# <meta content="" id="csrf-token-meta-tag" name="csrf-token"/>
# <script>
#
#       var sherlock_firstbyte = Number(new Date());
# </script>
# <title>Classic Close-In Portland in Portland</title>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="https://www.airbnb.com/rooms/1943748" rel="canonical"/>
# <link href="https://es.airbnb.com/rooms/1943748" hreflang="es" rel="alternate"/>
# <link href="https://fr.airbnb.be/rooms/1943748" hreflang="fr-BE" rel="alternate"/>
# <link href="https://fr.airbnb.ca/rooms/1943748" hreflang="fr-CA" rel="alternate"/>
# <link href="https://fr.airbnb.ch/rooms/1943748" hreflang="fr-CH" rel="alternate"/>
# <link href="https://it.airbnb.ch/rooms/1943748" hreflang="it-CH" rel="alternate"/>
# <link href="https://th.airbnb.com/rooms/1943748" hreflang="th" rel="alternate"/>
# <link href="https://www.airbnb.at/rooms/1943748" hreflang="de-AT" rel="alternate"/>
# <link href="https://www.airbnb.be/rooms/1943748" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.airbnb.ca/rooms/1943748" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.airbnb.cat/rooms/1943748" hreflang="ca" rel="alternate"/>
# <link href="https://www.airbnb.ch/rooms/1943748" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.airbnb.cl/rooms/1943748" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.airbnb.co.cr/rooms/1943748" hreflang="es-CR" rel="alternate"/>
# <link href="https://www.airbnb.co.id/rooms/1943748" hreflang="id" rel="alternate"/>
# <link href="https://www.airbnb.co.in/rooms/1943748" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.airbnb.co.kr/rooms/1943748" hreflang="ko" rel="alternate"/>
# <link href="https://www.airbnb.co.nz/rooms/1943748" hreflang="en-NZ" rel="alternate"/>
# <link href="https://www.airbnb.co.uk/rooms/1943748" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.airbnb.co.ve/rooms/1943748" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.airbnb.com/rooms/1943748" hreflang="en" rel="alternate"/>
# <link href="https://www.airbnb.com.ar/rooms/1943748" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.airbnb.com.au/rooms/1943748" hreflang="en-AU" rel="alternate"/>
# <link href="https://www.airbnb.com.bo/rooms/1943748" hreflang="es-BO" rel="alternate"/>
# <link href="https://www.airbnb.com.br/rooms/1943748" hreflang="pt" rel="alternate"/>
# <link href="https://www.airbnb.com.bz/rooms/1943748" hreflang="es-BZ" rel="alternate"/>
# <link href="https://www.airbnb.com.co/rooms/1943748" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.airbnb.com.ec/rooms/1943748" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.airbnb.com.gt/rooms/1943748" hreflang="es-GT" rel="alternate"/>
# <link href="https://www.airbnb.com.hk/rooms/1943748" hreflang="zh-HK" rel="alternate"/>
# <link href="https://www.airbnb.com.hn/rooms/1943748" hreflang="es-HN" rel="alternate"/>
# <link href="https://www.airbnb.com.mt/rooms/1943748" hreflang="en-MT" rel="alternate"/>
# <link href="https://www.airbnb.com.my/rooms/1943748" hreflang="ms" rel="alternate"/>
# <link href="https://www.airbnb.com.ni/rooms/1943748" hreflang="es-NI" rel="alternate"/>
# <link href="https://www.airbnb.com.pa/rooms/1943748" hreflang="es-PA" rel="alternate"/>
# <link href="https://www.airbnb.com.pe/rooms/1943748" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.airbnb.com.py/rooms/1943748" hreflang="es-PY" rel="alternate"/>
# <link href="https://www.airbnb.com.sg/rooms/1943748" hreflang="en-SG" rel="alternate"/>
# <link href="https://www.airbnb.com.sv/rooms/1943748" hreflang="es-SV" rel="alternate"/>
# <link href="https://www.airbnb.com.tr/rooms/1943748" hreflang="tr" rel="alternate"/>
# <link href="https://www.airbnb.com.tw/rooms/1943748" hreflang="zh-TW" rel="alternate"/>
# <link href="https://www.airbnb.cz/rooms/1943748" hreflang="cs" rel="alternate"/>
# <link href="https://www.airbnb.de/rooms/1943748" hreflang="de" rel="alternate"/>
# <link href="https://www.airbnb.dk/rooms/1943748" hreflang="da" rel="alternate"/>
# <link href="https://www.airbnb.es/rooms/1943748" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.airbnb.fi/rooms/1943748" hreflang="fi" rel="alternate"/>
# <link href="https://www.airbnb.fr/rooms/1943748" hreflang="fr" rel="alternate"/>
# <link href="https://www.airbnb.gr/rooms/1943748" hreflang="el" rel="alternate"/>
# <link href="https://www.airbnb.gy/rooms/1943748" hreflang="en-GY" rel="alternate"/>
# <link href="https://www.airbnb.hu/rooms/1943748" hreflang="hu" rel="alternate"/>
# <link href="https://www.airbnb.ie/rooms/1943748" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.airbnb.is/rooms/1943748" hreflang="is" rel="alternate"/>
# <link href="https://www.airbnb.it/rooms/1943748" hreflang="it" rel="alternate"/>
# <link href="https://www.airbnb.jp/rooms/1943748" hreflang="ja" rel="alternate"/>
# <link href="https://www.airbnb.mx/rooms/1943748" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.airbnb.nl/rooms/1943748" hreflang="nl" rel="alternate"/>
# <link href="https://www.airbnb.no/rooms/1943748" hreflang="no" rel="alternate"/>
# <link href="https://www.airbnb.pl/rooms/1943748" hreflang="pl" rel="alternate"/>
# <link href="https://www.airbnb.pt/rooms/1943748" hreflang="pt-PT" rel="alternate"/>
# <link href="https://www.airbnb.ru/rooms/1943748" hreflang="ru" rel="alternate"/>
# <link href="https://www.airbnb.se/rooms/1943748" hreflang="sv" rel="alternate"/>
# <link href="https://zh.airbnb.com/rooms/1943748" hreflang="zh" rel="alternate"/>
# <link href="android-app://com.airbnb.android/airbnb/rooms/1943748" rel="alternate"/>
# <meta content="Entire home/apt for $138. My spacious 3 bedroom house is a classic &amp;quot;Portland style&amp;quot; home with hardwood floors and art by local artists throughout. Located about a mile from ..." name="description"/>
# <meta content="138566025676" property="fb:app_id"/>
# <meta content="Airbnb" property="og:site_name"/>
# <meta content="Classic Close-In Portland in Portland" property="og:title"/>
# <meta content="airbedandbreakfast:listing" property="og:type"/>
# <meta content="https://www.airbnb.com/rooms/1943748" property="og:url"/>
# <meta content="House in Portland, United States. My spacious 3 bedroom house is a classic &amp;quot;Portland style&amp;quot; home with hardwood floors and art by local artists throughout. Located about a mile from downtown it&amp;#x27;s centrally located and a great base for exploring the city on foot, by bike, public tra..." property="og:description"/>
# <meta content="https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&amp;size=x_large&amp;output-format=progressive-jpeg&amp;output-quality=70" property="og:image"/>
# <meta content="Portland" property="airbedandbreakfast:locality"/>
# <meta content="OR" property="airbedandbreakfast:region"/>
# <meta content="United States" property="airbedandbreakfast:country"/>
# <meta content="Portland" property="airbedandbreakfast:city"/>
# <meta content="5.0" property="airbedandbreakfast:rating"/>
# <meta content="45.52351979507172" property="airbedandbreakfast:location:latitude"/>
# <meta content="-122.64481835926598" property="airbedandbreakfast:location:longitude"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="on" name="twitter:widgets:csp"/>
# <meta content="photo" name="twitter:card"/>
# <meta content="https://www.airbnb.com/rooms/1943748" name="twitter:url"/>
# <meta content="https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&amp;size=x_large&amp;output-format=progressive-jpeg&amp;output-quality=70" name="twitter:image"/>
# <meta content="Classic Close-In Portland in Portland" name="twitter:title"/>
# <meta content="@airbnb" name="twitter:site"/>
# <meta content="Airbnb" name="twitter:app:name:iphone"/>
# <meta content="Airbnb" name="twitter:app:name:ipad"/>
# <meta content="Airbnb" name="twitter:app:name:googleplay"/>
# <meta content="401626263" name="twitter:app:id:iphone"/>
# <meta content="401626263" name="twitter:app:id:ipad"/>
# <meta content="com.airbnb.android" name="twitter:app:id:googleplay"/>
# <meta content="airbnb://rooms/1943748" name="twitter:app:url:iphone"/>
# <meta content="airbnb://rooms/1943748" name="twitter:app:url:ipad"/>
# <meta content="airbnb://rooms/1943748" name="twitter:app:url:googleplay"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&amp;size=x_large&amp;output-format=progressive-jpeg&amp;output-quality=70" rel="image_src"/>
# <link href="/opensearch.xml" rel="search" title="Airbnb" type="application/opensearchdescription+xml"/>
# <!--[if lte IE 9]>
#       <script src="https://a2.muscache.com/airbnb/static/packages/libs_ie_support-b79daf6f8ced9b9ee1d841fbcc88d2a7.js" type="text/javascript"></script>
#       <link href="https://a0.muscache.com/airbnb/respond-proxy.html" id="respond-proxy" rel="respond-proxy" />
#       <link href="/respond.proxy.gif" id="respond-redirect" rel="respond-redirect" />
#       <script src="/respond.proxy.js?cb=1"></script>
#     <![endif]-->
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="#f5f5f5" name="theme-color"/>
# <link href="https://a1.muscache.com/airbnb/static/icons/apple-touch-icon-76x76-29b6a802ddcbcada3e98c1336b078985.png" rel="apple-touch-icon"/>
# <link href="https://a1.muscache.com/airbnb/static/icons/apple-touch-icon-76x76-29b6a802ddcbcada3e98c1336b078985.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://a2.muscache.com/airbnb/static/icons/apple-touch-icon-120x120-f755fee8bec28959299b265351f0dee2.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://a1.muscache.com/airbnb/static/icons/apple-touch-icon-152x152-51479ae43400e03b95a33f5119c65262.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://a2.muscache.com/airbnb/static/icons/apple-touch-icon-180x180-830c8479ce4d0a3c9df95fdfeddf6faa.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://a0.muscache.com/airbnb/static/icons/android-icon-192x192-ab82dea1266beaa15c85fbed5bc45702.png" rel="icon" sizes="192x192"/>
# <link href="https://a1.muscache.com/airbnb/static/logotype_favicon-21cc8e6c6a2cca43f061d2dcabdf6e58.ico" rel="shortcut icon" sizes="76x76" type="image/x-icon"/>
# </head>
# <body class="no_wiggle_webkit">
# <a class="screen-reader-only screen-reader-only-focusable skip-to-content" data-hook="skip-to-content" href="#site-content" tabindex="1">
#       Skip to content
#     </a>
# <span class="screen-reader-only">
#       Airbnb
#     </span>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-46MK" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div aria-hidden="true" class="smart-banner" role="banner">
# <a class="icon icon-remove icon-size-1 pull-left link-reset banner-close" href="#">
# <span class="screen-reader-only">
#       Close
#     </span>
# </a>
# <a class="pull-left app-icon install-link action-link" data-href="http://r.yoz.io/l.c.hsjS" data-href-alt="http://r.yoz.io/l.c.hskj" href="#">
# <span class="screen-reader-only">
#       Install
#     </span>
# </a>
# <div class="banner-content">
# <div class="banner-title space-top-sm-1 space-top-md-3">
# <strong class="icon-dark-gray ios-item">
#         Airbnb for iOS
#       </strong>
# <strong class="icon-dark-gray android-item hide">
#         Airbnb for Android
#       </strong>
# <br class="android-item hide"/>
# <br class="ios-item hide-sm"/>
# <div class="star-rating">
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-star icon-light-gray"></i>
# </div>
# <small class="banner-reviews icon-gray ios-item">(5,268)</small>
# <small class="banner-reviews icon-gray android-item hide">(60,813)</small>
# </div>
# <div class="banner-buttons text-right space-top-sm-2 space-top-md-4">
# <a class="link-reset btn btn-primary btn-small banner-button install-link action-link" data-href="http://r.yoz.io/l.c.hsjS" data-href-alt="http://r.yoz.io/l.c.hskj" href="#">
#         Install
#       </a>
# <a class="btn btn-small banner-button open-in-app-button action-link" data-backup-href="http://r.yoz.io/l.c.hsjS" data-backup-href-alt="http://r.yoz.io/l.c.hskj" data-href="airbnb://" href="airbnb://">
#          Open in App
#       </a>
# </div>
# </div>
# </div>
# <div class="airbnb-header new " id="header">
# <header aria-hidden="true" class="header--sm show-sm" role="banner">
# <a aria-label="Homepage" class="link-reset burger--sm" data-prevent-default="" href="#">
# <i class="icon icon-reorder icon-rausch"></i>
# <span class="screen-reader-only">
#       Airbnb
#     </span>
# </a>
# <div class="title--sm text-center">
# <button class="btn btn-block search-btn--sm search-modal-trigger">
# <i class="icon icon-search icon-gray"></i>
# <span class="search-placeholder--sm">
#           Where are you going?
#         </span>
# </button>
# </div>
# <div class="action--sm"></div>
# <nav class="nav--sm" role="navigation"></nav>
# <div class="search-modal-container"></div>
# </header>
# <header class="regular-header clearfix hide-sm" id="old-header" role="banner">
# <a aria-label="Homepage" class="header-belo pull-left" href="/">
# <span class="screen-reader-only">
#       Airbnb
#     </span>
# </a>
# <ul class="nav pull-left hide-sm list-unstyled search-form-container" id="search-form-header">
# <li class="search-bar-wrapper pull-left medium-right-margin" id="header-search">
# <form action="/s" class="search-form" id="search-form">
# <div class="search-bar">
# <i class="icon icon-search icon-gray h4"></i>
# <label class="screen-reader-only" for="input-location">
#           Where are you going?
#         </label>
# <input autocomplete="off" class="location" data-date-placeholder="mm/dd/yyyy" id="input-location" name="location" placeholder="Where are you going?" type="text"/>
# <input name="source" type="hidden" value="hdr"/>
# </div>
# </form>
# </li>
# <li class="dropdown-trigger pull-left large-right-margin hide-sm hide" data-behavior="recently-viewed__container">
# <a class="no-crawl link-reset" data-behavior="recently-viewed__trigger" data-href="/history#docked-filters" href="#">
# <span class="show-lg recently-viewed__label">
#         Recently Viewed
#       </span>
# <span class="hide-lg recently-viewed__label">
# <i class="icon icon-recently-viewed icon-gray h4"></i>
# </span>
# <i class="icon icon-caret-down icon-light-gray h5"></i>
# </a>
# <div class="tooltip tooltip-top-left dropdown-menu recently-viewed__dropdown" data-behavior="recently-viewed__dropdown">
# </div>
# </li>
# <li class="browse-container dropdown-trigger pull-left hide-md">
# <a class="link-reset header-browse-trigger" data-prevent-default="" href="#" id="header-browse-trigger">
#   Browse
#    <i class="icon icon-caret-down icon-light-gray h5"></i>
# </a>
# <ul class="tooltip tooltip-top-left dropdown-menu list-unstyled">
# <li>
# <a class="link-reset menu-item header-browse-popular" href="/wishlists/popular">
#       Popular
#     </a>
# </li>
# <li>
# <a class="link-reset menu-item header-browse-friends" href="/wishlists/friends">
#       Friends
#     </a>
# </li>
# <li>
# <a class="link-reset menu-item header-browse-neighborhoods" href="/locations">
#       Neighborhoods
#     </a>
# </li>
# <li class="groups hide">
# <a class="no-crawl link-reset menu-item header-browse-groups" data-href="/groups" href="#" rel="nofollow">
#       Groups
#     </a>
# </li>
# <li>
# <a class="link-reset menu-item header-browse-vacation-rentals" href="/vacation-rentals">
#       Vacation Rentals
#     </a>
# </li>
# </ul>
# </li>
# </ul>
# <ul class="nav pull-right help-menu list-unstyled">
# <li class="help-menu-container pull-left large-right-margin hide-md dropdown-trigger" id="header-help-menu">
# <a class="help-toggle link-reset" href="/help" id="header-help-trigger">
#       Help
#       <i class="icon icon-caret-down icon-light-gray h5"></i>
# </a>
# <div class="tooltip tooltip-top-right dropdown-menu help-dropdown">
# <ul class="list-layout">
# <li class="search-bar--help hide">
# <form action="/help/search" class="search-form--help menu-item">
# <div class="input-addon">
# <input autocomplete="off" class="input-stem" name="q" placeholder="Search the help center" type="text"/>
# <input name="search_from" type="hidden" value="hdr"/>
# <i class="btn btn-primary icon icon-search input-suffix form-submit--help"></i>
# </div>
# </form>
# </li>
# <li class="visit-helpcenter-cta hide">
# <a class="help-center-link menu-item" href="/help">
#       Visit the Help Center »
#     </a>
# </li>
# <li class="loading"></li>
# <li class="all_faqs hide">
# <a class="link-reset menu-item" href="/help">
#       See all FAQs
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li class="list-your-space pull-left">
# <a class="btn btn-special list-your-space-btn hide" href="/rooms/new" id="list-your-space">
#           List Your Space
#         </a>
# </li>
# </ul>
# <ul class="nav pull-right logged-out list-unstyled medium-right-margin">
# <li class="pull-left medium-right-margin" id="sign_up">
# <a class="link-reset" data-header-view="true" data-redirect="redirect_params[action]=show&amp;redirect_params[controller]=rooms&amp;redirect_params[id]=1943748" data-signup-modal="" href="/signup_login">
#       Sign Up
#     </a>
# </li>
# <li class="pull-left" id="login">
# <a class="link-reset" data-login-modal="" data-redirect="redirect_params[action]=show&amp;redirect_params[controller]=rooms&amp;redirect_params[id]=1943748" href="/login">
#       Log In
#     </a>
# </li>
# </ul>
# <ul class="nav pull-right logged-in list-unstyled medium-right-margin">
# <li class="inbox-item pull-left dropdown-trigger js-inbox-comp" id="inbox-item">
# <a class="no-crawl link-reset inbox-icon" data-href="/inbox" href="#" rel="nofollow">
# <i class="alert-count fade text-center">0</i>
# <i class="icon icon-envelope icon-gray">
# <span class="text-hide hide">
#           Inbox
#         </span>
# </i>
# </a>
# <div class="tooltip tooltip-top-right dropdown-menu list-unstyled header-dropdown notifications-dropdown hide">
# </div>
# </li>
# </ul>
# <ul class="nav pull-right logged-in list-unstyled" role="navigation">
# <li class="user-item pull-left medium-right-margin dropdown-trigger">
# <a class="link-reset header-avatar-trigger" href="#" id="header-avatar-trigger">
# <div class="media-photo media-round user-profile-image"></div>
# <span class="value_name">
#         User
#       </span>
# <i class="icon icon-caret-down icon-light-gray h5"></i>
# </a>
# <ul class="tooltip tooltip-top-right dropdown-menu list-unstyled header-dropdown">
# <li>
# <a class="no-crawl link-reset menu-item item-dashboard" data-href="/home/dashboard" href="#" rel="nofollow">
#           Dashboard
#         </a>
# </li>
# <li class="listings">
# <a class="no-crawl link-reset menu-item item-listing" data-href="/rooms" href="#" rel="nofollow">
# <span class="singular" style="display: none;">
#             Your Listing
#           </span>
# <span class="plural">
#             Your Listings
#           </span>
# </a>
# </li>
# <li class="reservations" style="display: none;">
# <a class="no-crawl link-reset menu-item item-reservation" data-href="/my_reservations" href="#" rel="nofollow">
#            Your Reservations
#         </a>
# </li>
# <li>
# <a class="no-crawl link-reset menu-item item-trips" data-href="/trips/upcoming" href="#" rel="nofollow">
#           Your Trips
#         </a>
# </li>
# <li>
# <a class="no-crawl link-reset menu-item item-wishlists" data-href="/wishlists/my" href="#" id="wishlists">
#           Wish Lists
#         </a>
# </li>
# <li class="groups">
# <a class="no-crawl link-reset menu-item item-groups" data-href="/groups" href="#" rel="nofollow">
#           Groups
#         </a>
# </li>
# <li>
# <a class="no-crawl link-reset menu-item item-invite-friends" data-href="/invite?r=3" href="#">
#           Invite Friends
#           <span class="label label-pink label-new">
#             New
#           </span>
# </a>
# </li>
# <li>
# <a class="no-crawl link-reset menu-item item-user-edit" data-href="/users/edit" href="#" rel="nofollow">
#           Edit Profile
#         </a>
# </li>
# <li>
# <a class="no-crawl link-reset menu-item item-account" data-href="/account" href="#" rel="nofollow">
#           Account
#         </a>
# </li>
# <li class="business-travel hide">
# <a class="no-crawl link-reset menu-item item-business-travel" data-href="/business" href="#" rel="nofollow">
#           Business Travel
#         </a>
# </li>
# <li>
# <a class="no-crawl link-reset menu-item header-logout" data-href="/logout" href="#" rel="nofollow">
#           Log Out
#         </a>
# </li>
# </ul>
# </li>
# </ul>
# </header>
# <div class="regular-header regular-header--new clearfix hide-sm" id="new-header">
# <div class="comp pull-left">
# <a class="hdr-btn link-reset belo-container" href="/">
# <i class="icon icon-pos--lower icon-rausch icon-airbnb-alt h2 show-login"></i>
# <i class="icon icon-pos--lower icon-rausch icon-airbnb show-logout"></i>
# </a>
# </div>
# <div class="comp pull-left search-bar-wrapper">
# <form action="/s" class="search-form">
# <div class="search-bar">
# <i class="icon icon-search icon-gray h4"></i>
# <input autocomplete="off" class="location" data-date-placeholder="mm/dd/yyyy" name="location" placeholder="Where are you going?" type="text"/>
# <input name="source" type="hidden" value="hdr"/>
# </div>
# </form>
# </div>
# <div id="header-help-menu">
# <div class="comp pull-right help-trigger-wrapper no-border background-light-gray ">
# <a class="hdr-btn help-toggle link-reset" href="/help">
# <span class="margin-right--tiny">Help</span>
# <i class="icon-chevron-down-alt hide-md icon-chevron-down-alt-gray"></i>
# </a>
# </div>
# </div>
# <div class="comp-on-right">
# <div class="comp pull-right show-host">
# <a class="no-crawl hdr-btn link-reset " data-href="/dashboard" href="#" rel="nofollow">
# <i class="icon icon-host-home-alt h3 margin-right--small icon-pos--lower icon-gray"></i>
# <span class="hide-md margin-right--tiny">
#       Host
#     </span>
# <i class="icon-chevron-down-alt hide-md icon-chevron-down-alt-gray"></i>
# </a>
# <div class="panel tooltip tooltip-top-right drop-down-menu host-tooltip--new">
# <ul class="menu-list list-layout">
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/dashboard" href="#">Dashboard</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/rooms" href="#">Manage Listings</a>
# </li>
# <li class="menu-list__item">
# <a class="menu-list__item-block link-reset" href="/rooms/new">List Your Space</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/my_reservations" href="#">Your Reservations</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/users/reviews" href="#">Reviews</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/groups" href="#">Groups</a>
# </li>
# <li class="menu-list__item">
# <a class="menu-list__item-block link-reset" href="/hospitality">Hospitality</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="comp pull-right hide-host">
# <a class="hdr-btn link-reset " href="/rooms/new">
# <i class="icon icon-host-home-alt h3 margin-right--small icon-pos--lower icon-gray"></i>
# <span class="hide-md margin-right--tiny">
#       Become a Host
#     </span>
# </a>
# </div>
# </div>
# <div class="comp pull-right show-login">
# <a class="no-crawl hdr-btn link-reset js-inbox-comp " data-href="/inbox" href="#" rel="nofollow">
# <div class="inbox-icon-container text-center">
# <i class="icon icon-envelope h3 icon-pos--lower icon-gray">
# <span class="text-hide hide">Inbox</span>
# </i>
# <i class="alert-count text-center fade">0</i>
# </div>
# </a>
# <div class="tooltip tooltip-top-right panel drop-down-menu notifications-dropdown hide">
# </div>
# </div>
# <div class="comp pull-right show-login">
# <a class="no-crawl hdr-btn link-reset header-avatar-trigger" data-href="/dashboard" data-href-host="/trips" href="#" rel="nofollow">
# <div class="media-photo media-round normal-line-height user-profile-image margin-right--tiny"></div>
# <span class="value_name margin-right--tiny hide-md"></span>
# <i class="icon-chevron-down-alt hide-md icon-chevron-down-alt-gray"></i>
# </a>
# <div class="panel tooltip tooltip-top-right drop-down-menu avatar-tooltip--new">
# <ul class="menu-list list-layout">
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/trips" href="#">Your Trips</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/wishlists/popular" href="#">Wish Lists</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/users/edit" href="#">Edit Profile</a>
# </li>
# <li class="menu-list__item">
# <a class="menu-list__item-block link-reset" href="/invite">Invite Friends</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/users/notifications" href="#">Account Settings</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/logout" href="#">Log Out</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="comp pull-right show-logout">
# <a class="hdr-btn link-reset" data-header-view="true" data-redirect="redirect_params[action]=show&amp;redirect_params[controller]=rooms&amp;redirect_params[id]=1943748" data-signup-modal="" href="/signup_login">
#     Sign Up
#   </a>
# </div>
# <div class="comp pull-right show-logout">
# <a class="hdr-btn link-reset" data-login-modal="" data-redirect="redirect_params[action]=show&amp;redirect_params[controller]=rooms&amp;redirect_params[id]=1943748" href="/login">
#     Log In
#   </a>
# </div>
# <div class="comp-on-left">
# <div class="comp pull-right show-host">
# <a class="no-crawl hdr-btn link-reset " data-href="/dashboard" href="#" rel="nofollow">
# <i class="icon icon-host-home-alt h3 margin-right--small icon-pos--lower icon-gray"></i>
# <span class="hide-md margin-right--tiny">
#       Host
#     </span>
# <i class="icon-chevron-down-alt hide-md icon-chevron-down-alt-gray"></i>
# </a>
# <div class="panel tooltip tooltip-top-right drop-down-menu host-tooltip--new">
# <ul class="menu-list list-layout">
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/dashboard" href="#">Dashboard</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/rooms" href="#">Manage Listings</a>
# </li>
# <li class="menu-list__item">
# <a class="menu-list__item-block link-reset" href="/rooms/new">List Your Space</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/my_reservations" href="#">Your Reservations</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/users/reviews" href="#">Reviews</a>
# </li>
# <li class="menu-list__item">
# <a class="no-crawl menu-list__item-block link-reset" data-href="/groups" href="#">Groups</a>
# </li>
# <li class="menu-list__item">
# <a class="menu-list__item-block link-reset" href="/hospitality">Hospitality</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="comp pull-right hide-host">
# <a class="hdr-btn link-reset " href="/rooms/new">
# <i class="icon icon-host-home-alt h3 margin-right--small icon-pos--lower icon-gray"></i>
# <span class="hide-md margin-right--tiny">
#       Become a Host
#     </span>
# </a>
# </div>
# </div>
# <div class="comp pull-right hide" data-behavior="recently-viewed__container">
# <div>
# <a class="no-crawl hdr-btn link-reset " data-behavior="recently-viewed__trigger" data-href="/history#docked-filters" href="#">
# <i class="icon icon-recently-viewed h3 margin-right--small icon-pos--lower icon-gray"></i>
# <span class="hide-md margin-right--tiny">
#         Recently Viewed
#       </span>
# <i class="icon-chevron-down-alt hide-md icon-chevron-down-alt-gray"></i>
# </a>
# </div>
# <div class="panel tooltip tooltip-top-right drop-down-menu host-tooltip--new recently-viewed__dropdown" data-behavior="recently-viewed__dropdown">
# </div>
# </div>
# </div>
# </div>
# <noscript>
# <div class="alert alert-with-icon alert-error no-js-alert">
# <i class="icon alert-icon icon-alert-alt"></i>
#         We’re sorry, some parts of the Airbnb website don’t work properly without JavaScript enabled.
#
# </div>
# </noscript>
# <!-- This has to be here as field_guide3 is used in init() -->
# <meta content='{"flags":{"name":"flags","value":{"can_see_community":2,"og_publish":16,"has_wishlisted":32,"update_cached":64,"revert_to_admin":128,"facebook_connected":256,"erf_override":512,"has_search":1024,"search_help_dropdown":2048,"has_dates":4096,"can_see_notifications_tooltip":8192,"can_send_profile_messages":32768,"just_logged_in":65536,"has_been_host":131072,"should_drop_pellet":262144,"field_guide_preload":524288,"is_active_host":1048576,"is_business_travel_manager":2097152,"can_see_availability_rules":33554432,"is_vr_platform_powered_host":67108864,"can_see_meetups":134217728,"should_drop_sift_pellet":268435456,"can_see_groups":536870912,"has_verified_phone":1073741824,"has_profile_pic":2147483648}},"roles":{"name":"roles","value":{"is_content_manager":1048576,"is_stats_admin":16777216}},"user_attributes":{"name":"_user_attributes"}}' id="_bootstrap-user-attr-cookies"/>
# <meta content='{"use_business_travel_header":null}' id="_bootstrap-header-init"/>
# <meta content='{"hca_contact_me":{"subject":"bev","buckets":100,"percent_exposed":100,"treatments":[{"name":"control","buckets":100},{"name":"hide_contact_me","buckets":0}]},"inspectlet_on_guest":{"subject":"bev","buckets":2,"percent_exposed":1,"treatments":[{"name":"control","buckets":null},{"name":"inspectlet_active","buckets":null}]},"superhost_badge_host_pics":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"dont_show_superhost_badges","buckets":null},{"name":"show_superhost_badges","buckets":null}]},"p2_p3_encourage_dates_messaging_v2":{"subject":"bev","buckets":3,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"illustration_and_message","buckets":null},{"name":"simple_message","buckets":null}]},"p3_friendlier_ib_cta":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"friendlier_ib_cta","buckets":null}]},"p3_history_replace_state":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"use_replace_state","buckets":null}]},"p3_safety_features_section":{"subject":"bev","buckets":3,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"treatment1","buckets":null},{"name":"treatment2","buckets":null}]},"the_new_header_take_4":{"subject":"bev","buckets":3,"percent_exposed":100,"treatments":[{"name":"new_header_lys_on_left","buckets":null},{"name":"new_header_lys_on_right","buckets":null},{"name":"old_header","buckets":null}]},"global_recently_viewed":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"global_recently_viewed","buckets":null}]},"p1_search_autocomplete_bounds":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"experiment","buckets":null}]},"ipad_download_interstitial_modal":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"control","buckets":null},{"name":"show_ipad_modal","buckets":null}]},"field_guide3":{"subject":"bev","buckets":2,"percent_exposed":100,"treatments":[{"name":"baseline","buckets":null},{"name":"show_guide","buckets":null}]}}' id="_bootstrap-erf"/>
# <script src="https://a2.muscache.com/airbnb/static/packages/header_cookie-ed18f63f212d3be1f78b58964982842c.js" type="text/javascript"></script>
# <script>
#
#       (function () {
#         var initData = BootstrapData.get('header-init');
#         var headerContainer = document.getElementById('header');
#         var newHeader = document.getElementById('new-header');
#         var oldHeader = document.getElementById('old-header');
#         var useBusinessTravelHeader = initData ? initData.use_business_travel_header : false;
#
#         var useNewHeaderLeft = function () {
#           J(document.body).addClass('with-new-header');
#           headerContainer.removeChild(oldHeader);
#           J(headerContainer).addClass('lys-on-left');
#         };
#         var useNewHeaderRight = function () {
#           J(document.body).addClass('with-new-header');
#           headerContainer.removeChild(oldHeader);
#           J(headerContainer).addClass('lys-on-right');
#         };
#         var useOldHeader = function () {
#           headerContainer.removeChild(newHeader);
#         };
#
#         // Don't affect header experiment if business header is enabled.
#         if (useBusinessTravelHeader) { return };
#
#         Airbnb.ERF.deliverExperiment(
#           'the_new_header_take_4',
#           {
#             new_header_lys_on_left: useNewHeaderLeft,
#             new_header_lys_on_right: useNewHeaderRight,
#             old_header: useOldHeader,
#             treatment_unknown: useOldHeader
#           }
#         );
#       })();
# </script>
# <div class="flash-container"></div>
# <main id="site-content" role="main">
# <div class="subnav-container">
# <div aria-hidden="true" class="subnav book-it show-md" data-sticky="true" data-transition-at="#details">
# <div class="page-container-responsive">
# <div class="pull-left text-contrast subnav-element">
# <div class="va-container va-container-v">
# <div class="va-middle">
# <strong>
# <span class="book-it-price-amount h3">
#                 $138
#               </span>
# <span class="per-night">
#                 per night
#               </span>
# <span class="per-month hide">
#                 per month
#               </span>
# </strong>
# </div>
# </div>
# </div>
# <div class="pull-right book-it-btn-container">
# <button class="btn btn-primary btn-large" id="sticky-md-book-it-btn" type="submit">
# <span class="book-it">
#             Request to Book
#           </span>
# <span class="instant-book">
# <i class="icon icon-bolt icon-beach h4"></i>
#             Instant Book
#           </span>
# </button>
# </div>
# </div>
# </div>
# <div aria-hidden="true" class="subnav section-titles hide-md" data-sticky="true" data-transition-at="#summary">
# <div class="page-container-responsive">
# <ul class="subnav-list">
# <li>
# <a aria-selected="true" class="subnav-item" href="#photos">
#             Photos
#           </a>
# </li>
# <li>
# <a class="subnav-item" href="#summary">
#             About this listing
#           </a>
# </li>
# <li>
# <a class="subnav-item" href="#reviews">
#             Reviews
#           </a>
# </li>
# <li>
# <a class="subnav-item" href="#host-profile">
#             The Host
#           </a>
# </li>
# <li>
# <a class="subnav-item" href="#neighborhood">
#             Location
#           </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="container" id="og_pro_photo_prompt"></div>
# <div id="room" itemscope="" itemtype="http://schema.org/Product">
# <meta content="https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&amp;size=large&amp;output-format=jpg&amp;output-quality=70" itemprop="image"/>
# <div class="with-photos with-modal" id="photos">
# <img alt="" class="hide" src="https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&amp;size=large&amp;output-format=jpg&amp;output-quality=70" srcset="https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&amp;size=large&amp;output-format=jpg&amp;output-quality=70 639w, https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&amp;size=xx_large&amp;output-format=jpg&amp;output-quality=70 1440w"/>
# <span class="cover-img-container" data-hook="cover-img-container">
# <div class="cover-img show-sm" data-hook="img-sm" style="background-image: url(https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&amp;size=large&amp;output-format=jpg&amp;output-quality=70)">
# </div>
# <div class="cover-img hide-sm" data-hook="img-lg" style="background-image:
#                   url(https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&amp;size=xx_large&amp;output-format=jpg&amp;output-quality=70)">
# </div>
# </span>
# <div aria-hidden="true" class="modal photo-modal" data-preload-size="5" id="photo-modal" role="dialog">
# <div class="modal-table">
# <div class="modal-cell">
# <button class="carousel-chevron right text-contrast" data-slideshow-next="true">
# <span class="screen-reader-only">Next</span>
# <i class="icon icon-chevron-right icon-size-4 text-contrast"></i>
# </button>
# <button class="carousel-chevron left" data-slideshow-prev="true">
# <span class="screen-reader-only">Previous</span>
# <i class="icon icon-chevron-left icon-size-4 text-contrast"></i>
# </button>
# <a class="modal-close" data-behavior="modal-close" href="#">
#             ×
#             <span class="screen-reader-only">Close</span>
# </a>
# <div class="modal-content">
# <ul class="slideshow-images loading loading-dark">
# <li class="media-photo media-photo-block active">
# <div class="media-cover text-center">
# <img alt="The living room has an efficient gas fireplace." class="carousel-image img-responsive-height" src="https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&amp;size=xx_large&amp;output-format=jpg&amp;output-quality=70"/>
# </div>
# </li>
# <li class="media-photo media-photo-block">
# <div class="media-cover text-center">
# <img alt="Dining room." class="carousel-image img-responsive-height" src="https://a2.muscache.com/ac/pictures/59246739/3ab7ba0f_original.jpg?interpolation=lanczos-none&amp;size=x_large&amp;output-format=progressive-jpeg&amp;output-quality=70"/>
# </div>
# </li>
# </ul>
# <div class="slideshow-preload hide"></div>
# <div class="slideshow-inline-preload hide">
# <img alt="Dining room." src="https://a2.muscache.com/ac/pictures/59246739/3ab7ba0f_original.jpg?interpolation=lanczos-none&amp;size=x_large&amp;output-format=progressive-jpeg&amp;output-quality=70"/>
# <img alt="Loft-like master bedroom on the third floor." src="https://a1.muscache.com/ac/pictures/59246481/bb8a0dc7_original.jpg?interpolation=lanczos-none&amp;size=x_large&amp;output-format=progressive-jpeg&amp;output-quality=70"/>
# </div>
# </div>
# <div class="text-center">
# <figcaption class="slideshow-media-caption media-caption text-center">
# <div class="slideshow-caption-viewport row-space-4">
# <div class="slideshow-caption-container page-container-responsive">
# <div class="row row-space-2">
# <div class="col-lg-9">
# <div class="slideshow-caption text-left">
# </div>
# <div class="text-left">
# <i class="slideshow-professional text-muted hide">
#                           Verified Photo
#                         </i>
# </div>
# </div>
# <div class="col-lg-3 text-right">
#                       Show photo list
#                       <i class="icon icon-caret-down"></i>
# </div>
# </div>
# <div class="thumbnails-viewport">
# <div class="thumbnails-slide-container">
# <ul class="slideshow-thumbnails thumbnails-slide-panel">
# </ul>
# </div>
# </div>
# </div>
# </div>
# </figcaption>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="panel room-section" id="summary">
# <div class="page-container-responsive">
# <div class="row">
# <div class="col-lg-8">
# <div class="row-space-4 row-space-top-4">
# <div class="row">
# <div class="col-md-3 space-sm-4 text-center space-sm-2">
# <div class="media-photo-badge">
# <a class="media-photo media-round" href="#host-profile"><img alt="User Profile Image" class="host-profile-image" height="115" nopin="nopin" src="https://a2.muscache.com/ac/users/10053932/profile_pic/1384651532/original.jpg?interpolation=lanczos-none&amp;crop=w:w;*,*&amp;crop=h:h;*,*&amp;resize=225:*&amp;output-format=jpg&amp;output-quality=70" title="Larry" width="115"/></a>
# </div>
# </div>
# <div class="col-md-9">
# <h1 class="overflow h3 row-space-1 text-center-sm" id="listing_name" itemprop="name">
#         Classic Close-In Portland
#       </h1>
# <span class="hide" itemprop="breadcrumb">
# <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <a href="/s/United-States" itemprop="url"><span itemprop="title">United States</span>,</a>
# </span>
# <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <a href="/s/Oregon--United-States" itemprop="url"><span itemprop="title">Oregon</span>,</a>
# </span>
# <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <a href="/s/Portland--OR" itemprop="url"><span itemprop="title">Portland</span></a>
# </span>
# </span>
# <div class="row-space-2 text-muted text-center-sm" data-location="Portland, OR, United States" id="display-address" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating">
# <a class="link-reset" href="#neighborhood">Portland, OR, United States</a>
#
#
#           <a class="link-reset hide-sm" href="#reviews"> <div class="star-rating">
# <div class="foreground">
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <i class="icon icon-beach icon-star"></i>
# <meta content="5.0" itemprop="ratingValue"/>
# </div>
# <div class="background">
# <i class="icon icon-star icon-light-gray"></i>
# <i class="icon icon-star icon-light-gray"></i>
# <i class="icon icon-star icon-light-gray"></i>
# <i class="icon icon-star icon-light-gray"></i>
# <i class="icon icon-star icon-light-gray"></i>
# </div>
# </div>
# (<span itemprop="reviewCount">53</span>)</a>
# </div>
# <div class="row row-condensed text-muted text-center">
# <div class="col-sm-3">
# <i class="icon icon-entire-place icon-size-2"></i>
# </div>
# <div class="col-sm-3">
# <i class="icon icon-group icon-size-2"></i>
# </div>
# <div class="col-sm-3">
# <i class="icon icon-rooms icon-size-2"></i>
# </div>
# <div class="col-sm-3">
# <i class="icon icon-double-bed icon-size-2"></i>
# </div>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-md-3 text-muted text-center hide-sm">
# <a class="link-reset text-wrap" href="#host-profile">Larry</a>
# </div>
# <div class="col-md-9">
# <div class="row row-condensed text-muted text-center">
# <div class="col-sm-3">
#             Entire home/apt
#           </div>
# <div class="col-sm-3">
#             6 Guests
#           </div>
# <div class="col-sm-3">
#             3 Bedrooms
#           </div>
# <div class="col-sm-3">
#             3 Beds
#           </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-lg-4">
# <form accept-charset="UTF-8" action="https://www.airbnb.com/payments/book?hosting_id=1943748" class="info new-o2-form-inline" id="book_it_form" method="post"><div style="margin:0;padding:0;display:inline"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="V4$.airbnb.com$r2eISeiw8LE$0Bl9plCzKLsq03ex1f3LVqXWDfEfhjUBYv1N7xmucKc="/></div>
# <h4 class="screen-reader-only">
#     Request to Book
#   </h4>
# <div id="pricing" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <div class="book-it-price-amount pull-left h3 text-special" id="price_amount">
#       $138
#     </div>
# <i class="icon icon-bolt icon-beach pull-left h3 pricing__bolt"></i>
# <div class="pull-right" id="payment-period-container">
# <div class="per-night" id="per_night">
#         Per Night
#       </div>
# <div class="per-month hide" id="per_month">
#         Per Month
#         <i class="icon icon-question hide" data-behavior="tooltip" id="price-info-tooltip"></i>
# </div>
# </div>
# <meta content="USD" itemprop="priceCurrency"/>
# <meta content="138" itemprop="price"/>
# </div>
# <div id="book_it">
# <div class="panel">
# <div class="panel-body panel-light">
# <div class="form-fields">
# <div class="row row-condensed row-space-3">
# <div class="col-md-9">
# <div class="row row-condensed">
# <div class="col-sm-6 row-space-1-sm">
# <label for="checkin">
#                     Check In
#                   </label>
# <input class="checkin" id="checkin" name="checkin" placeholder="mm/dd/yyyy" type="text"/>
# </div>
# <div class="col-sm-6 row-space-1-sm">
# <label for="checkout">
#                     Check Out
#                   </label>
# <input class="checkout" id="checkout" name="checkout" placeholder="mm/dd/yyyy" type="text"/>
# </div>
# </div>
# </div>
# <div class="col-md-3">
# <label for="number_of_guests">
#                 Guests
#               </label>
# <div class="select select-block">
# <select id="number_of_guests" name="number_of_guests"><option value="1">1</option>
# <option value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option></select>
# </div>
# </div>
# </div>
# <div class="simple-dates-message-container hide">
# <div class="media text-kazan space-top-2 space-2">
# <div class="pull-left message-icon">
# <i class="icon icon-currency-usd"></i>
# </div>
# <div class="media-body">
# <strong>
#                   Enter dates for accurate prices and availability.
#                 </strong>
# </div>
# </div>
# </div>
# </div>
# <div id="book_it_status">
# <div class="clearfix" id="book_it_enabled">
# <div class="hide" id="subtotal_area">
# <span class="text-muted hide" id="subtotal-label">
#                 Subtotal
#               </span>
# <span class="text-muted hide" id="total-label">
#                 Total
#               </span>
# <div class="h1 text-special row-space-1" id="subtotal"></div>
# </div>
# <div class="book-it-btn-container" id="book_it_button_container">
# <button class="btn btn-large btn-block" id="book_it_button" type="submit">
# <span class="book-it">
#                   Request to Book
#                 </span>
# <span class="instant-book">
# <i class="icon icon-bolt icon-beach h4"></i>
#                   Instant Book
#                 </span>
# <span class="book-now">
#                   Book Now
#                 </span>
# </button>
# </div>
# <p class="text-muted book-it--friendlier__book-it-btn-help row-space-3 text-center">
# <small>
#                 You’ll be able to review before paying.
#               </small>
# </p>
# </div>
# <div class="text-center hide" id="book_it_disabled">
# <p class="icon-rausch" id="book_it_disabled_message">
#               This property is unavailable.
#             </p>
# <a class="btn btn-large btn-block" href="" id="view_other_listings_button">
#               View Other Listings
#             </a>
# </div>
# </div>
# <div class="fancy-dates-message-container va-container va-container-h space-3 hide hide-sm">
# <div class="illustration-container va-middle">
# <div class="text">
# <strong>
#                 When are you traveling?
#               </strong><br/>
#               Enter dates for accurate prices and availability.
#             </div>
# </div>
# </div>
# <div data-host-name="Larry" id="book-it-urgency-commitment">
# ...
# </a> </li>
# <li>
# <a class="link-contrast footer-icon-container" href="https://www.pinterest.com/airbnb/" itemprop="sameAs" target="_blank">
# <span class="screen-reader-only">Pinterest</span>
# <i class="icon footer-icon icon-pinterest"></i>
# </a> </li>
# <li>
# <a class="link-contrast footer-icon-container" href="http://www.youtube.com/airbnb" itemprop="sameAs" target="_blank">
# <span class="screen-reader-only">YouTube</span>
# <i class="icon footer-icon icon-youtube"></i>
# </a> </li>
# <li>
# <a class="link-contrast footer-icon-container" href="https://www.instagram.com/airbnb" itemprop="sameAs" target="_blank">
# <span class="screen-reader-only">Instagram</span>
# <i class="icon footer-icon icon-instagram"></i>
# </a> </li>
# </ul>
# <div class="space-top-2 text-muted">
#       © Airbnb, Inc.
#     </div>
# </div>
# </footer>
# </div>
# <div class="hide" id="gmap-preload"></div>
# <meta content="{&quot;ml.preview.this_is_a_preview_of_your_listing&quot;:&quot;This is a preview of your listing.&quot;,&quot;ml.preview.your_space_is_unlisted&quot;:&quot;Your space is unlisted.&quot;,&quot;ml.preview.your_space_is_listed_edit_calendar&quot;:&quot;Your space is listed! %{link_start}Edit your calendar%{link_end} to make sure it shows accurate availability.&quot;,&quot;shared.Close&quot;:&quot;Close&quot;,&quot;ml.preview.edit_preview&quot;:&quot;Edit Listing&quot;,&quot;host_standards.rooms.deactivated_flash&quot;:&quot;Your listing is temporarily deactivated. %{reactivate_link_start}Learn more and reactivate.%{reactivate_link_end}||||Your listings are temporarily deactivated. %{reactivate_link_start}Learn more and reactivate.%{reactivate_link_end}&quot;,&quot;checkin_noun&quot;:&quot;Check-In&quot;,&quot;calendar.host_requires_minimum_nights&quot;:&quot;A minimum of %{smart_count} %{line_break}night stay is required |||| A minimum of %{smart_count} %{line_break}nights stay is required&quot;,&quot;calendar.host_requires_start_day_of_week&quot;:&quot;%{host_name} requires checking in%{line_break} on %{day_of_week_plural}&quot;,&quot;Mondays&quot;:&quot;Mondays&quot;,&quot;Tuesdays&quot;:&quot;Tuesdays&quot;,&quot;Wednesdays&quot;:&quot;Wednesdays&quot;,&quot;Thursdays&quot;:&quot;Thursdays&quot;,&quot;Fridays&quot;:&quot;Fridays&quot;,&quot;Saturdays&quot;:&quot;Saturdays&quot;,&quot;Sundays&quot;:&quot;Sundays&quot;,&quot;calendar.host_requires_no_arrival&quot;:&quot;%{host_name} isn&amp;#8217;t available%{line_break} for check in on%{line_break} this date&quot;,&quot;calendar.host_requires_no_departure&quot;:&quot;%{host_name} isn&amp;#8217;t available%{line_break} for check out on%{line_break} this date&quot;,&quot;limited_days_available_month&quot;:&quot;Love %{user}'s place? Book soon. There are only &lt;b&gt;%{number_of_days}&lt;/b&gt; available in the next month.&quot;,&quot;simple_view_count_day&quot;:&quot;%{number_of_people} viewed %{user}'s place today&quot;,&quot;simple_view_count_week&quot;:&quot;%{number_of_people} viewed %{user}'s place this week&quot;,&quot;view_count&quot;:&quot;See yourself here? Book soon. &lt;b&gt;%{number_of_people}&lt;/b&gt; viewed %{user}'s place this week.&quot;,&quot;shared.pluralize.person&quot;:&quot;%{smart_count} person||||%{smart_count} people&quot;,&quot;similar_listings&quot;:&quot;Similar Listings&quot;,&quot;no_similar_listings&quot;:&quot;No similar listings available.&quot;,&quot;same_address&quot;:&quot;Same Address&quot;,&quot;distance_away&quot;:&quot;%{distance} away&quot;,&quot;learn_more&quot;:&quot;Learn more&quot;,&quot;accommodation&quot;:&quot;Accommodation&quot;,&quot;service_fee&quot;:&quot;Service fee&quot;,&quot;occupancy_taxes&quot;:&quot;Occupancy Taxes&quot;,&quot;includes_vat&quot;:&quot;(includes VAT)&quot;,&quot;total_amounts&quot;:&quot;Total amounts&quot;,&quot;progress_indicator_caption&quot;:&quot;%{numerator}/%{denominator}: %{caption}&quot;,&quot;neighborhood_singular&quot;:&quot;Neighborhood&quot;,&quot;location_map&quot;:&quot;Location Map&quot;,&quot;host_recommendation&quot;:&quot;Host Recommendation&quot;,&quot;priv.everyone&quot;:&quot;Everyone&quot;,&quot;priv.only_me&quot;:&quot;Only Me&quot;,&quot;priv.description&quot;:&quot;Who can see this?&quot;,&quot;priv.everyone_description&quot;:&quot;Visible to everyone and included on your public Airbnb profile.&quot;,&quot;priv.only_me_description&quot;:&quot;Visible only to you and not shared anywhere.&quot;,&quot;save_to_wish_list&quot;:&quot;Save to Wish List&quot;,&quot;save_to_wish_list_and_fb&quot;:&quot;Save to Wish List and Facebook Timeline&quot;,&quot;wl_modal.create_new&quot;:&quot;Create new&quot;,&quot;wl_modal.make_a_new&quot;:&quot;Make a new wish list...&quot;,&quot;wl_modal.create&quot;:&quot;Create&quot;,&quot;wl_modal.add_note&quot;:&quot;Add a note&quot;,&quot;wl_modal.post_to_facebook&quot;:&quot;Post to Facebook&quot;,&quot;wl_modal.done&quot;:&quot;Done&quot ...
# <meta content='{"canonical_host":"www.airbnb.com","language":"en","locale":"en","api_config":{"baseUrl":"https://www.airbnb.com/api","key":"d306zoyjsyarp7ifhu67rjxn52tv0t20"},"deep_link":null,"tracking_context":{"source":"monorail","platform":"js","version":"7904c118be2329286b28b8558218234fb1dfdae1","controller":"rooms","action":"show","req_uuid":"6c8d02c9-b0bf-4c57-af9c-3543b5ffce3d","shardset":"a0,a1,a2"},"no_flash_alerts":null,"google_maps_url":"https://maps.googleapis.com/maps/api/js?language=en&amp;region=US&amp;sensor=false&amp;v=3.13&amp;libraries=places&amp;client=gme-airbnbinc&amp;channel=monorail-prod","open_street_map_url":"https://api.tiles.mapbox.com/mapbox.js/v2.1.4/mapbox.js","sift_key":"5d704de7e8","pellet_id":"kfgn8s24"}' id="_bootstrap-layout-init"/>
# <meta content='{"data":{"country":"US","tld_country":"US","currencies":{"AED":{"symbol":"&amp;#1583;.&amp;#1573;","code_required":false,"options":{"unicode_symbol":"ﺩ.ﺇ"}},"ARS":{"symbol":"$","code_required":true,"options":null},"AUD":{"symbol":"$","code_required":true,"options":null},"BRL":{"symbol":"R$","code_required":false,"options":{"space_between_price_and_symbol":true}},"CAD":{"symbol":"$","code_required":true,"options":null},"CHF":{"symbol":"CHF","code_required":false,"options":{"position":"after","space_between_price_and_symbol":true}},"CNY":{"symbol":"&amp;yen;","code_required":false,"options":{"unicode_symbol":"¥"}},"CRC":{"symbol":"&amp;#8353;","code_required":false,"options":{"unicode_symbol":"₡"}},"CZK":{"symbol":"&amp;#75;&amp;#269;","code_required":false,"options":{"unicode_symbol":"Kč"}},"DKK":{"symbol":"kr","code_required":true,"options":{"position":"after","space_between_price_and_symbol":true,"explicit_currency_not_aesthetic":true}},"EUR":{"symbol":"&amp;euro;","code_required":false,"options":{"unicode_symbol":"€","position":"special"}},"GBP":{"symbol":"&amp;pound;","code_required":false,"options":{"unicode_symbol":"£"}},"HKD":{"symbol":"$","code_required":true,"options":null},"HRK":{"symbol":"kn","code_required":false,"options":null},"HUF":{"symbol":"Ft","code_required":false,"options":null},"IDR":{"symbol":"Rp","code_required":false,"options":null},"ILS":{"symbol":"&amp;#8362;","code_required":false,"options":{"unicode_symbol":"₪","space_between_price_and_symbol":true}},"INR":{"symbol":"&amp;#8377;","code_required":false,"options":{"unicode_symbol":"₹"}},"JPY":{"symbol":"&amp;yen;","code_required":false,"options":{"unicode_symbol":"¥","space_between_price_and_symbol":true}},"KRW":{"symbol":"&amp;#8361;","code_required":false,"options":{"unicode_symbol":"₩"}},"MAD":{"symbol":"MAD","code_required":false,"options":null},"MXN":{"symbol":"$","code_required":true,"options":null},"MYR":{"symbol":"&amp;#82;&amp;#77;","code_required":false,"options":{"unicode_symbol":"RM"}},"NOK":{"symbol":"kr","code_required":true,"options":{"position":"after","space_between_price_and_symbol":true,"explicit_currency_not_aesthetic":true}},"NZD":{"symbol":"$","code_required":true,"options":null},"PEN":{"symbol":"&amp;#83;&amp;#47;&amp;#46;","code_required":false,"options":{"unicode_symbol":"S/."}},"PHP":{"symbol":"&amp;#8369;","code_required":false,"options":{"unicode_symbol":"₱"}},"PLN":{"symbol":"z&amp;#22;&amp;#322;","code_required":false,"options":{"unicode_symbol":"zł","position":"after","space_between_price_and_symbol":true}},"RON":{"symbol":"lei","code_required":false,"options":null},"RUB":{"symbol":"&amp;#1088;","code_required":false,"options":{"unicode_symbol":"р","position":"after"}},"SEK":{"symbol":"kr","code_required":true,"options":{"position":"after","space_between_price_and_symbol":true,"explicit_currency_not_aesthetic":true}},"SGD":{"symbol":"$","code_required":true,"options":null},"THB":{"symbol":"&amp;#3647;","code_required":false,"options":{"unicode_symbol":"฿"}},"TRY":{"symbol":"&amp;#84;&amp;#76;","code_required":false,"options":{"unicode_symbol":"TL","position":"after","space_between_price_and_symbol":true}},"TWD":{"symbol":"$","code_required":true,"options":null},"USD":{"symbol":"$","code_required":false,"options":null},"VND":{"symbol":"&amp;#8363;","code_required":false,"options":{"unicode_symbol":"₫"}},"ZAR":{"symbol":"R","code_required":true,"options":null}},"current_locale_name":"English","languages":[{"locale_name":"Bahasa Indonesia","locale":"id"},{"locale_name":"Bahasa Melayu","locale":"ms"},{"locale_name":"Català","locale":"ca"},{"locale_name":"Dansk","locale":"da"},{"locale_name":"Deutsch","locale":"de"},{"locale_name":"English","locale":"en"},{"locale_name":"Español","locale":"es"},{"locale_name":"Eλληνικά","locale":"el"},{"locale_name":"Français","locale":"fr"},{"locale_name":"Italiano","locale":"it"},{"locale_name":"Magyar","locale":"hu"},{"locale_name":"Nederlands","locale":"nl"},{"locale_name":" ...
# <meta content='{"enabled":true,"appId":"138566025676","scope":"email,user_birthday,user_likes,user_education_history,user_hometown,user_location,user_friends","sdkUrl":"https://connect.facebook.net/en_US/sdk.js"}' id="_bootstrap-facebook-init"/>
# <meta content='{"packages/field_guide.bundle.js":"https://a1.muscache.com/airbnb/static/packages/field_guide.bundle-362a5b44735694172fff257a493c3404.js","packages/airlock_modal.bundle.js":"https://a1.muscache.com/airbnb/static/packages/airlock_modal.bundle-69d4e767e0eda2d5466ad0c682a6bae8.js","packages/profile_pic_upsell.js":"https://a0.muscache.com/airbnb/static/packages/profile_pic_upsell-1e37b543f244b7b06a98a5bb2761b14f.js"}' id="_bootstrap-javascript_paths"/>
# <meta content="true" id="_bootstrap-is-signup-prompt-page"/>
# <meta content='{"id":1943748}' id="_bootstrap-admin_listing"/>
# <meta content='{"book_it_color_experiment":false,"search.search_autocomplete_bounds":true}' id="_bootstrap-trebuchet"/>
# <meta content='{"locale":"en","hostingId":1943748,"isMonthly":false,"airEventData":{"page":"p3","hosting_id":1943748,"visible_review_count":53,"friend_count":0,"person_capacity":6,"price":138.0,"saved_to_wishlist_count":223,"reponse_rate_shown":0.9,"response_time_shown":1238.0,"guest_satisfaction_overall":96,"accuracy_rating":10,"cleanliness_rating":10,"checkin_rating":10,"communication_rating":10,"location_rating":10,"value_rating":10,"picture_count":27,"cancel_policy":4,"amenities":[1,3,4,8,27,30,31,33,34,35,36,37,40,41],"instant_book_possible":false,"utc_offset":-25200,"time_since_last_calendar_update":7610.003018319,"room_type":"Entire home/apt","bed_type":"Real Bed"},"nightly_price":"$138","staggered_price":"$3864","numPhotos":27,"minNights":2,"calendarLastUpdated":"2015-06-24","photoData":[{"caption":"The living room has an efficient gas fireplace.","caption_formatted":"1/27: The living room has an efficient gas fireplace.","url":"https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&amp;size=xx_large&amp;output-format=jpg&amp;output-quality=70","thumbnail_url":"https://a1.muscache.com/ac/pictures/59246672/f9dcde30_original.jpg?interpolation=lanczos-none&amp;size=small&amp;output-format=jpg&amp;output-quality=70","professional":true,"first":true},{"caption":"Dining room.","caption_formatted":"2/27: Dining room.","url":"https://a2.muscache.com/ac/pictures/59246739/3ab7ba0f_original.jpg?interpolation=lanczos-none&amp;size=x_large&amp;output-format=progressive-jpeg&amp;output-quality=70","thumbnail_url":"https://a2.muscache.com/ac/pictures/59246739/3ab7ba0f_original.jpg?interpolation=lanczos-none&amp;size=small&amp;output-format=jpg&amp;output-quality=70","professional":true,"first":false},{"caption":"Loft-like master bedroom on the third floor.","caption_formatted":"3/27: Loft-like master bedroom on the third floor.","url":"https://a1.muscache.com/ac/pictures/59246481/bb8a0dc7_original.jpg?interpolation=lanczos-none&amp;size=x_large&amp;output-format=progressive-jpeg&amp;output-quality=70","thumbnail_url":"https://a1.muscache.com/ac/pictures/59246481/bb8a0dc7_original.jpg?interpolation=lanczos-none&amp;size=small&amp;output-format=jpg&amp;output-quality=70","professional":true,"first":false},{"caption":"Master bedroom has a queen-sized TempurPedic bed.","caption_formatted":"4/27: Master bedroom has a queen-sized TempurPedic bed.","url":"https://a1.muscache.com/ac/pictures/59246490/c1bcdd44_original.jpg?interpolation=lanczos-none&amp;size=x_large&amp;output-format=progressive-jpeg&amp;output-quality=70","thumbnail_url":"https://a1.muscache.com/ac/pictures/59246490/c1bcdd44_original.jpg?interpolation=lanczos-none&amp;size=small&amp;output-format=jpg&amp;output-quality=70","professional":true,"first":false},{"caption":"Bathroom on the 2nd floor.","caption_formatted":"5/27: Bathroom on the 2nd floor.","url":"https://a0.muscache.com/ac/pictures/59246504/2ff1575b_original.jpg?interpolation=lanczos-none&amp;size=x_large&amp;output-format=progressive-jpeg&amp;output-quality=70","thumbnail_url":"https://a0.muscache.com/ac/pictures/59246504/2ff1575b_original.jpg?interpolation=lanczos-none&amp;size=small&amp;output-format=jpg&amp;output-quality=70","professional":true,"first":false},{"caption":"Bedroom with full-sized bed and great light!","caption_formatted":"6/27: Bedroom with full-sized bed and great light!","url":"https://a2.muscache.com/ac/pictures/59246518/c149667e_original.jpg?interpolation=lanczos-none&amp;size=x_large&amp;output-format=progressive-jpeg&amp;output-quality=70","thumbnail_url":"https://a2.muscache.com/ac/pictures/59246518/c149667e_original.jpg?interpolation=lanczos-none&amp;size=small&amp;output-format=jpg&amp;output-quality=70","professional":true,"first":false},{"caption":"Classic Close-In Portland","caption_formatted":"7/27: Classic Close-In Portland","url":"https://a2.muscache.com/ac/pictures/59246525/f3d9e682_original.jpg?interpolation=lanczos-none&amp;size=x_large&a ...
# <meta content='{"captchaPublicKey":"6LeP4QATAAAAAFK8nC5UePxJtQC-WXXKn0GgBRoz"}' id="_bootstrap-captcha_data"/>
# <meta content="null" id="_bootstrap-owner_suspended"/>
# <!--[if lt IE 9]>
#   <script src="https://a0.muscache.com/airbnb/static/packages/libs_jquery_1x-ddd855c6b11e4ce7810e9c7e816fc0f4.js" type="text/javascript"></script>
# <![endif]-->
# <!--[if gte IE 9]><!-->
# <script src="https://a2.muscache.com/airbnb/static/packages/libs_jquery_2x-fa4b85da111957f63fc5fa6783d8d324.js" type="text/javascript"></script>
# <!--<![endif]-->
# <script src="https://a1.muscache.com/airbnb/static/packages/o2.1-e9d096bf5771e5e17c6ed9dbd80c0545.js" type="text/javascript"></script>
# <script src="https://a1.muscache.com/airbnb/static/packages/core.bundle-917b815dab0ac48c21a0ed51ed43ef91.js" type="text/javascript"></script>
# <script>
#
#   Airbnb.init();
# </script>
# <div id="fb-root"></div>
# <script src="https://a0.muscache.com/airbnb/static/packages/p3_template_manifest-9c58eb0bf04e51188997e19a9a11dfd7.js" type="text/javascript"></script><script src="https://a2.muscache.com/airbnb/static/packages/p3.bundle-1c45b5057a6d93fed697f587cedd5bc3.js" type="text/javascript"></script>
# <div aria-hidden="true" class="modal" id="contact-modal" role="dialog">
# <div class="modal-table">
# <div class="modal-cell">
# <div class="modal-content">
# <div style="height:300px"></div>
# </div>
# </div>
# </div>
# </div>
# </body>
# </html>
# >

# %%
def extract_listing_features(soup):

    listing_name = soup.find('div', {'class':"rich-toggle wish_list_button"})['data-name']
    address = soup.find('div', {'class':"rich-toggle wish_list_button"})['data-address']
    hood = soup.find('div',{'id':'neighborhood-seo-link'}).h3.a.get_text().strip()
    num_saved = soup.find('div', {'class':"rich-toggle wish_list_button"})['title']
    price_currency = soup.find('meta', {'itemprop': 'priceCurrency'})['content']
    price = soup.find('meta', {'itemprop': 'price'})['content']

    headline = soup.find('meta', {'property':"og:description"})['content']

    description_raw = soup.find('div', {'class':'row description'}).find('div', {'class':'expandable-content expandable-content-long'}).get_text()

    print listing_name
    print address
    print hood
    print num_saved
    print price_currency
    print price
    print
    print "HEADLINE:"
    print headline
    print
    print "DESCRIPTION"
    print description_raw

# %%
extract_listing_features(soup)
# Out:
# Classic Close-In Portland
# Southeast Ankeny Street, Portland (Buckman)
# Buckman
# Saved 223 times
# USD
# 138
#
# HEADLINE:
# House in Portland, United States. My spacious 3 bedroom house is a classic &quot;Portland style&quot; home with hardwood floors and art by local artists throughout. Located about a mile from downtown it&#x27;s centrally located and a great base for exploring the city on foot, by bike, public tra...
#
# DESCRIPTION
#
# The Space
# The first floor has an open layout that includes a living room with a gas fireplace for chilly days. South-facing French doors open onto an elevated front deck that is surrounded by foliage, so you can watch the world go by without being on stage. The kitchen has a retro chrome cafe table for quick meals, and there's a formal dining room in the living room. There is a half bath off the kitchen and a stereo and turntable with lots of records and CDs.
# One bedroom, a media room, and the bathroom are located on the second floor. The bedroom is a simple guest room with a full size bed. The media room is set up with a flatscreen TV, desk and couch for movie watching. The couch can fold down to accommodate 2 more sleepers. The second floor was remodeled just a few years ago and has warm bamboo flooring.
# The master bedroom is located on the third floor, in a bright, loft-like space. This bedroom has  queen size TempurPedic bed.
# The house is up from the street, and is three stories tall, so it is not ideal for folks who have problems with stairs.
# Guest Access
# Guests will share the washer (new this year!) and dryer located in the basement with the tenants who live in a separate apartment downstairs. They have their own entrance and their apartment is divided from the rest of the basement, so likely you will not ever cross paths.
# Interaction with Guests
# I am available by phone and email from a remote location. I have a friend who is taking care of the house who lives in the neighborhood who will be available to help you if you need anything during your stay.
# The Neighborhood
# The close-in location of the house makes it ideal for exploring Portland without a car. The location is six blocks from 28th Avenue "Restaurant Row", and there are many shops and brew pubs around. There is a Whole Foods  and a movie theater less than 7 blocks away, and a walking score of 77.
# The house is situated half a mile from a large historic city park designed by an Olmstead acolyte, with a pond and play areas including tennis and basketball courts.
# Getting Around
# Public transit is close by; you'll be just a couple blocks from bus line 20, whose route is a main artery of the city. There is ample street parking in front of the house.

# %% [markdown]
# NICE! We got the information we needed!
#
# We'll definately have to do some feature engineering on the description (hence the name, description raw, but for the most part we're in a good place.

# %%
#Lets try one more:
r = requests.get('https://www.airbnb.com/rooms/44323')
soup = BeautifulSoup(r.content)
extract_listing_features(soup)
# Out:
# Hip Inner Mission Garden Room
# Lexington St, San Francisco (Mission District)
# Mission District
# Saved 2433 times
# USD
# 69
#
# HEADLINE:
# House in San Francisco, United States. We are currently not accepting ANY short or long term reservations for the Garden Room. We will soon start a major remodel of our entire home and we are unsure as to when we will reopen the new &amp; improved space.  Why rent a room for $60-$90 per ni...
#
# DESCRIPTION
#
# The Space
# Why rent a room for $60-$90 per night and share your bathroom with the host?
# Why be a $20 cab ride away from Valencia Street's bars, night clubs and restaurants when you can stay directly in the middle of our vibrant neighborhood?
# Our 1876 Victorian home is located in the sunny Liberty Hill Historic District. Features include:
#    * Full size bed and linens for your comfort.
#    * Private garden path entrance with your own key.
#    * Sunny patio with gurgling fountain.
#    * Private bathroom with tile-lined shower adjacent to room.
#    * Plush bathroom towels reserved exclusively for our guests.
#    * Kitchen privileges - with a natural foods market steps away.
#    * Robust cable modem Wifi with 11.72 Mbps download and .84 Mbps upload speed.
#    * 1 block from major bus line to downtown operating every 5-15 minutes 24 hours a day.
#    * 3 blocks from the 24th Street BART Station, which serves SFO & OAK airports.
#    * The charge for an additional guest is $20 per night.
#    * The special weekly rate for a single is a bargain at $450.
# I look forward to meeting you and introducing you to our beautiful city and exciting neighborhood.

# %% [markdown]
# Interesting, that this doesnt have the same pieces of information as the previous one did. It only has the Space section.

# %%
#Lets try at least one more:
r = requests.get('https://www.airbnb.com/rooms/736080')
soup = BeautifulSoup(r.content)
extract_listing_features(soup)
# Out:
# HUGE Master Suite with Private Bath
# 17th Ave, San Francisco (Inner Sunset)
# Inner Sunset
# Saved 61 times
# USD
# 119
#
# HEADLINE:
#  •	Separate Large Living Room/Office with couch, cof...
#
# DESCRIPTION
#
# The Space
# Beautiful, Modern MASTER Bedroom with Private BATH & Private PARKING GARAGE SPOT & WASHER/DRYER!
# The Master Bedroom: 420 sq ft!!! Room is Larger than most studios in SF!
# •	Private Bathroom
# •	Separate Large Living Room/Office with couch, coffee table, 30 in TV, DVD player
# •	Queen Size Bed with Super Comfortable Pillow Top Mattress
# •	2 Closets with Full Length Mirrors
# •	Full Size Dresser with Vanity Mirror
# •	Backyard view with Natural Light
# •	High Speed Wireless Internet, Comcast Cable with DVR
# ***Free Garage Parking Spot Available!!!!!!***
# The Condo: Nicest one you will see in you search guaranteed!
# •	BRAND NEW REMODELED 3 bedroom/2 bathroom condo in the inner sunset shared with two exceptionally respectful housemates (both medical professionals (a MD and a PhD at UCSF)
# •	HARDWOOD FLOORS throughout except CARPET in the bedrooms
# •	Huge living room with fireplace, 3 sofas, 60 inch TV, separate dining room, etc.  Dinning room table with 6 chairs.
# •	Large kitchen with dishwasher, all new appliances, marble counter-tops, and plenty of cabinets
# •	WASHER/DRYER in the unit (Free)
# •	Large BACKYARD patio, garage, and storage
# •	Sorry: No Smoking on the property
# •	Sorry: landlord doesn’t allow furry animals
# The Location: Across the street from Golden Gate Park!!!
# •	On Multiple muni lines for easy access to downtown, Haight Ashbury, UCSF, the Beach, or wherever you need to go (The 71 picks up right outside our place!)
# •	Easy to the North or South Bay since 19th Ave is just 2 blocks away.
# •	N Judah is 2 blocks away for easy downtown access or the beach
# Lots of great restaurants in walking distance and some of the best Asian food in SF! Sushi, Chinese, Thai, Vietnamese, Tacos, Pizza, Indian, etc!
# ***Zip car hourly car rental located next door
# ***Full Service host. I can even pick you up:)
# Guest Access
# Master Suite, Living Room, Dining Rooms, and Kitchen. Garage is off limits.
# Interaction with Guests
# I love to host and will answer all questions upon check-in. I will be out of town during your stay but my kind roommate can assist you with anything you need.
# The Neighborhood
# I love being across the street from the magnificent Golgen Gate Park and steps from all the restaurnats and shopping on Irving Street.
# Getting Around
# Parking is not including in the listing, but there is easy street parking on Lincoln and the Muni bus picks ups right outside the condo at the corner of 17th Ave and Lincoln.
# Other Things to Note
# I have a very nice roommate that can assist you during your stay.

# %% [markdown]
# Using the above code as a template, I was able to create **'scrape_listings.py'**
#
# This script is used to scrape AirBnB's listings pages for its content
# * scrapes every listing found in the listing collection
#
# NOTE:
# * While I did this file, I got stopped several times.
# * At a certain point, I used a VPN from Canada to scrape, so some my findings are from CA
# * Thankfully, I had a 3500+ chunk that I was able to do overnight the one night.
#
# I also run the **'extract_features_from_listings.py'** file, which extracts features from the listings & extends the MongoDB document for each neighborhood with this information.
#
# The reason for the above split was to scrape the data from AirBnB (/slash/ not get banned) and to seperate the scraping from the feature extraction
#
# The majority of the functions are based on the AirBnBListing class in **'airbnb/airbnblisting.py'**, whose methods help.
#
# Notes:
# * I didn't do it here, but I will do some feature engineering during the modeling phase to the description to help is put it in the model.

# %% [markdown]
# #Continue onto the Analysis:
# ###See /notebook_2_eda-analysis.ipynb
