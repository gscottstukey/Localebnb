# %% [markdown]
# #Create a joined dataset

# %% [markdown]
# ### Prep the listings

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['zeros']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import airbnblisting as airl

DB_NAME = 'airbnb'
COLL_NAME = 'listings'

# %%
reload(airl)

air_listing = airl.AirBnBListing(db_name=DB_NAME, coll_name=COLL_NAME)
air_listing

# %%
#Grab a list of listing_ids & neighborhoods for all the listings
listing_list = list(air_listing.coll.find({},{'_id':1, 'neighborhood':1}))
print len(listing_list)
listing_list[:5]
# Out:
# 4228
# [{u'_id': u'0', u'neighborhood': u'N/A'},
#  {u'_id': u'6751767', u'neighborhood': u'N/A'},
#  {u'_id': u'2066868', u'neighborhood': u'Western Addition/NOPA'},
#  {u'_id': u'6', u'neighborhood': u'North Park'},
#  {u'_id': u'4', u'neighborhood': u'N/A'}]

# %%
#test an example
x = listing_list[19]   # Used 20 for no damn good reason
air_listing.pull_from_db(listing_id = x['_id'])
x, air_listing.url
# Out:
# ({u'_id': u'267820', u'neighborhood': u'Twin Peaks'},
#  u'https://www.airbnb.com/rooms/267820')

# %%
#check the extract_features functionality
d = air_listing._extract_clean_description().split()
d
# Out:
# [u'cozy',
#  u'clean',
#  u'quiet',
#  u'and',
#  u'with',
#  u'flair',
#  u'our',
#  u'apartment',
#  u'is',
#  u'located',
#  u'in',
#  u'the',
#  u'twin',
#  u'peaks',
#  u'neighborhood',
#  u'right',
#  u'in',
#  u'the',
#  u'middle',
#  u'of',
#  u'the',
#  u'city',
#  u'of',
#  u'san',
#  u'francisco',
#  u'situated',
#  u'up',
#  u'at',
#  u'one',
#  u'of',
#  u'the',
#  u'highest',
#  u'elevations',
#  u'in',
#  u'the',
#  u'city',
#  u'the',
#  u'breathtaking',
#  u'views',
#  u'of',
#  u'san',
#  u'francisco',
#  u'and',
#  u'the',
#  u'bay',
#  u'are',
#  u'the',
#  u'highlight',
#  u'of',
#  u'our',
#  u'place',
#  u'a',
#  u'5',
#  u'10',
#  u'minute',
#  u'hike',
#  u'up',
#  u'the',
#  u'hill',
#  u'will',
#  u'take',
#  u'you',
#  u'to',
#  u'one',
#  u'on',
#  u'the',
#  u'most',
#  u'visited',
#  u'spots',
#  u'in',
#  u'san',
#  u'francisco',
#  u'the',
#  u'top',
#  u'of',
#  u'twin',
#  u'peaks',
#  u'has',
#  u'a',
#  u'360',
#  u'degree',
#  u'view',
#  u'of',
#  u'the',
#  u'entire',
#  u'city',
#  u'including',
#  u'the',
#  u'golden',
#  u'gate',
#  u'bridge',
#  u'and',
#  u'alcatraz',
#  u'the',
#  u'hill',
#  u'is',
#  u'a',
#  u'great',
#  u'place',
#  u'for',
#  u'exercising',
#  u'with',
#  u'a',
#  u'full',
#  u'sized',
#  u'deck',
#  u'you',
#  u'can',
#  u'appreciate',
#  u'the',
#  u'view',
#  u'with',
#  u'tea',
#  u'breakfast',
#  u'wine',
#  u'etc',
#  u'the',
#  u'one',
#  u'large',
#  u'bedroom',
#  u'houses',
#  u'a',
#  u'double',
#  u'sized',
#  u'bed',
#  u'while',
#  u'the',
#  u'open',
#  u'and',
#  u'spacious',
#  u'floor',
#  u'plan',
#  u'of',
#  u'the',
#  u'living',
#  u'room',
#  u'allows',
#  u'for',
#  u'a',
#  u'large',
#  u'deep',
#  u'set',
#  u'couch',
#  u'that',
#  u'sleeps',
#  u'one',
#  u'to',
#  u'two',
#  u'comfortably',
#  u'when',
#  u'the',
#  u'back',
#  u'pillows',
#  u'are',
#  u'removed',
#  u'wifi',
#  u'1',
#  u'000',
#  u'dvd',
#  u'movie',
#  u'collection',
#  u'streaming',
#  u'netflix',
#  u'cable',
#  u'and',
#  u'apple',
#  u'tv',
#  u'are',
#  u'available',
#  u'to',
#  u'watch',
#  u'on',
#  u'a',
#  u'46\u201d',
#  u'plasma',
#  u'flat',
#  u'screen',
#  u'with',
#  u'a',
#  u'5',
#  u'1',
#  u'home',
#  u'theatre',
#  u'system',
#  u'bedroom',
#  u'also',
#  u'has',
#  u'a',
#  u'flat',
#  u'screen',
#  u'with',
#  u'apple',
#  u'tv',
#  u'on',
#  u'the',
#  u'desk',
#  u'in',
#  u'the',
#  u'living',
#  u'room',
#  u'there',
#  u'is',
#  u'a',
#  u'23',
#  u'monitor',
#  u'perfect',
#  u'for',
#  u'connecting',
#  u'laptops',
#  u'full',
#  u'kitchen',
#  u'with',
#  u'copper',
#  u'pots',
#  u'and',
#  u'complete',
#  u'cookware',
#  u'nice',
#  u'shower',
#  u'with',
#  u'tub',
#  u'large',
#  u'shower',
#  u'head',
#  u'and',
#  u'constant',
#  u'hot',
#  u'water',
#  u'washer',
#  u'and',
#  u'dryer',
#  u'located',
#  u'in',
#  u'building',
#  u'at',
#  u'4',
#  u'a',
#  u'load',
#  u'ample',
#  u'street',
#  u'parking',
#  u'37',
#  u'bus',
#  u'stop',
#  u'50',
#  u'feet',
#  u'from',
#  u'the',
#  u'front',
#  u'door',
#  u'takes',
#  u'passengers',
#  u'down',
#  u'the',
#  u'hill',
#  u'where',
#  u'transferring',
#  u'to',
#  u'other',
#  u'transit',
#  u'lines',
#  u'can',
#  u'take',
#  u'you',
#  u'anywhere',
#  u'in',
#  u'the',
#  u'city',
#  u'using',
#  u'the',
#  u'public',
#  u'steps',
#  u'some',
#  u'choose',
#  u'to',
#  u'walk',
#  u'down',
#  u'the',
#  u'hill',
#  u'appreciating',
#  u'the',
#  u'view',
#  u'the',
#  u'entire',
#  u'way',
#  u'and',
#  u'take',
#  u'public',
#  u'transportation',
#  u'back',
#  u'up']

# %% [markdown]
# ### Extract all descriptions

# %%
corpus = []
for l in listing_list:
    air_listing.pull_from_db(listing_id = l['_id'])
    corpus.append(air_listing._extract_clean_description())

# %%
#EDA - how many listings are 0 length?
lens = [len(x) for x in corpus]
zeros = [x==0 for x in lens]
print sum(zeros), len(corpus), round(float(sum(zeros))/len(corpus),2)
plt.hist(lens, bins=50)
plt.show()
# Out:
# 360 4228 0.09

# %%
#create a word_corpus of the words in the corpus
word_corpus = [x.encode('ascii','ignore').split() for x in corpus]
len(word_corpus)
# Out:
# 4228

# %%
# add the words to the listing
for listing, words, doc in zip(listing_list, word_corpus, corpus):
    listing['words'] = words
    listing['doc'] = doc

# %%
listing_list[:5]
# Out:
# [{u'_id': u'0', 'doc': '', u'neighborhood': u'N/A', 'words': []},
#  {u'_id': u'6751767',
#   'doc': u'can gramunt es una mas\xeda de origen medieval en la torre de claramunt tras su rehabilitaci\xf3n integral alberga tres amplios apartamentos y una sala polivalente con piscina jardin y terrazas con magn\xedficas vistas en un entorno entre vi\xf1edos romero es un apartamento de unos 60m2 en la planta primera con acceso a una magn\xedfica terraza orientada a este ubicada sobre la restaurada cisterna de agua de lluvia el techo es de vigas de madera originales el suelo de baldosas cer\xe1micas de la zona las paredes acabados con arcilla de un color rojizo mezclado \xfanicamente con arena y agua la cocina es amplia y abierta que permite que la preparaci\xf3n de comida se convierta en una actividad com\xfan los hu\xe9spedes del apartamento tienen acceso al jard\xedn con barbacoa y piscina y a la sala polivalente en el mismo recinto donde se ubica el apartamento vive una pareja encantadora que puede atender a los hu\xe9spedes que as\xed lo deseen la torre de claramunt la mas\xeda pertenece al t\xe9rmino municipal de la torre de claramunt un pueblo con un casco antiguo pintoresco alrededor de un castillo medieval consta de la infraestructura necesaria para poder prescindir de m\xe1s desplazamiento que los veinte minutos de paseo hacia el pueblo en medio de los vi\xf1edos y pasando por el valle del r\xedo agosto hay horno artesano y supermercado para los que prefieren cocinar en casa y el restaurante el rinc\xf3n de la torre y algunos bares para los que se quieren dejar seducir por la cocina aut\xf3ctona a la casa se llega en transporte privado y hay espacio para aparcar al exterior de la casa en la esplanada de acceso',
#   u'neighborhood': u'N/A',
#   'words': ['can',
#    'gramunt',
#    'es',
#    'una',
#    'masa',
#    'de',
#    'origen',
#    'medieval',
#    'en',
#    'la',
#    'torre',
#    'de',
#    'claramunt',
#    'tras',
#    'su',
#    'rehabilitacin',
#    'integral',
#    'alberga',
#    'tres',
#    'amplios',
#    'apartamentos',
#    'y',
#    'una',
#    'sala',
#    'polivalente',
#    'con',
#    'piscina',
#    'jardin',
#    'y',
#    'terrazas',
#    'con',
#    'magnficas',
#    'vistas',
#    'en',
#    'un',
#    'entorno',
#    'entre',
#    'viedos',
#    'romero',
#    'es',
#    'un',
#    'apartamento',
#    'de',
#    'unos',
#    '60m2',
#    'en',
#    'la',
#    'planta',
#    'primera',
#    'con',
#    'acceso',
#    'a',
#    'una',
#    'magnfica',
#    'terraza',
#    'orientada',
#    'a',
#    'este',
#    'ubicada',
#    'sobre',
#    'la',
#    'restaurada',
#    'cisterna',
#    'de',
#    'agua',
#    'de',
#    'lluvia',
#    'el',
#    'techo',
#    'es',
#    'de',
#    'vigas',
#    'de',
#    'madera',
#    'originales',
#    'el',
#    'suelo',
#    'de',
#    'baldosas',
#    'cermicas',
#    'de',
#    'la',
#    'zona',
#    'las',
#    'paredes',
#    'acabados',
#    'con',
#    'arcilla',
#    'de',
#    'un',
#    'color',
#    'rojizo',
#    'mezclado',
#    'nicamente',
#    'con',
#    'arena',
#    'y',
#    'agua',
#    'la',
#    'cocina',
#    'es',
#    'amplia',
#    'y',
#    'abierta',
#    'que',
#    'permite',
#    'que',
#    'la',
#    'preparacin',
#    'de',
#    'comida',
#    'se',
#    'convierta',
#    'en',
#    'una',
#    'actividad',
#    'comn',
#    'los',
#    'huspedes',
#    'del',
#    'apartamento',
#    'tienen',
#    'acceso',
#    'al',
#    'jardn',
#    'con',
#    'barbacoa',
#    'y',
#    'piscina',
#    'y',
#    'a',
#    'la',
#    'sala',
#    'polivalente',
#    'en',
#    'el',
#    'mismo',
#    'recinto',
#    'donde',
#    'se',
#    'ubica',
#    'el',
#    'apartamento',
#    'vive',
#    'una',
#    'pareja',
#    'encantadora',
#    'que',
#    'puede',
#    'atender',
#    'a',
#    'los',
#    'huspedes',
#    'que',
#    'as',
#    'lo',
#    'deseen',
#    'la',
#    'torre',
#    'de',
#    'claramunt',
#    'la',
#    'masa',
#    'pertenece',
#    'al',
#    'trmino',
#    'municipal',
#    'de',
#    'la',
#    'torre',
#    'de',
#    'claramunt',
#    'un',
#    'pueblo',
#    'con',
#    'un',
#    'casco',
#    'antiguo',
#    'pintoresco',
#    'alrededor',
#    'de',
#    'un',
#    'castillo',
#    'medieval',
#    'consta',
#    'de',
#    'la',
#    'infraestructura',
#    'necesaria',
#    'para',
#    'poder',
#    'prescindir',
#    'de',
#    'ms',
#    'desplazamiento',
#    'que',
#    'los',
#    'veinte',
#    'minutos',
#    'de',
#    'paseo',
#    'hacia',
#    'el',
#    'pueblo',
#    'en',
#    'medio',
#    'de',
#    'los',
#    'viedos',
#    'y',
#    'pasando',
#    'por',
#    'el',
#    'valle',
#    'del',
#    'ro',
#    'agosto',
#    'hay',
#    'horno',
#    'artesano',
#    'y',
#    'supermercado',
#    'para',
#    'los',
#    'que',
#    'prefieren',
#    'cocinar',
#    'en',
#    'casa',
#    'y',
#    'el',
#    'restaurante',
#    'el',
#    'rincn',
#    'de',
#    'la',
#    'torre',
#    'y',
#    'algunos',
#    'bares',
#    'para',
#    'los',
#    'que',
#    'se',
#    'quieren',
#    'dejar',
#    'seducir',
#    'por',
#    'la',
#    'cocina',
#    'autctona',
#    'a',
#    'la',
#    'casa',
#    'se',
#    'llega',
#    'en',
#    'transporte',
#    'privado',
#    'y',
#    'hay',
#    'espacio',
#    'para',
#    'aparcar',
#    'al',
#    'exterior',
#    'de',
#    'la',
#    'casa',
#    'en',
#    'la',
#    'esplanada',
#    'de',
#    'acceso']},
#  {u'_id': u'2066868',
#   'city': u'san-francisco',
#   'doc': '',
#   u'neighborhood': u'Western Addition/NOPA',
#   'traits': ['LABEL_nightlife'],
#   'words': []},
#  {u'_id': u'6',
#   'doc': u'we are located in the heart of north park the perfect spot to stay to be minutes from every major attraction in san diego north park also has the best night life with hot new bars and restaurants within walking distance the house is also only a couple minutes drive from balboa park the zoo and the gaslamp district downtown where comic con is held during the day you can head to the beach or sea world which are a short 10 min drive away it is the perfect combination of daytime activities in san diego and nighttime activities within walking distance at night enjoy the craft beer and cocktails at urbn tiger tiger polite provisions and many more as well as delicious restaurants no shortage of night life close by if you prefer to stay in enjoy our beautiful backyard area including fire pit comfy seating and outdoor heater in case it is a little chilly the living room is comfortable and equipped with a swivel mounted tv connected to apple tv for all your entertainment needs the house is a cute newly remodeled craftsmen with hardwood floors and all the all the modern technology you could ask for and more high speed internet is included the master bedroom has a california king size bed the master has a private bathroom and french doors that lead to the back patio there is also a tv and xbox that can be used for watching hulu netflix ect the second bedroom has a blow up queen size bed or if you have a little one feel free to use the crib there will be fresh crib sheets and of course bedding for the blow up ready for you this room also has it s own tv and apple tv for watching all your favorite shows the second bedroom also has a patio off the room and it s own private bathroom which has also been newly remodeled the house is conveniently located within a block of a grocery store and a bus stop we are also within the range of car2go if you use their service come and enjoy your stay in san diego we have been hosting airbnb for years and we love it we will do everything we can to make sure you enjoy your stay guests will have access to everything in the house accept the office which will be locked we will not be in town but you are welcome to call or text us with any needs you have also we have someone local who will be help in need of an emergency we have the best neighborhood in san diego in my opinion north park has become the hub for craft beer there are so many great restaurants and bars but without the crowds or tourist feel of downtown this is a great community and such a fun area to be we are right around the corner from a bus stop which is a great way to get downtown quick also since it is so close to downtown and other attractions you can still get a cab or lyft to downtown for under 20 however if you are coming into town for a major event like comic con be careful as the rates for lyfts and ubers can go up and usually do go up quite a bit it might be best to check the bus schedule check out car2go or rent a car',
#   u'neighborhood': u'North Park',
#   'words': ['we',
#    'are',
#    'located',
#    'in',
#    'the',
#    'heart',
#    'of',
#    'north',
#    'park',
#    'the',
#    'perfect',
#    'spot',
#    'to',
#    'stay',
#    'to',
#    'be',
#    'minutes',
#    'from',
#    'every',
#    'major',
#    'attraction',
#    'in',
#    'san',
#    'diego',
#    'north',
#    'park',
#    'also',
#    'has',
#    'the',
#    'best',
#    'night',
#    'life',
#    'with',
#    'hot',
#    'new',
#    'bars',
#    'and',
#    'restaurants',
#    'within',
#    'walking',
#    'distance',
#    'the',
#    'house',
#    'is',
#    'also',
#    'only',
#    'a',
#    'couple',
#    'minutes',
#    'drive',
#    'from',
#    'balboa',
#    'park',
#    'the',
#    'zoo',
#    'and',
#    'the',
#    'gaslamp',
#    'district',
#    'downtown',
#    'where',
#    'comic',
#    'con',
#    'is',
#    'held',
#    'during',
#    'the',
#    'day',
#    'you',
#    'can',
#    'head',
#    'to',
#    'the',
#    'beach',
#    'or',
#    'sea',
#    'world',
#    'which',
#    'are',
#    'a',
#    'short',
#    '10',
#    'min',
#    'drive',
#    'away',
#    'it',
#    'is',
#    'the',
#    'perfect',
#    'combination',
#    'of',
#    'daytime',
#    'activities',
#    'in',
#    'san',
#    'diego',
#    'and',
#    'nighttime',
#    'activities',
#    'within',
#    'walking',
#    'distance',
#    'at',
#    'night',
#    'enjoy',
#    'the',
#    'craft',
#    'beer',
#    'and',
#    'cocktails',
#    'at',
#    'urbn',
#    'tiger',
#    'tiger',
#    'polite',
#    'provisions',
#    'and',
#    'many',
#    'more',
#    'as',
#    'well',
#    'as',
#    'delicious',
#    'restaurants',
#    'no',
#    'shortage',
#    'of',
#    'night',
#    'life',
#    'close',
#    'by',
#    'if',
#    'you',
#    'prefer',
#    'to',
#    'stay',
#    'in',
#    'enjoy',
#    'our',
#    'beautiful',
#    'backyard',
#    'area',
#    'including',
#    'fire',
#    'pit',
#    'comfy',
#    'seating',
#    'and',
#    'outdoor',
#    'heater',
#    'in',
#    'case',
#    'it',
#    'is',
#    'a',
#    'little',
#    'chilly',
#    'the',
#    'living',
#    'room',
#    'is',
#    'comfortable',
#    'and',
#    'equipped',
#    'with',
#    'a',
#    'swivel',
#    'mounted',
#    'tv',
#    'connected',
#    'to',
#    'apple',
#    'tv',
#    'for',
#    'all',
#    'your',
#    'entertainment',
#    'needs',
#    'the',
#    'house',
#    'is',
#    'a',
#    'cute',
#    'newly',
#    'remodeled',
#    'craftsmen',
#    'with',
#    'hardwood',
#    'floors',
#    'and',
#    'all',
#    'the',
#    'all',
#    'the',
#    'modern',
#    'technology',
#    'you',
#    'could',
#    'ask',
#    'for',
#    'and',
#    'more',
#    'high',
#    'speed',
#    'internet',
#    'is',
#    'included',
#    'the',
#    'master',
#    'bedroom',
#    'has',
#    'a',
#    'california',
#    'king',
#    'size',
#    'bed',
#    'the',
#    'master',
#    'has',
#    'a',
#    'private',
#    'bathroom',
#    'and',
#    'french',
#    'doors',
#    'that',
#    'lead',
#    'to',
#    'the',
#    'back',
#    'patio',
#    'there',
#    'is',
#    'also',
#    'a',
#    'tv',
#    'and',
#    'xbox',
#    'that',
#    'can',
#    'be',
#    'used',
#    'for',
#    'watching',
#    'hulu',
#    'netflix',
#    'ect',
#    'the',
#    'second',
#    'bedroom',
#    'has',
#    'a',
#    'blow',
#    'up',
#    'queen',
#    'size',
#    'bed',
#    'or',
#    'if',
#    'you',
#    'have',
#    'a',
#    'little',
#    'one',
#    'feel',
#    'free',
#    'to',
#    'use',
#    'the',
#    'crib',
#    'there',
#    'will',
#    'be',
#    'fresh',
#    'crib',
#    'sheets',
#    'and',
#    'of',
#    'course',
#    'bedding',
#    'for',
#    'the',
#    'blow',
#    'up',
#    'ready',
#    'for',
#    'you',
#    'this',
#    'room',
#    'also',
#    'has',
#    'it',
#    's',
#    'own',
#    'tv',
#    'and',
#    'apple',
#    'tv',
#    'for',
#    'watching',
#    'all',
#    'your',
#    'favorite',
#    'shows',
#    'the',
#    'second',
#    'bedroom',
#    'also',
#    'has',
#    'a',
#    'patio',
#    'off',
#    'the',
#    'room',
#    'and',
#    'it',
#    's',
#    'own',
#    'private',
#    'bathroom',
#    'which',
#    'has',
#    'also',
#    'been',
#    'newly',
#    'remodeled',
#    'the',
#    'house',
#    'is',
#    'conveniently',
#    'located',
#    'within',
#    'a',
#    'block',
#    'of',
#    'a',
#    'grocery',
#    'store',
#    'and',
#    'a',
#    'bus',
#    'stop',
#    'we',
#    'are',
#    'also',
#    'within',
#    'the',
#    'range',
#    'of',
#    'car2go',
#    'if',
#    'you',
#    'use',
#    'their',
#    'service',
#    'come',
#    'and',
#    'enjoy',
#    'your',
#    'stay',
#    'in',
#    'san',
#    'diego',
#    'we',
#    'have',
#    'been',
#    'hosting',
#    'airbnb',
#    'for',
#    'years',
#    'and',
#    'we',
#    'love',
#    'it',
#    'we',
#    'will',
#    'do',
#    'everything',
#    'we',
#    'can',
#    'to',
#    'make',
#    'sure',
#    'you',
#    'enjoy',
#    'your',
#    'stay',
#    'guests',
#    'will',
#    'have',
#    'access',
#    'to',
#    'everything',
#    'in',
#    'the',
#    'house',
#    'accept',
#    'the',
#    'office',
#    'which',
#    'will',
#    'be',
#    'locked',
#    'we',
#    'will',
#    'not',
#    'be',
#    'in',
#    'town',
#    'but',
#    'you',
#    'are',
#    'welcome',
#    'to',
#    'call',
#    'or',
#    'text',
#    'us',
#    'with',
#    'any',
#    'needs',
#    'you',
#    'have',
#    'also',
#    'we',
#    'have',
#    'someone',
#    'local',
#    'who',
#    'will',
#    'be',
#    'help',
#    'in',
#    'need',
#    'of',
#    'an',
#    'emergency',
#    'we',
#    'have',
#    'the',
#    'best',
#    'neighborhood',
#    'in',
#    'san',
#    'diego',
#    'in',
#    'my',
#    'opinion',
#    'north',
#    'park',
#    'has',
#    'become',
#    'the',
#    'hub',
#    'for',
#    'craft',
#    'beer',
#    'there',
#    'are',
#    'so',
#    'many',
#    'great',
#    'restaurants',
#    'and',
#    'bars',
#    'but',
#    'without',
#    'the',
#    'crowds',
#    'or',
#    'tourist',
#    'feel',
#    'of',
#    'downtown',
#    'this',
#    'is',
#    'a',
#    'great',
#    'community',
#    'and',
#    'such',
#    'a',
#    'fun',
#    'area',
#    'to',
#    'be',
#    'we',
#    'are',
#    'right',
#    'around',
#    'the',
#    'corner',
#    'from',
#    'a',
#    'bus',
#    'stop',
#    'which',
#    'is',
#    'a',
#    'great',
#    'way',
#    'to',
#    'get',
#    'downtown',
#    'quick',
#    'also',
#    'since',
#    'it',
#    'is',
#    'so',
#    'close',
#    'to',
#    'downtown',
#    'and',
#    'other',
#    'attractions',
#    'you',
#    'can',
#    'still',
#    'get',
#    'a',
#    'cab',
#    'or',
#    'lyft',
#    'to',
#    'downtown',
#    'for',
#    'under',
#    '20',
#    'however',
#    'if',
#    'you',
#    'are',
#    'coming',
#    'into',
#    'town',
#    'for',
#    'a',
#    'major',
#    'event',
#    'like',
#    'comic',
#    'con',
#    'be',
#    'careful',
#    'as',
#    'the',
#    'rates',
#    'for',
#    'lyfts',
#    'and',
#    'ubers',
#    'can',
#    'go',
#    'up',
#    'and',
#    'usually',
#    'do',
#    'go',
#    'up',
#    'quite',
#    'a',
#    'bit',
#    'it',
#    'might',
#    'be',
#    'best',
#    'to',
#    'check',
#    'the',
#    'bus',
#    'schedule',
#    'check',
#    'out',
#    'car2go',
#    'or',
#    'rent',
#    'a',
#    'car']},
#  {u'_id': u'4', 'doc': '', u'neighborhood': u'N/A', 'words': []}]

# %% [markdown]
# #Map neighborhoods to traits!

# %%
import airbnbneighborhood as airn

DB_NAME = 'airbnb'
COLL_NAME_NEIGHBORHOOD = 'neighborhoods'

# %%
reload(airn)

air_hood = airn.AirBnBNeighborhood(db_name=DB_NAME, coll_name=COLL_NAME_NEIGHBORHOOD)
air_hood

# %%
#Grab the hood list
hood_list = list(air_hood.coll.find({},{'_id':1, 'neighborhood':1, 'traits':1, 'city':1}))
hood_list[0]
# Out:
# {u'_id': 0,
#  u'city': u'san-francisco',
#  u'neighborhood': u'Alamo Square',
#  u'traits': [u'Loved by San Franciscans', u'Stunning Views', u'Touristy']}

# %%
set(sum([x['traits'] for x in hood_list]))
# Out:
# {u'Artsy',
#  u'Cultural Enclaves',
#  u'Dining',
#  u'Great Transit',
#  u'Loved by New Yorkers',
#  u'Loved by San Franciscans',
#  u'Nightlife',
#  u'Peace & Quiet',
#  u'Shopping',
#  u'Stunning Views',
#  u'Touristy',
#  u'Trendy'}

# %%
set(([x['neighborhood'] for x in hood_list]))
# Out:
# {u'Alamo Square',
#  u'Alphabet City',
#  u'Astoria',
#  u'Battery Park City',
#  u'Bayview',
#  u'Bedford-Stuyvesant',
#  u'Bernal Heights',
#  u'Boerum Hill',
#  u'Brooklyn Heights',
#  u'Bushwick',
#  u'Carroll Gardens',
#  u'Chelsea',
#  u'Chinatown',
#  u'Civic Center',
#  u'Clinton Hill',
#  u'Cobble Hill',
#  u'Cole Valley',
#  u'Cow Hollow',
#  u'Crown Heights',
#  u'DUMBO',
#  u'Dogpatch',
#  u'Downtown',
#  u'Downtown Brooklyn',
#  u'Duboce Triangle',
#  u'East Harlem',
#  u'East Village',
#  u'Excelsior',
#  u'Financial District',
#  u"Fisherman's Wharf",
#  u'Flatbush',
#  u'Flatiron District',
#  u'Flushing',
#  u'Fort Greene',
#  u'Glen Park',
#  u'Gowanus',
#  u'Gramercy Park',
#  u'Greenpoint',
#  u'Greenwich Village',
#  u'Haight-Ashbury',
#  u'Harlem',
#  u'Hayes Valley',
#  u"Hell's Kitchen",
#  u'Hudson Square',
#  u'Inner Sunset',
#  u'Inwood',
#  u'Jackson Heights',
#  u'Japantown',
#  u'Kensington',
#  u'Kips Bay',
#  u'Lefferts Garden',
#  u'Little Italy',
#  u'Long Island City',
#  u'Lower East Side',
#  u'Lower Haight',
#  u'Marina',
#  u'Meatpacking District',
#  u'Midtown',
#  u'Midtown East',
#  u'Mission Bay',
#  u'Mission District',
#  u'Mission Terrace',
#  u'Morningside Heights',
#  u'Murray Hill',
#  u'Nob Hill',
#  u'Noe Valley',
#  u'Noho',
#  u'Nolita',
#  u'North Beach',
#  u'Outer Sunset',
#  u'Pacific Heights',
#  u'Park Slope',
#  u'Parkside',
#  u'Portola',
#  u'Potrero Hill',
#  u'Presidio Heights',
#  u'Prospect Heights',
#  u'Red Hook',
#  u'Richmond District',
#  u'Ridgewood',
#  u'Russian Hill',
#  u'SoMa',
#  u'Soho',
#  u'South Beach',
#  u'South Street Seaport',
#  u'Telegraph Hill',
#  u'Tenderloin',
#  u'The Castro',
#  u'Times Square/Theatre District',
#  u'Tribeca',
#  u'Twin Peaks',
#  u'Union Square',
#  u'Upper East Side',
#  u'Upper West Side',
#  u'Visitacion Valley',
#  u'Washington Heights',
#  u'West Village',
#  u'Western Addition/NOPA',
#  u'Williamsburg',
#  u'Windsor Terrace'}

# %%
#Make a dict to make it easier to map
clean_label_map = {'Artsy':'LABEL_artsy',
                 'Cultural Enclaves':'LABEL_cultural_enclave',
                 'Dining':'LABEL_dining',
                 'Great Transit':'LABEL_great_transit',
                 'Loved by New Yorkers':'LABEL_loved_by_locals',
                 'Loved by San Franciscans':'LABEL_loved_by_locals',
                 'Nightlife':'LABEL_nightlife',
                 'Peace & Quiet':'LABEL_peace_and_quiet',
                 'Shopping':'LABEL_shopping',
                 'Stunning Views':'LABEL_stunning_views',
                 'Touristy':'LABEL_touristy',
                 'Trendy':'LABEL_trendy'}

#for hood in hood_list:
#    hood['traits'] = map(lambda x: clean_label_map[x],hood['traits'])
    
hood_to_traits = {x['neighborhood']:x['traits'] for x in hood_list}
hood_to_city = {x['neighborhood']:x['city'] for x in hood_list}

# %%
for listing in listing_list:
    if listing['neighborhood'] in hood_to_traits:
        listing['traits'] = hood_to_traits[listing['neighborhood']]
        listing['city'] = hood_to_city[listing['neighborhood']]

# %%
listing_list[10]
# Out:
# {u'_id': u'6701531',
#  'city': u'san-francisco',
#  'doc': '',
#  u'neighborhood': u'Tenderloin',
#  'traits': ['LABEL_dining', 'LABEL_nightlife'],
#  'words': []}

# %%
#Number of lisitngs that mapped a neighborhood
sum(['traits' in x for x in listing_list])
# Out:
# 3369

# %%
#Number of lisitngs that mapped a neighborhood with a trait 
model_data_cond = ['traits' in l and l['traits'] != [] and l['words'] != [] for l in listing_list]
print model_data_cond[:5]
model_data = [l for l in listing_list if 'traits' in l if l['traits'] != [] if l['words'] != []]
len(model_data)
# Out:
# [False, False, False, False, False]
# 2935

# %% [markdown]
# #Build Doc2Vec model

# %%
from gensim.models import Word2Vec

# %% [markdown]
# ###test Word2Vec

# %%
docs = [x['words'] for x in model_data]
model = Word2Vec(docs)

# %%
#playing around with Word2Vec
model.most_similar(positive=['neighborhood'], negative=['local'], topn=10)
# Out:
# [('loft', 0.5207953453063965),
#  ('originally', 0.5049461126327515),
#  ('rare', 0.5005202293395996),
#  ('1907', 0.4987376928329468),
#  ('become', 0.4931432902812958),
#  ('1906', 0.48724865913391113),
#  ('1908', 0.477723091840744),
#  ('incredibly', 0.47167205810546875),
#  ('bask', 0.4708530902862549),
#  ('oasis', 0.4697762429714203)]

# %%
#Most common words
from collections import defaultdict

d = defaultdict(int)
for word, obj in model.vocab.iteritems():
    d[word] = obj.count
sorted(dict(d), key=lambda x: d[x], reverse=True)
# Out:
# ['the',
#  'and',
#  'a',
#  'to',
#  'is',
#  'in',
#  'of',
#  'you',
#  'with',
#  'for',
#  'are',
#  'on',
#  'from',
#  'i',
#  'or',
#  'we',
#  'it',
#  'have',
#  'your',
#  'apartment',
#  'there',
#  'room',
#  'will',
#  'as',
#  's',
#  'this',
#  'be',
#  'street',
#  'all',
#  'can',
#  'at',
#  'that',
#  'if',
#  'walk',
#  'away',
#  'has',
#  'kitchen',
#  '2',
#  'one',
#  'park',
#  'our',
#  'also',
#  'blocks',
#  'neighborhood',
#  'city',
#  'restaurants',
#  'bed',
#  'bedroom',
#  'access',
#  'an',
#  'very',
#  'living',
#  '1',
#  'by',
#  'new',
#  'home',
#  'but',
#  'great',
#  'full',
#  'two',
#  'my',
#  'guests',
#  'so',
#  'just',
#  'san',
#  'not',
#  'block',
#  'located',
#  'area',
#  'out',
#  'available',
#  'building',
#  'minutes',
#  'francisco',
#  'house',
#  'up',
#  'train',
#  '3',
#  '5',
#  'bathroom',
#  'parking',
#  'space',
#  'private',
#  'stay',
#  'bus',
#  'please',
#  'no',
#  'other',
#  'subway',
#  'large',
#  'which',
#  'square',
#  'well',
#  'minute',
#  'walking',
#  'free',
#  'coffee',
#  'get',
#  'tv',
#  'like',
#  'manhattan',
#  'mission',
#  'need',
#  'floor',
#  'queen',
#  'easy',
#  'within',
#  'time',
#  'about',
#  'around',
#  'any',
#  'close',
#  'more',
#  'brooklyn',
#  'take',
#  'only',
#  'best',
#  'many',
#  'people',
#  'size',
#  'place',
#  'bars',
#  'use',
#  '4',
#  '10',
#  'check',
#  'downtown',
#  'distance',
#  'shops',
#  'location',
#  't',
#  'east',
#  'most',
#  'center',
#  'here',
#  'quiet',
#  'public',
#  'day',
#  'beautiful',
#  'do',
#  'clean',
#  'lines',
#  'enjoy',
#  'st',
#  'station',
#  'right',
#  'car',
#  'guest',
#  'some',
#  '15',
#  'wifi',
#  'am',
#  'transportation',
#  'dryer',
#  'me',
#  'min',
#  'district',
#  'comfortable',
#  'central',
#  'bart',
#  'm',
#  'its',
#  'when',
#  'cable',
#  'flat',
#  'dining',
#  'than',
#  'hidden',
#  'high',
#  '6',
#  'shared',
#  'few',
#  'internet',
#  'towels',
#  'make',
#  'fully',
#  'garden',
#  'muni',
#  'night',
#  'door',
#  'during',
#  'where',
#  'line',
#  'll',
#  'want',
#  're',
#  'food',
#  'nyc',
#  'shopping',
#  'everything',
#  'live',
#  'laundry',
#  'york',
#  'including',
#  'unit',
#  'feel',
#  'own',
#  'see',
#  'short',
#  'etc',
#  'corner',
#  'may',
#  'local',
#  'washer',
#  'stop',
#  'love',
#  '20',
#  'side',
#  'us',
#  'they',
#  'sf',
#  'nearby',
#  'much',
#  'trains',
#  'over',
#  'down',
#  'art',
#  'small',
#  'gate',
#  'go',
#  'times',
#  'union',
#  'bedrooms',
#  'ride',
#  'market',
#  '7',
#  'off',
#  'bay',
#  'light',
#  'heart',
#  'front',
#  'into',
#  'work',
#  'after',
#  'golden',
#  'shower',
#  'views',
#  'questions',
#  'who',
#  'lots',
#  'find',
#  'friendly',
#  'back',
#  'c',
#  'bath',
#  'safe',
#  'spacious',
#  'hill',
#  'always',
#  'top',
#  'plenty',
#  'airport',
#  'air',
#  'open',
#  'closet',
#  'ave',
#  'equipped',
#  'village',
#  'modern',
#  'provided',
#  'cafes',
#  'museum',
#  'near',
#  'loft',
#  'west',
#  'floors',
#  'phone',
#  'both',
#  'windows',
#  '24',
#  'help',
#  'stores',
#  'little',
#  'beach',
#  'amazing',
#  'table',
#  'l',
#  'perfect',
#  'welcome',
#  'microwave',
#  'entire',
#  'avenue',
#  'linens',
#  'know',
#  'while',
#  'would',
#  'every',
#  'williamsburg',
#  'lower',
#  'f',
#  'sized',
#  'airbnb',
#  'three',
#  'rooms',
#  'additional',
#  '30',
#  'steps',
#  'world',
#  'happy',
#  'don',
#  'website',
#  'provide',
#  'between',
#  'valley',
#  'cleaning',
#  'sofa',
#  'each',
#  'offer',
#  'service',
#  'their',
#  'across',
#  'convenient',
#  'music',
#  'good',
#  'through',
#  'studio',
#  'stops',
#  'neighborhoods',
#  'long',
#  'amenities',
#  'n',
#  'buses',
#  'family',
#  'd',
#  'extra',
#  'castro',
#  'features',
#  'bike',
#  'nice',
#  'outside',
#  'bridge',
#  'grocery',
#  'view',
#  'garage',
#  'deck',
#  'furnished',
#  'fresh',
#  'come',
#  'email',
#  'several',
#  'famous',
#  'j',
#  'north',
#  'mattress',
#  'screen',
#  'heights',
#  'entrance',
#  'included',
#  'less',
#  'store',
#  'leave',
#  'town',
#  'haight',
#  'note',
#  'way',
#  'person',
#  'share',
#  'areas',
#  'yourself',
#  'super',
#  'couch',
#  'historic',
#  'whole',
#  'rental',
#  'give',
#  'before',
#  'beds',
#  'appliances',
#  'anything',
#  'fee',
#  'bar',
#  'experience',
#  'what',
#  'hour',
#  'number',
#  'main',
#  'first',
#  'b',
#  'south',
#  'throughout',
#  'ask',
#  'major',
#  'places',
#  'even',
#  '8',
#  'big',
#  'lot',
#  'separate',
#  'been',
#  'backyard',
#  'wireless',
#  'dishwasher',
#  'transit',
#  'stove',
#  'includes',
#  'via',
#  'fun',
#  'e',
#  'next',
#  'privacy',
#  'easily',
#  'streets',
#  'sunny',
#  'restaurant',
#  'let',
#  'sheets',
#  'water',
#  'sleep',
#  'renovated',
#  'second',
#  'tub',
#  'cozy',
#  'refrigerator',
#  'hardwood',
#  'upon',
#  'things',
#  'oven',
#  'miles',
#  'brand',
#  'such',
#  'too',
#  'apt',
#  'key',
#  'r',
#  'host',
#  'anywhere',
#  'really',
#  'per',
#  'then',
#  'g',
#  'hours',
#  'speed',
#  'visit',
#  'q',
#  'end',
#  'four',
#  'taxi',
#  'fridge',
#  'part',
#  'sure',
#  'wine',
#  'along',
#  'half',
#  'arrival',
#  'desk',
#  'days',
#  'cooking',
#  'foot',
#  'accommodate',
#  'was',
#  'master',
#  'them',
#  'old',
#  'request',
#  'breakfast',
#  'patio',
#  'double',
#  'bathrooms',
#  'needed',
#  'set',
#  'twin',
#  'level',
#  'term',
#  'couple',
#  'property',
#  'parks',
#  'soho',
#  'gas',
#  'eat',
#  '12',
#  'same',
#  'broadway',
#  'travel',
#  'cafe',
#  'looking',
#  'elevator',
#  'huge',
#  'wi',
#  'ceilings',
#  'keys',
#  'keep',
#  'unique',
#  'rent',
#  'fi',
#  'book',
#  'morning',
#  'common',
#  'however',
#  'community',
#  'upstairs',
#  'tea',
#  'late',
#  'lovely',
#  '24th',
#  'attractions',
#  'downstairs',
#  'include',
#  'life',
#  'years',
#  'victorian',
#  'maker',
#  'financial',
#  'w',
#  'express',
#  'netflix',
#  'charming',
#  '25',
#  'quick',
#  'mins',
#  'takes',
#  'roof',
#  'foods',
#  'comfortably',
#  'ocean',
#  'outdoor',
#  'iron',
#  'booking',
#  'plus',
#  'wonderful',
#  'newly',
#  'system',
#  'yard',
#  'accessible',
#  'office',
#  'hotel',
#  'hot',
#  'galleries',
#  'staying',
#  'natural',
#  'built',
#  'cool',
#  'chinatown',
#  'meet',
#  'sleeps',
#  'cook',
#  'vibrant',
#  'spot',
#  'usually',
#  'stocked',
#  'toaster',
#  'window',
#  'nightlife',
#  'comes',
#  'offers',
#  'because',
#  '0',
#  'young',
#  'style',
#  'sq',
#  'those',
#  'being',
#  'week',
#  'midtown',
#  'upper',
#  'wall',
#  'smoking',
#  'how',
#  'cab',
#  'diverse',
#  'residential',
#  'children',
#  'french',
#  'hair',
#  'security',
#  'tons',
#  'answer',
#  'might',
#  'these',
#  'going',
#  'often',
#  'theater',
#  'dolores',
#  'directly',
#  'noe',
#  'explore',
#  'boutiques',
#  'could',
#  'options',
#  'uber',
#  'suite',
#  'lounge',
#  'shop',
#  '50',
#  'must',
#  'shampoo',
#  'furniture',
#  'another',
#  'king',
#  'text',
#  'storage',
#  'call',
#  'trendy',
#  'favorite',
#  'single',
#  'museums',
#  'sun',
#  'conveniently',
#  'try',
#  'should',
#  'excellent',
#  'jfk',
#  'river',
#  'ft',
#  'getting',
#  'services',
#  'stainless',
#  'bright',
#  '100',
#  'arrive',
#  'coming',
#  'sharing',
#  'filled',
#  'ferry',
#  'still',
#  'chairs',
#  'look',
#  'able',
#  'middle',
#  'friends',
#  'drive',
#  'rooftop',
#  'feet',
#  'italian',
#  'machine',
#  'centrally',
#  'valencia',
#  'wharf',
#  'busy',
#  'working',
#  'bedford',
#  'details',
#  'prospect',
#  'charge',
#  '9',
#  '2nd',
#  'complete',
#  'pretty',
#  'never',
#  'glass',
#  'bring',
#  've',
#  'fast',
#  'reservation',
#  'above',
#  'grand',
#  'dog',
#  'pets',
#  'information',
#  'stairs',
#  'steel',
#  'contact',
#  'once',
#  'business',
#  'culture',
#  'stays',
#  'course',
#  'early',
#  'different',
#  'embarcadero',
#  'known',
#  'convenience',
#  'run',
#  'wood',
#  'five',
#  'hall',
#  'inside',
#  'sleeping',
#  'hip',
#  'relax',
#  'gym',
#  'popular',
#  'tree',
#  'listing',
#  'spots',
#  'under',
#  'since',
#  'board',
#  'harlem',
#  'soma',
#  'fantastic',
#  '00',
#  'noise',
#  'possible',
#  'island',
#  'extremely',
#  'show',
#  'read',
#  'sfo',
#  'families',
#  'real',
#  'used',
#  'fireplace',
#  'neighbors',
#  'church',
#  'comfy',
#  'utensils',
#  'multiple',
#  'gourmet',
#  'california',
#  'either',
#  'sink',
#  'luxury',
#  'ground',
#  'now',
#  'price',
#  'without',
#  'entertainment',
#  'yet',
#  'hayes',
#  'state',
#  'awesome',
#  'rest',
#  'hang',
#  'original',
#  'gardens',
#  'basement',
#  'making',
#  'doors',
#  'chelsea',
#  'movie',
#  'pacific',
#  'trip',
#  'player',
#  '11',
#  'interaction',
#  'spaces',
#  'conditioner',
#  'pots',
#  'fisherman',
#  'soap',
#  'completely',
#  'green',
#  'organic',
#  'true',
#  'special',
#  'artists',
#  'pans',
#  'quality',
#  'summer',
#  'cars',
#  'ideal',
#  'z',
#  'plan',
#  'bushwick',
#  'longer',
#  'futon',
#  'else',
#  'bedding',
#  'fillmore',
#  'gorgeous',
#  'dinner',
#  'balcony',
#  'kids',
#  'does',
#  'month',
#  'remodeled',
#  'basic',
#  'dresser',
#  'dvd',
#  'addition',
#  'needs',
#  'conditioning',
#  'grill',
#  'presidio',
#  'hand',
#  'pick',
#  'recommendations',
#  'recently',
#  'brownstone',
#  'enough',
#  'subways',
#  'site',
#  'marina',
#  'nights',
#  'quite',
#  'play',
#  'tourist',
#  'metro',
#  'heat',
#  'pillows',
#  'markets',
#  'warm',
#  'prior',
#  'clinton',
#  'items',
#  'personal',
#  'interesting',
#  'third',
#  '5th',
#  'apple',
#  'civic',
#  'lined',
#  'transport',
#  'fort',
#  'events',
#  'daily',
#  'makes',
#  'academy',
#  'travelers',
#  'sleeper',
#  'facing',
#  'runs',
#  'goes',
#  'condo',
#  'japanese',
#  'far',
#  '3rd',
#  'clubs',
#  'bernal',
#  '101',
#  'dishes',
#  'ceiling',
#  'ashbury',
#  '40',
#  'weekends',
#  'brick',
#  'lived',
#  'mile',
#  'lock',
#  'pm',
#  'heating',
#  'ny',
#  'everyone',
#  'though',
#  'made',
#  'recommend',
#  'depending',
#  'having',
#  'watch',
#  'television',
#  'history',
#  'urban',
#  'stations',
#  '14',
#  'respect',
#  'pool',
#  'bathtub',
#  'bbq',
#  'sometimes',
#  'literally',
#  'pizza',
#  'american',
#  'below',
#  'yours',
#  'dates',
#  'taxis',
#  'code',
#  'direction',
#  'something',
#  'parts',
#  'left',
#  'yes',
#  'gets',
#  'library',
#  'year',
#  'everywhere',
#  'supermarket',
#  'deposit',
#  'traveling',
#  'drink',
#  'fees',
#  'buildings',
#  'owner',
#  'direct',
#  'rates',
#  'head',
#  'non',
#  'truly',
#  'granite',
#  'wash',
#  'fine',
#  'italy',
#  'alamo',
#  'enter',
#  'movies',
#  'bit',
#  'interact',
#  'utilities',
#  'yoga',
#  'minimum',
#  '280',
#  'slope',
#  'prefer',
#  'almost',
#  'catch',
#  'ready',
#  'international',
#  'sound',
#  'sunset',
#  'he',
#  'message',
#  'ironing',
#  'meeting',
#  'shuttle',
#  'won',
#  'looky',
#  'situated',
#  'bakery',
#  'variety',
#  'someone',
#  'story',
#  'reach',
#  'necessary',
#  'pay',
#  'pull',
#  'closets',
#  'greene',
#  'had',
#  'terrace',
#  'case',
#  'drop',
#  'books',
#  'tips',
#  'generally',
#  'walls',
#  'send',
#  'luggage',
#  'electric',
#  'entry',
#  'chair',
#  'ac',
#  'counter',
#  'means',
#  'ten',
#  'foam',
#  'safeway',
#  'lyft',
#  'marble',
#  'respectful',
#  'hope',
#  'secure',
#  'professionals',
#  '4th',
#  'meal',
#  'total',
#  'especially',
#  'availability',
#  'cost',
#  'using',
#  'kettle',
#  'seating',
#  'parties',
#  'suggestions',
#  'last',
#  'la',
#  'relaxing',
#  'farmers',
#  'judah',
#  'ever',
#  'doorman',
#  'venues',
#  'cat',
#  'stroll',
#  'toilet',
#  'caltrain',
#  'decorated',
#  'unless',
#  '1st',
#  'professional',
#  'called',
#  'group',
#  'comfort',
#  'visiting',
#  'moscone',
#  'provides',
#  'weather',
#  'hard',
#  'delicious',
#  'cultural',
#  'score',
#  'say',
#  'vacation',
#  'others',
#  'potrero',
#  'white',
#  'visitors',
#  'hallway',
#  'classic',
#  'spend',
#  'forward',
#  'numerous',
#  'peaceful',
#  'theaters',
#  'de',
#  'evening',
#  'clothes',
#  'authentic',
#  'glen',
#  'although',
#  'sunlight',
#  'name',
#  'complimentary',
#  'divisadero',
#  'mini',
#  'designed',
#  'itself',
#  'blue',
#  'ice',
#  'range',
#  'empire',
#  ...]

# %% [markdown]
# #Doc2Vec Model Creation

# %%
from gensim.models.doc2vec import LabeledSentence, Doc2Vec

# %%
labeled_listings = []
for listing in model_data:
    labeled_listing = LabeledSentence(words = listing['words'], labels = listing['traits'] + ["LISTING_" + listing['_id'], "HOOD_" + listing['neighborhood'].replace(' ','_'), "CITY_" + listing['city']])
    labeled_listings.append(labeled_listing)

# %%
model = Doc2Vec(labeled_listings)

# %%
model.most_similar(positive=['CITY_new-york'], negative=[], topn=20)
# Out:
# [(u'LISTING_596576', 0.7788791656494141),
#  (u'LISTING_2496086', 0.7784890532493591),
#  (u'LISTING_6785229', 0.7777861952781677),
#  (u'LISTING_348714', 0.7774398326873779),
#  (u'LISTING_102477', 0.7757824659347534),
#  (u'LISTING_4882295', 0.7748103141784668),
#  ('vous', 0.7744808197021484),
#  (u'LISTING_267820', 0.7734787464141846),
#  (u'LISTING_764010', 0.7732689380645752),
#  (u'LISTING_70753', 0.7608593106269836),
#  (u'LISTING_242614', 0.7570623159408569),
#  (u'LISTING_2315086', 0.7514861822128296),
#  (u'LISTING_44323', 0.7463805675506592),
#  (u'LISTING_5013816', 0.7418489456176758),
#  ('pas', 0.7183961868286133),
#  (u'LISTING_748256', 0.71689772605896),
#  (u'LISTING_5298133', 0.7097851037979126),
#  (u'CITY_san-francisco', 0.6964515447616577),
#  (u'LISTING_713877', 0.6962674856185913),
#  (u'LISTING_6168082', 0.6903549432754517)]

# %%
air_listing.pull_from_db(listing_id = '348714')
air_listing.extract_features()
# Out:
# {'address': 'Lyon St, San Francisco (Western Addition/NOPA)',
#  'description_raw': u'\nThe Space\nPrivate garden room in large Queen Anne Victorian, half a block from Golden Gate Park (botanical garden, buffalo paddock, science center) 5 Blocks from Haight Asbury, 15 minute walk to the Castro, 4 blocks from Historic Alamo Square and the Painted Ladys. Muni to downtown 100 ft away. Includes 32" TV, wet bar, microwave, coffee maker, small fridge, private bath, on site laundry and separate entrance way. Internet Wi Fi free. Backyard patio access. \nNorth Panhandle Area with fine gourmet restaurants just blocks away. There is so much to do and see in this area that you\'ll never be bored! For food options, check out the soul food at Eddie\'s Cafe, Ethiopian at Assab Eritrean Restaurant or the Cuban / tapas at Cha Cha Cha! For night life, you have the low key atmosphere of the sake bar Corkage Sake & Wine Shop, the swanky interior of Internos Wine Cafe or the dive bar Lucky 13! \nIf you have any questions, please feel free to contact me!\n\n',
#  'headline': 'Apartment in San Francisco, United States. Private garden room in large Queen Anne Victorian, half a block from Golden Gate Park (botanical garden, buffalo paddock, science center) 5 Blocks from Haight Asbury, 15 minute walk to the Castro, 4 blocks from Historic Alamo Square and the Painte...',
#  'listing_name': 'Elegant Victorian Studio ',
#  'neighborhood': u'Western Addition/NOPA',
#  'num_saved': 'Saved 1817 times',
#  'price': '170',
#  'price_currency': 'USD'}

# %%
model_data[0]
# Out:
# {u'_id': u'2066868',
#  u'neighborhood': u'Western Addition/NOPA',
#  'traits': ['LABEL_nightlife'],
#  'words': []}

# %% [markdown]
# #Naive Bayes Model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.cross_validation import train_test_split

# %%
# y = ['LABEL_artsy' in x['traits'] for x in model_data]
y = ['LABEL_dining' in x['traits'] for x in model_data]

X_raw = [x['doc'] for x in model_data]
X_train_raw, X_test_raw, y_train, y_test = train_test_split(X_raw, y, random_state=1) 

tfidf = TfidfVectorizer(max_df = .7, min_df=2)
vectorized_corpus = tfidf.fit_transform(X_train_raw)
X_train = vectorized_corpus.toarray()

# %%
sorted(zip(tfidf.get_feature_names(), tfidf.idf_), key=lambda x: x[1])[:20]
# Out:
# [(u'kitchen', 1.3640983028961442),
#  (u'restaurants', 1.4422365072052874),
#  (u'have', 1.4471957805646376),
#  (u'or', 1.4622228969677937),
#  (u'room', 1.4701852987893362),
#  (u'all', 1.4716398445003307),
#  (u'this', 1.4870416891118372),
#  (u'it', 1.4959504340009466),
#  (u'will', 1.5147692053973629),
#  (u'there', 1.5300834403704053),
#  (u'be', 1.5347238199269075),
#  (u'your', 1.5472044811505166),
#  (u'bed', 1.555876194932134),
#  (u'apartment', 1.5630275960897593),
#  (u'can', 1.5742546586835426),
#  (u'at', 1.5815391910981718),
#  (u'walk', 1.5872418542103539),
#  (u'has', 1.5880591815954528),
#  (u'away', 1.5896958431719206),
#  (u'one', 1.603716691413859)]

# %%
mnb = MultinomialNB()
mnb.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
mnb.score(X_train, y_train)
# Out:
# 0.66151749204906862

# %%
X_test = tfidf.transform(X_test_raw).toarray()
mnb.score(X_test, y_test)
# Out:
# 0.63760217983651224

# %%
1-float(sum(y))/len(y)
# Out:
# 0.36456558773424186

# %% [markdown]
# ARTSY test results:
# (0.4119250425894378, 0.5880749574105621)
# (random_state, train_results, test_results)
#
#
# tfidf = TfidfVectorizer():
#
# (1, 0.66242616992276238, 0.6389645776566758)
# (42, 0.67060427078600637, 0.6634877384196185)
# (55, 0.671967287596547, 0.5926430517711172)
#
#
# tfidf = TfidfVectorizer(max_df = .9, ngram_range=(1,2)):
#
# (1, 0.67105860972285325 , 0.6294277929155313)
# (42, 0.67651067696501588, 0.64850136239782019)
# (55, 0.67560199909132213, 0.5926430517711172)
#
# tfidf = TfidfVectorizer(max_df = .7):
#
# (1, 0.69195820081781012, 0.66485013623978206)
# (42, 0.70331667423898225,0.67983651226158037)
# (55, 0.6942298955020445, 0.5880749574105621)
#
#
#
# DINING test results
# (0.6354344122657581, 0.36456558773424186):
# (random_state, train_results, test_results)
#
# tfidf = TfidfVectorizer(max_df = .7):
# (1, 0.64198091776465238, 0.6294277929155313)
# (42, 0.64198091776465238, 0.64441416893732972)
# (55, 0.64288959563834625, 0.63623978201634879)

# %% [markdown]
# #Random Forest Model

# %%
1+1

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_raw, y)
rfc.oob_score_

# %%
rfc.feature_importances_

# %% [markdown]
# #Testing NMF

# %%
from sklearn.decomposition import NMF as NMF_real

# %%
nmf_real = NMF_real(n_components=10)

# %%
nmf_real.fit(X_train)
# Out:
# NMF(beta=1, eta=0.1, init=None, max_iter=200, n_components=10,
#   nls_max_iter=2000, random_state=None, sparseness=None, tol=0.0001)

# %%
feature_names = tfidf.get_feature_names()

n_top_words = 20
for topic_idx, topic in enumerate(nmf_real.components_):
    print("Topic #%d:" % topic_idx)
    print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print
# Out:
# Topic #0:
# my it if have there your will be can but so that or room me am not out very at
#
# Topic #1:
# san francisco street parking muni park mission blocks bart gate golden bus downtown or away valley car castro beach public
#
# Topic #2:
# we our have us your re home will if so that also as can it guests or be but here
#
# Topic #3:
# looky mission home shared stay guests house other quality main kitchens we among who would homes clean transportation affordable bathrooms
#
# Topic #4:
# train min walk minutes minute 15 subway 10 away station manhattan 20 by square close only ride blocks williamsburg mins
#
# Topic #5:
# apartment east village subway nyc central building west side square park away all york new blocks soho restaurants street trains
#
# Topic #6:
# brooklyn prospect manhattan park williamsburg clinton as slope greene hill barclays train museum fort music brownstone new neighborhood there or
#
# Topic #7:
# community mission fun active enough culture min term diverse we bike night crucial inspiration this skills perks consistent melting balance
#
# Topic #8:
# bedroom room bed living size large has full kitchen queen bathroom tv apartment dining two one flat floor private bedrooms
#
# Topic #9:
# fee check fees your please cleaning no be additional rental available service reservation per at not or upon arrival security

# %%
from sklearn.metrics.pairwise import pairwise_distances
pairwise_distances(nmf_real.components_, X_test[80], metric='cosine')
# Out:
# array([[ 0.84013162],
#        [ 0.85445981],
#        [ 0.91891666],
#        [ 0.93442365],
#        [ 0.84178803],
#        [ 0.70892337],
#        [ 0.86819491],
#        [ 0.96388839],
#        [ 0.78754433],
#        [ 0.86451754]])

# %%
nmf_real.components_
# Out:
# array([[ 0.01488535,  0.        ,  0.00375196, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.011464  ,  0.00349046,  0.00077285, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.00178726,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.        ,  0.        ,  0.00092713, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.00232949,  0.0009732 ,  0.00330116, ...,  0.00607394,
#          0.00404929,  0.01012324],
#        [ 0.14417158,  0.01810505,  0.00504086, ...,  0.        ,
#          0.        ,  0.        ]])
