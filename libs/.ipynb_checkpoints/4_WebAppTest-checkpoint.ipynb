# %%
from bs4 import BeautifulSoup
import pickle

# %%
import airbnbsearchresult as air_sr

DB_NAME = 'airbnb'
COLL_NAME = 'search'

# %%
reload(air_sr)
air_search = air_sr.AirBnBSearchResult(db_name=DB_NAME, coll_name=COLL_NAME)
air_search

# %%
#reminder of what the format is
import pandas as pd
df = pd.read_csv('../data/city_list.csv')
df.head()
# Out:
#    city_id           city state        country
# 0        1  San-Francisco    CA  United-States
# 1        2       New-York    NY  United-States

# %%
params = {'city':'San-Francisco',
          'state':'CA',
          'country':'United-States',
          'checkin':'06-16-2015',
          'checkout':'06-18-2015',
          'guests':2}
air_search.set_params(params=params)
air_search.params
# Out:
# {'checkin': '06-16-2015',
#  'checkout': '06-18-2015',
#  'city': 'San-Francisco',
#  'country': 'United-States',
#  'guests': 2,
#  'state': 'CA'}

# %%
# air_search.scrape_from_web(insert_into_db=False)
air_search.pull_one_from_db()

# %%
air_search.r.url
# Out:
# u'https://www.airbnb.com/s/San-Francisco--CA--United-States?checkin=06-16-2015&checkout=06-18-2015&guests=1&page=1'

# %%
air_search.r.status_code
# Out:
# 200

# %%
air_search.extract_listing_ids()
# Out:
# ['6751766',
#  '6784213',
#  '1510363',
#  '6785229',
#  '4882295',
#  '44323',
#  '267820',
#  '5650515',
#  '764010',
#  '12522']

# %%
soup = BeautifulSoup(air_search.r.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 8]>
#
# <html lang="en"
#
#       xmlns:fb="http://ogp.me/ns/fb#"
#       class="ie">
#
# <![endif]--><!--[if IE 8]>
#
# <html lang="en"
#
#       xmlns:fb="http://ogp.me/ns/fb#"
#       class="ie ie8">
#
# <![endif]--><!--[if IE 9]>
#
#   <html lang="en"
#
#       xmlns:fb="http://ogp.me/ns/fb#"
#       class="ie ie9">
#
# <![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html lang="en" xmlns:fb="http://ogp.me/ns/fb#">
# <!--<![endif]-->
# <head>
# <link href="//maps.googleapis.com" rel="dns-prefetch"/>
# <link href="//maps.gstatic.com" rel="dns-prefetch"/>
# <link href="//mts0.googleapis.com" rel="dns-prefetch"/>
# <link href="//mts1.googleapis.com" rel="dns-prefetch"/>
# <!--[if IE]><![endif]-->
# <meta charset="utf-8"/>
# <!--[if IE 8]>
#       <link href="https://a0.muscache.com/airbnb/static/packages/common_o2.1_ie8-571b1ade51353e6c547d3046fe6e2b59.css" media="all" rel="stylesheet" type="text/css" />
#     <![endif]-->
# <!--[if !(IE 8)]><!-->
# ...

# %% [markdown]
# ###NOTE: I encountered an issue scraping, so I saved the error requests object as a pickle.
# See next 2 boxes

# %%
# pickling the error soup
pkl = pickle.dump(air_search.r, open('../other/error_request.pkl', 'w'))

# %%
input_file = '../other/error_request.pkl'
f = open(input_file)
x = pickle.loads(f.read())
x
# Out:
# <Response [200]>

# %%
air_search.coll.find_one({}).keys()
#air_search.coll.find_one({})['params'].keys()
# Out:
# [u'city',
#  u'url',
#  u'country',
#  u'requests_meta',
#  u'content',
#  u'state',
#  u'params',
#  u'time',
#  u'dt',
#  u'_id',
#  u'pickle',
#  u'page']

# %%
sample_search = air_search.coll.find_one({'city':params['city'], 
                          'state':params['state'],
                          'country':params['country'],
                          'params.checkin':'06-16-2015'})

# %%
soup = BeautifulSoup(sample_search['pickle'])

# %%
#Finding the X & Y coords of the listing
air_search.extract_thumbnail_data()
# Out:
# {'12522': {'blurb': 'Perfectly located Castro',
#   'lat': '37.760721593547714',
#   'listing_id': '12522',
#   'listing_type': 'not available',
#   'lng': '-122.42815308225491',
#   'thumbnail_img': 'https://a0.muscache.com/ac/pictures/9158991/d0fa6362_original.jpg?interpolation=lanczos-none&size=x_medium&output-format=jpg&output-quality=70',
#   'thumbnail_price': 'n/a'},
#  '1510363': {'blurb': 'Cozy 2 BR  Apt. In The Sunnyside',
#   'lat': '37.7288094455469',
#   'listing_id': '1510363',
#   'listing_type': u'\n  Entire home/apt\n     ',
#   'lng': '-122.45282003304021',
#   'thumbnail_img': 'https://a1.muscache.com/ac/pictures/23638135/bed8fa30_original.jpg?interpolation=lanczos-none&size=x_medium&output-format=jpg&output-quality=70',
#   'thumbnail_price': u'110'},
#  '267820': {'blurb': 'Beautiful Twin Peaks Apartment',
#   'lat': '37.75095253762238',
#   'listing_id': '267820',
#   'listing_type': u'\n  Entire home/apt\n     ',
#   'lng': '-122.44536432100527',
# ...

# %% [markdown]
# #TEST to see if scraping works (6.22)

# %%
params = {'city':'San-Francisco',
          'state':'CA',
          'country':'United-States',
          'checkin':'06-26-2015',
          'checkout':'06-28-2015',
          'guests':2, 
          'price_max':400}
air_search.set_params(params=params)
air_search.params
# Out:
# {'checkin': '06-26-2015',
#  'checkout': '06-28-2015',
#  'city': 'San-Francisco',
#  'country': 'United-States',
#  'guests': 2,
#  'price_max': 400,
#  'state': 'CA'}

# %%
air_search.scrape_from_web(insert_into_db=False)

# %%
soup = BeautifulSoup(air_search.r.content)
